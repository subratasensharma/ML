# %%
# https://www.analyticsvidhya.com/blog/2018/11/implementation-faster-r-cnn-python-object-detection/?utm_source=blog&utm_medium=a-step-by-step-introduction-to-the-basic-object-detection-algorithms-part-1

# %%
import os
from os import listdir
import xml.etree.ElementTree as ET
import pandas as pd
import glob

# %%
# function to extract bounding boxes from an annotation file

def extract_boxes(filename):
    
    blood_frame = pd.DataFrame()
    
    # load and parse the file
    tree = ET.parse(filename)
    
    # get the root of the document
    root = tree.getroot()
    
    # extract each bounding box
    boxes = list()
    i_name = root[1].text    # since image name is in position [1] of .xml file - see .xml file
    width = int(root.find('.//size/width').text)
    height = int(root.find('.//size/height').text)
    
    
    for box in root.findall('.//object'):
        
        c_name = box.find('name').text
        
        xmin = int(box.find('.//bndbox/xmin').text)
        ymin = int(box.find('.//bndbox/ymin').text)
        xmax = int(box.find('.//bndbox/xmax').text)
        ymax = int(box.find('.//bndbox/ymax').text)
        coors = [i_name, c_name, xmin, xmax, ymin, ymax, width, height]
        boxes.append(coors)
        
    blood_frame = pd.DataFrame(boxes)
    
    return blood_frame

# %%
# Extract all info incl. boundary boxes from annotation file and creating a dataframe :

files = glob.glob('/home/scar3crow/Downloads/BCCD_Dataset-master/BCCD/Annotations/*.xml')

col_names = ['image_names', 'cell_type', 'xmin', 'xmax', 'ymin', 'ymax', 'width', 'height']

b_frame = pd.DataFrame()

for i in range(len(files)):
#    b_frame.append(extract_boxes(files[i]))
    b_frame = pd.concat([b_frame, extract_boxes(files[i])])
    
b_frame.columns = col_names

b_frame = b_frame.reset_index(drop = True)

# %%
print('Number of unique images = ', b_frame['image_names'].nunique())  # print total no, of unique images

print('Number of classes in diff. categories = ', b_frame['cell_type'].value_counts()) 

b_frame.tail(3)
# Out:
# Number of unique images =  364
# Number of classes in diff. categories =  RBC          4155
# WBC           372
# Platelets     361
# Name: cell_type, dtype: int64
#                image_names  cell_type  xmin  xmax  ymin  ymax  width  height
# 4885  BloodImage_00248.jpg        WBC   149   354   233   423    640     480
# 4886  BloodImage_00147.jpg  Platelets   200   238   249   294    640     480
# 4887  BloodImage_00147.jpg        WBC   339   514    42   207    640     480

# %%
# making train_dataframe for images in train_images

train_df = pd.DataFrame()

train_image_list = list()
train_image_list = listdir('/home/scar3crow/Dropbox/WorkStation-Subrata/python/keras-frcnn/train_images')

train_df = b_frame.loc[b_frame['image_names'].isin(train_image_list)]

train_df = train_df.reset_index(drop=True)

train_df.tail(3)
# Out:
#                image_names  cell_type  xmin  xmax  ymin  ymax  width  height
# 3404  BloodImage_00248.jpg        WBC   149   354   233   423    640     480
# 3405  BloodImage_00147.jpg  Platelets   200   238   249   294    640     480
# 3406  BloodImage_00147.jpg        WBC   339   514    42   207    640     480

# %%
print('Number of images in train_images file = ', len(train_image_list))
print('Number of unique images in train dataframe = ', train_df['image_names'].nunique())
# Out:
# Number of images in train_images file =  254
# Number of unique images in train dataframe =  254

# %%
data = pd.DataFrame()

data['format'] = train_df['image_names']

data.tail(3)
# Out:
#                     format
# 3404  BloodImage_00248.jpg
# 3405  BloodImage_00147.jpg
# 3406  BloodImage_00147.jpg

# %%
pwd
# Out:
# '/home/scar3crow/Dropbox/WorkStation-Subrata/python'

# %%
cd keras-frcnn
# Out:
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/keras-frcnn

# %%
# as the images are in train_images folder, add path of images before the image name

for i in range(data.shape[0]):
    data['format'][i] = '/home/scar3crow/Dropbox/WorkStation-Subrata/python/keras-frcnn/train_images/' + data['format'][i]
    
    
# add xmin, ymin, xmax, ymax and class as per the format required

for i in range(data.shape[0]):
    data['format'][i] = data['format'][i] + ',' + str(train_df['xmin'][i]) + ',' + str(train_df['ymin'][i]) + ',' + str(train_df['xmax'][i]) + ',' + str(train_df['ymax'][i]) + ',' + train_df['cell_type'][i]

data.to_csv('annotate_new.txt', header=None, index=None, sep=' ')

# %%
# !python3 train_frcnn.py -o simple -p annotate_new.txt
# Out:
# Using TensorFlow backend.
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Parsing annotation files
# Training images per class:
# {'Platelets': 264, 'RBC': 2882, 'WBC': 261, 'bg': 0}
# Num classes (including bg) = 4
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 214
# Num val samples 40
# loading weights from resnet50_weights_tf_dim_ordering_tf_kernels.h5
# Could not load pretrained model weights. Weights can be found in the keras application folder 		https://github.com/fchollet/keras/tree/master/keras/applications
# Starting training
# Epoch 1/200
# 2020-05-08 21:27:35.605698: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 100/100 [==============================] - 2340s 23s/step - rpn_cls: 3.4682 - rpn_regr: 0.1375 - detector_cls: 0.7503 - detector_regr: 0.3644
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 26.42
# Classifier accuracy for bounding boxes from RPN: 0.5928125
# Loss RPN classifier: 3.4681556054949763
# Loss RPN regression: 0.13752920486032963
# Loss Detector classifier: 0.7502986866235734
# Loss Detector regression: 0.3643869659304619
# Elapsed time: 2340.2120893001556
# Total loss decreased from inf to 4.720370462909341, saving weights
# Epoch 2/200
# Average number of overlapping bounding boxes from RPN = 26.42 for 100 previous iterations
# 100/100 [==============================] - 2346s 23s/step - rpn_cls: 3.2019 - rpn_regr: 0.1367 - detector_cls: 0.5301 - detector_regr: 0.3032
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 26.57
# Classifier accuracy for bounding boxes from RPN: 0.7521875
# Loss RPN classifier: 3.2019056914815884
# Loss RPN regression: 0.13670651204884052
# Loss Detector classifier: 0.5301098860055208
# Loss Detector regression: 0.30320124223828315
# Elapsed time: 2357.3596546649933
# Total loss decreased from 4.720370462909341 to 4.171923331774233, saving weights
# Epoch 3/200
# Average number of overlapping bounding boxes from RPN = 26.57 for 100 previous iterations
#  99/100 [============================>.] - ETA: 24s - rpn_cls: 3.1117 - rpn_regr: 0.1193 - detector_cls: 0.4651 - detector_regr: 0.2584Average number of overlapping bounding boxes from RPN = 22.8 for 100 previous iterations
# 100/100 [==============================] - 2411s 24s/step - rpn_cls: 3.1328 - rpn_regr: 0.1195 - detector_cls: 0.4644 - detector_regr: 0.2594
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.752475247524753
# Classifier accuracy for bounding boxes from RPN: 0.7803125
# Loss RPN classifier: 3.1328030121326447
# Loss RPN regression: 0.11950986100360751
# Loss Detector classifier: 0.4643546389043331
# Loss Detector regression: 0.2594286245107651
# Elapsed time: 2412.2780883312225
# Total loss decreased from 4.171923331774233 to 3.9760961365513503, saving weights
# Epoch 4/200
#  99/100 [============================>.] - ETA: 24s - rpn_cls: 3.1870 - rpn_regr: 0.1427 - detector_cls: 0.3993 - detector_regr: 0.2600Average number of overlapping bounding boxes from RPN = 22.6 for 100 previous iterations
# 100/100 [==============================] - 2437s 24s/step - rpn_cls: 3.1600 - rpn_regr: 0.1429 - detector_cls: 0.4011 - detector_regr: 0.2596
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.58
# Classifier accuracy for bounding boxes from RPN: 0.8115625
# Loss RPN classifier: 3.1599907317757605
# Loss RPN regression: 0.14285319358110427
# Loss Detector classifier: 0.4011124423984438
# Loss Detector regression: 0.25960968136787416
# Elapsed time: 2438.025161743164
# Total loss decreased from 3.9760961365513503 to 3.963566049123183, saving weights
# Epoch 5/200
#  98/100 [============================>.] - ETA: 50s - rpn_cls: 3.1524 - rpn_regr: 0.1124 - detector_cls: 0.3499 - detector_regr: 0.2197 Average number of overlapping bounding boxes from RPN = 23.75 for 100 previous iterations
# 100/100 [==============================] - 2508s 25s/step - rpn_cls: 3.1665 - rpn_regr: 0.1119 - detector_cls: 0.3533 - detector_regr: 0.2211
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.77227722772277
# Classifier accuracy for bounding boxes from RPN: 0.85
# Loss RPN classifier: 3.166494505686569
# Loss RPN regression: 0.11185200039297342
# Loss Detector classifier: 0.35330731452442704
# Loss Detector regression: 0.2211087518185377
# Elapsed time: 2508.7116096019745
# Total loss decreased from 3.963566049123183 to 3.8527625724225074, saving weights
# Epoch 6/200
#  98/100 [============================>.] - ETA: 49s - rpn_cls: 3.2098 - rpn_regr: 0.1274 - detector_cls: 0.4107 - detector_regr: 0.2358 Average number of overlapping bounding boxes from RPN = 28.81 for 100 previous iterations
# 100/100 [==============================] - 2500s 25s/step - rpn_cls: 3.1915 - rpn_regr: 0.1266 - detector_cls: 0.4077 - detector_regr: 0.2355
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 28.84
# Classifier accuracy for bounding boxes from RPN: 0.820625
# Loss RPN classifier: 3.191452788710594
# Loss RPN regression: 0.126567656211555
# Loss Detector classifier: 0.40768449123948813
# Loss Detector regression: 0.23545340195298195
# Elapsed time: 2501.962841272354
# Epoch 7/200
#  97/100 [============================>.] - ETA: 1:16 - rpn_cls: 3.0465 - rpn_regr: 0.1194 - detector_cls: 0.3791 - detector_regr: 0.2408Average number of overlapping bounding boxes from RPN = 29.38 for 100 previous iterations
# 100/100 [==============================] - 2536s 25s/step - rpn_cls: 3.0231 - rpn_regr: 0.1207 - detector_cls: 0.3777 - detector_regr: 0.2421
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 29.495049504950494
# Classifier accuracy for bounding boxes from RPN: 0.8471875
# Loss RPN classifier: 3.023116697072983
# Loss RPN regression: 0.12065642952919006
# Loss Detector classifier: 0.3776629520952702
# Loss Detector regression: 0.2421096071600914
# Elapsed time: 2536.3874340057373
# Total loss decreased from 3.8527625724225074 to 3.763545685857534, saving weights
# Epoch 8/200
#  97/100 [============================>.] - ETA: 1:15 - rpn_cls: 2.1138 - rpn_regr: 0.1042 - detector_cls: 0.4179 - detector_regr: 0.2539Average number of overlapping bounding boxes from RPN = 29.53 for 100 previous iterations
# 100/100 [==============================] - 2531s 25s/step - rpn_cls: 2.1104 - rpn_regr: 0.1042 - detector_cls: 0.4161 - detector_regr: 0.2514
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 30.11
# Classifier accuracy for bounding boxes from RPN: 0.8171875
# Loss RPN classifier: 2.1103865864827607
# Loss RPN regression: 0.10419854074716568
# Loss Detector classifier: 0.4161063253507018
# Loss Detector regression: 0.2513520134985447
# Elapsed time: 2531.979500055313
# Total loss decreased from 3.763545685857534 to 2.8820434660791725, saving weights
# Epoch 9/200
#  97/100 [============================>.] - ETA: 1:15 - rpn_cls: 2.0661 - rpn_regr: 0.1216 - detector_cls: 0.4194 - detector_regr: 0.2687Average number of overlapping bounding boxes from RPN = 28.45 for 100 previous iterations
# 100/100 [==============================] - 2522s 25s/step - rpn_cls: 2.0636 - rpn_regr: 0.1214 - detector_cls: 0.4240 - detector_regr: 0.2709
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 28.01
# Classifier accuracy for bounding boxes from RPN: 0.811875
# Loss RPN classifier: 2.0636238936606968
# Loss RPN regression: 0.12138618141412735
# Loss Detector classifier: 0.4239970819652081
# Loss Detector regression: 0.27092184767127037
# Elapsed time: 2523.2708010673523
# Total loss decreased from 2.8820434660791725 to 2.8799290047113026, saving weights
# Epoch 10/200
#  97/100 [============================>.] - ETA: 1:15 - rpn_cls: 2.0147 - rpn_regr: 0.1096 - detector_cls: 0.4175 - detector_regr: 0.2505Average number of overlapping bounding boxes from RPN = 31.06 for 100 previous iterations
# 100/100 [==============================] - 2524s 25s/step - rpn_cls: 2.0094 - rpn_regr: 0.1100 - detector_cls: 0.4168 - detector_regr: 0.2498
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 31.19
# Classifier accuracy for bounding boxes from RPN: 0.82
# Loss RPN classifier: 2.0093739542275673
# Loss RPN regression: 0.11002521935850382
# Loss Detector classifier: 0.41679861426353454
# Loss Detector regression: 0.24980456978082657
# Elapsed time: 2524.545313358307
# Total loss decreased from 2.8799290047113026 to 2.7860023576304322, saving weights
# Epoch 11/200
#  96/100 [===========================>..] - ETA: 1:41 - rpn_cls: 2.0731 - rpn_regr: 0.1146 - detector_cls: 0.3384 - detector_regr: 0.2289Average number of overlapping bounding boxes from RPN = 27.85 for 100 previous iterations
# 100/100 [==============================] - 2540s 25s/step - rpn_cls: 2.0832 - rpn_regr: 0.1134 - detector_cls: 0.3399 - detector_regr: 0.2273
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 27.584158415841586
# Classifier accuracy for bounding boxes from RPN: 0.850625
# Loss RPN classifier: 2.0831686727055465
# Loss RPN regression: 0.11344902759417891
# Loss Detector classifier: 0.33986933395266533
# Loss Detector regression: 0.2272816614061594
# Elapsed time: 2541.0022563934326
# Total loss decreased from 2.7860023576304322 to 2.76376869565855, saving weights
# Epoch 12/200
#  96/100 [===========================>..] - ETA: 1:41 - rpn_cls: 1.9421 - rpn_regr: 0.1116 - detector_cls: 0.3936 - detector_regr: 0.2179Average number of overlapping bounding boxes from RPN = 27.05 for 100 previous iterations
# 100/100 [==============================] - 2537s 25s/step - rpn_cls: 1.9491 - rpn_regr: 0.1130 - detector_cls: 0.3986 - detector_regr: 0.2200
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 27.19
# Classifier accuracy for bounding boxes from RPN: 0.8215625
# Loss RPN classifier: 1.949107431920711
# Loss RPN regression: 0.11300106585025788
# Loss Detector classifier: 0.3986185584962368
# Loss Detector regression: 0.2200381314754486
# Elapsed time: 2537.7844519615173
# Total loss decreased from 2.76376869565855 to 2.680765187742654, saving weights
# Epoch 13/200
#  95/100 [===========================>..] - ETA: 2:07 - rpn_cls: 2.0051 - rpn_regr: 0.1188 - detector_cls: 0.3925 - detector_regr: 0.2381Average number of overlapping bounding boxes from RPN = 27.03 for 100 previous iterations
# 100/100 [==============================] - 2557s 26s/step - rpn_cls: 1.9944 - rpn_regr: 0.1181 - detector_cls: 0.3906 - detector_regr: 0.2373
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 27.18811881188119
# Classifier accuracy for bounding boxes from RPN: 0.8278125
# Loss RPN classifier: 1.994403749273342
# Loss RPN regression: 0.11806860607117414
# Loss Detector classifier: 0.3906345023214817
# Loss Detector regression: 0.23733856119215488
# Elapsed time: 2558.155748605728
# Epoch 14/200
#  95/100 [===========================>..] - ETA: 2:06 - rpn_cls: 1.8903 - rpn_regr: 0.0995 - detector_cls: 0.3886 - detector_regr: 0.2217Average number of overlapping bounding boxes from RPN = 24.79 for 100 previous iterations
# 100/100 [==============================] - 2539s 25s/step - rpn_cls: 1.8799 - rpn_regr: 0.1003 - detector_cls: 0.3861 - detector_regr: 0.2223
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.15841584158416
# Classifier accuracy for bounding boxes from RPN: 0.8271875
# Loss RPN classifier: 1.8799383219763695
# Loss RPN regression: 0.10034686559811234
# Loss Detector classifier: 0.38614714056253435
# Loss Detector regression: 0.22227419406175614
# Elapsed time: 2539.096123456955
# Total loss decreased from 2.680765187742654 to 2.5887065221987724, saving weights
# Epoch 15/200
#  94/100 [===========================>..] - ETA: 2:26 - rpn_cls: 1.8310 - rpn_regr: 0.1175 - detector_cls: 0.4178 - detector_regr: 0.2247Average number of overlapping bounding boxes from RPN = 38.55 for 100 previous iterations
# 100/100 [==============================] - 2432s 24s/step - rpn_cls: 1.8309 - rpn_regr: 0.1162 - detector_cls: 0.4097 - detector_regr: 0.2256
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 38.8
# Classifier accuracy for bounding boxes from RPN: 0.8121875
# Loss RPN classifier: 1.830931727168645
# Loss RPN regression: 0.1162162835150957
# Loss Detector classifier: 0.4097109746932983
# Loss Detector regression: 0.22563336871564388
# Elapsed time: 2433.1318359375
# Total loss decreased from 2.5887065221987724 to 2.582492354092683, saving weights
# Epoch 16/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 1.3407 - rpn_regr: 0.1122 - detector_cls: 0.4257 - detector_regr: 0.2287Average number of overlapping bounding boxes from RPN = 50.16 for 100 previous iterations
# 100/100 [==============================] - 2399s 24s/step - rpn_cls: 1.3343 - rpn_regr: 0.1110 - detector_cls: 0.4256 - detector_regr: 0.2262
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 51.7
# Classifier accuracy for bounding boxes from RPN: 0.8075
# Loss RPN classifier: 1.334342845631536
# Loss RPN regression: 0.11097197737544776
# Loss Detector classifier: 0.425602680593729
# Loss Detector regression: 0.22619559966027736
# Elapsed time: 2399.916711807251
# Total loss decreased from 2.582492354092683 to 2.09711310326099, saving weights
# Epoch 17/200
#  94/100 [===========================>..] - ETA: 2:24 - rpn_cls: 1.3787 - rpn_regr: 0.1103 - detector_cls: 0.4476 - detector_regr: 0.2172Average number of overlapping bounding boxes from RPN = 59.2 for 100 previous iterations
# 100/100 [==============================] - 2412s 24s/step - rpn_cls: 1.3708 - rpn_regr: 0.1112 - detector_cls: 0.4495 - detector_regr: 0.2168
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 59.48
# Classifier accuracy for bounding boxes from RPN: 0.79125
# Loss RPN classifier: 1.3708186841807584
# Loss RPN regression: 0.11123955201357603
# Loss Detector classifier: 0.4495204532146454
# Loss Detector regression: 0.2167676753550768
# Elapsed time: 2412.3438358306885
# Epoch 18/200
#  94/100 [===========================>..] - ETA: 2:24 - rpn_cls: 1.4014 - rpn_regr: 0.1079 - detector_cls: 0.4226 - detector_regr: 0.2138Average number of overlapping bounding boxes from RPN = 50.43 for 100 previous iterations
# 100/100 [==============================] - 2410s 24s/step - rpn_cls: 1.3791 - rpn_regr: 0.1065 - detector_cls: 0.4195 - detector_regr: 0.2112
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 49.64
# Classifier accuracy for bounding boxes from RPN: 0.800625
# Loss RPN classifier: 1.3791345201963299
# Loss RPN regression: 0.1065289587713778
# Loss Detector classifier: 0.4194745948910713
# Loss Detector regression: 0.21120522864162922
# Elapsed time: 2409.527014732361
# Epoch 19/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 1.2492 - rpn_regr: 0.1078 - detector_cls: 0.3927 - detector_regr: 0.2045Average number of overlapping bounding boxes from RPN = 56.03 for 100 previous iterations
# 100/100 [==============================] - 2401s 24s/step - rpn_cls: 1.2274 - rpn_regr: 0.1070 - detector_cls: 0.3941 - detector_regr: 0.2053
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 58.08
# Classifier accuracy for bounding boxes from RPN: 0.81875
# Loss RPN classifier: 1.227372633210689
# Loss RPN regression: 0.10704187363386154
# Loss Detector classifier: 0.3941270187497139
# Loss Detector regression: 0.20527045298367738
# Elapsed time: 2401.3843603134155
# Total loss decreased from 2.09711310326099 to 1.9338119785779417, saving weights
# Epoch 20/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 1.4512 - rpn_regr: 0.1119 - detector_cls: 0.4011 - detector_regr: 0.2042Average number of overlapping bounding boxes from RPN = 55.76 for 100 previous iterations
# 100/100 [==============================] - 2390s 24s/step - rpn_cls: 1.4201 - rpn_regr: 0.1125 - detector_cls: 0.4013 - detector_regr: 0.2053
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 54.23
# Classifier accuracy for bounding boxes from RPN: 0.815625
# Loss RPN classifier: 1.420070722538851
# Loss RPN regression: 0.11247278325259685
# Loss Detector classifier: 0.40128643199801445
# Loss Detector regression: 0.2053396685421467
# Elapsed time: 2390.8946104049683
# Epoch 21/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.1362 - rpn_regr: 0.1056 - detector_cls: 0.4186 - detector_regr: 0.1965Average number of overlapping bounding boxes from RPN = 54.87 for 100 previous iterations
# 100/100 [==============================] - 2381s 24s/step - rpn_cls: 1.1178 - rpn_regr: 0.1028 - detector_cls: 0.4148 - detector_regr: 0.1968
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 54.8
# Classifier accuracy for bounding boxes from RPN: 0.8059375
# Loss RPN classifier: 1.1177865564302936
# Loss RPN regression: 0.10277656706050038
# Loss Detector classifier: 0.4147856591641903
# Loss Detector regression: 0.19678716488182546
# Elapsed time: 2380.9333956241608
# Total loss decreased from 1.9338119785779417 to 1.8321359475368095, saving weights
# Epoch 22/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 1.1070 - rpn_regr: 0.0968 - detector_cls: 0.3999 - detector_regr: 0.2118Average number of overlapping bounding boxes from RPN = 60.2 for 100 previous iterations
# 100/100 [==============================] - 2386s 24s/step - rpn_cls: 1.1192 - rpn_regr: 0.0959 - detector_cls: 0.4040 - detector_regr: 0.2109
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 60.57
# Classifier accuracy for bounding boxes from RPN: 0.8146875
# Loss RPN classifier: 1.1191942287279522
# Loss RPN regression: 0.09591802263632417
# Loss Detector classifier: 0.4039969597756863
# Loss Detector regression: 0.21094446241855622
# Elapsed time: 2386.5744609832764
# Total loss decreased from 1.8321359475368095 to 1.8300536735585187, saving weights
# Epoch 23/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.1790 - rpn_regr: 0.0891 - detector_cls: 0.4558 - detector_regr: 0.2070Average number of overlapping bounding boxes from RPN = 59.95 for 100 previous iterations
# 100/100 [==============================] - 2376s 24s/step - rpn_cls: 1.1646 - rpn_regr: 0.0893 - detector_cls: 0.4511 - detector_regr: 0.2065
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 59.95
# Classifier accuracy for bounding boxes from RPN: 0.7853125
# Loss RPN classifier: 1.164565885648517
# Loss RPN regression: 0.08931870145723224
# Loss Detector classifier: 0.4510671027004719
# Loss Detector regression: 0.2064536128938198
# Elapsed time: 2376.7578585147858
# Epoch 24/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.0313 - rpn_regr: 0.1082 - detector_cls: 0.3987 - detector_regr: 0.1921Average number of overlapping bounding boxes from RPN = 57.25 for 100 previous iterations
# 100/100 [==============================] - 2369s 24s/step - rpn_cls: 1.0195 - rpn_regr: 0.1058 - detector_cls: 0.3977 - detector_regr: 0.1924
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 57.11
# Classifier accuracy for bounding boxes from RPN: 0.815625
# Loss RPN classifier: 1.0195019271729324
# Loss RPN regression: 0.10579545762389898
# Loss Detector classifier: 0.3977278643846512
# Loss Detector regression: 0.19244308926165105
# Elapsed time: 2368.666093349457
# Total loss decreased from 1.8300536735585187 to 1.7154683384431337, saving weights
# Epoch 25/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 1.2438 - rpn_regr: 0.0922 - detector_cls: 0.4284 - detector_regr: 0.1936Average number of overlapping bounding boxes from RPN = 59.65 for 100 previous iterations
# 100/100 [==============================] - 2386s 24s/step - rpn_cls: 1.2222 - rpn_regr: 0.0925 - detector_cls: 0.4287 - detector_regr: 0.1948
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 60.17
# Classifier accuracy for bounding boxes from RPN: 0.8003125
# Loss RPN classifier: 1.2221773129465212
# Loss RPN regression: 0.09245998194441199
# Loss Detector classifier: 0.4287271885573864
# Loss Detector regression: 0.19483617939054965
# Elapsed time: 2386.934278488159
# Epoch 26/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.0563 - rpn_regr: 0.0975 - detector_cls: 0.4032 - detector_regr: 0.1803Average number of overlapping bounding boxes from RPN = 58.7 for 100 previous iterations
# 100/100 [==============================] - 2381s 24s/step - rpn_cls: 1.0561 - rpn_regr: 0.0966 - detector_cls: 0.4036 - detector_regr: 0.1803
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 58.3
# Classifier accuracy for bounding boxes from RPN: 0.816875
# Loss RPN classifier: 1.0561031705996473
# Loss RPN regression: 0.09661087134853005
# Loss Detector classifier: 0.4036474584043026
# Loss Detector regression: 0.18032147362828255
# Elapsed time: 2381.239643573761
# Epoch 27/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.1378 - rpn_regr: 0.1000 - detector_cls: 0.3567 - detector_regr: 0.1903Average number of overlapping bounding boxes from RPN = 53.9 for 100 previous iterations
# 100/100 [==============================] - 2379s 24s/step - rpn_cls: 1.1259 - rpn_regr: 0.0997 - detector_cls: 0.3569 - detector_regr: 0.1914
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 55.31
# Classifier accuracy for bounding boxes from RPN: 0.8328125
# Loss RPN classifier: 1.125896992283524
# Loss RPN regression: 0.09973832920193672
# Loss Detector classifier: 0.35690976813435554
# Loss Detector regression: 0.19139285542070866
# Elapsed time: 2379.0424349308014
# Epoch 28/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.1190 - rpn_regr: 0.0922 - detector_cls: 0.3992 - detector_regr: 0.1913Average number of overlapping bounding boxes from RPN = 62.62 for 100 previous iterations
# 100/100 [==============================] - 2379s 24s/step - rpn_cls: 1.1501 - rpn_regr: 0.0938 - detector_cls: 0.3934 - detector_regr: 0.1891
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 61.18
# Classifier accuracy for bounding boxes from RPN: 0.8178125
# Loss RPN classifier: 1.1501405889240415
# Loss RPN regression: 0.09378258457407355
# Loss Detector classifier: 0.39337691411375997
# Loss Detector regression: 0.18913299791514873
# Elapsed time: 2378.7740597724915
# Epoch 29/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.1430 - rpn_regr: 0.0919 - detector_cls: 0.3916 - detector_regr: 0.1848Average number of overlapping bounding boxes from RPN = 58.57 for 100 previous iterations
# 100/100 [==============================] - 2373s 24s/step - rpn_cls: 1.1598 - rpn_regr: 0.0911 - detector_cls: 0.3937 - detector_regr: 0.1855
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 59.59
# Classifier accuracy for bounding boxes from RPN: 0.825
# Loss RPN classifier: 1.1598427055682987
# Loss RPN regression: 0.09105157675221562
# Loss Detector classifier: 0.3936927284300327
# Loss Detector regression: 0.18553195625543595
# Elapsed time: 2373.2199079990387
# Epoch 30/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 0.9631 - rpn_regr: 0.0902 - detector_cls: 0.3921 - detector_regr: 0.1786Average number of overlapping bounding boxes from RPN = 58.5 for 100 previous iterations
# 100/100 [==============================] - 2383s 24s/step - rpn_cls: 0.9770 - rpn_regr: 0.0905 - detector_cls: 0.3924 - detector_regr: 0.1792
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 57.71
# Classifier accuracy for bounding boxes from RPN: 0.83
# Loss RPN classifier: 0.9769971531948886
# Loss RPN regression: 0.09050333252176643
# Loss Detector classifier: 0.39242436081171034
# Loss Detector regression: 0.17922499880194664
# Elapsed time: 2383.281487226486
# Total loss decreased from 1.7154683384431337 to 1.6391498453303122, saving weights
# Epoch 31/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 1.0454 - rpn_regr: 0.0962 - detector_cls: 0.3711 - detector_regr: 0.1738Average number of overlapping bounding boxes from RPN = 57.87 for 100 previous iterations
# 100/100 [==============================] - 2376s 24s/step - rpn_cls: 1.0440 - rpn_regr: 0.0954 - detector_cls: 0.3739 - detector_regr: 0.1746
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 57.57
# Classifier accuracy for bounding boxes from RPN: 0.8259375
# Loss RPN classifier: 1.044028130500028
# Loss RPN regression: 0.09544778941199183
# Loss Detector classifier: 0.3738933852314949
# Loss Detector regression: 0.17463862534612418
# Elapsed time: 2377.325515270233
# Epoch 32/200
#  94/100 [===========================>..] - ETA: 2:19 - rpn_cls: 0.9295 - rpn_regr: 0.0844 - detector_cls: 0.3723 - detector_regr: 0.1738Average number of overlapping bounding boxes from RPN = 59.03 for 100 previous iterations
# 100/100 [==============================] - 2337s 23s/step - rpn_cls: 0.9742 - rpn_regr: 0.0842 - detector_cls: 0.3716 - detector_regr: 0.1729
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 58.61
# Classifier accuracy for bounding boxes from RPN: 0.8440625
# Loss RPN classifier: 0.9741901048453141
# Loss RPN regression: 0.08424406485632062
# Loss Detector classifier: 0.3715868149697781
# Loss Detector regression: 0.17287480100989341
# Elapsed time: 2337.132561683655
# Total loss decreased from 1.6391498453303122 to 1.6028957856813062, saving weights
# Epoch 33/200
#  94/100 [===========================>..] - ETA: 2:23 - rpn_cls: 0.9859 - rpn_regr: 0.0889 - detector_cls: 0.3700 - detector_regr: 0.1769Average number of overlapping bounding boxes from RPN = 59.81 for 100 previous iterations
# 100/100 [==============================] - 2392s 24s/step - rpn_cls: 0.9794 - rpn_regr: 0.0870 - detector_cls: 0.3712 - detector_regr: 0.1766
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 60.33
# Classifier accuracy for bounding boxes from RPN: 0.833125
# Loss RPN classifier: 0.9793700589359549
# Loss RPN regression: 0.08698644859716297
# Loss Detector classifier: 0.37118549913167953
# Loss Detector regression: 0.1766299826093018
# Elapsed time: 2392.421238422394
# Epoch 34/200
#  94/100 [===========================>..] - ETA: 2:22 - rpn_cls: 0.8957 - rpn_regr: 0.0888 - detector_cls: 0.3471 - detector_regr: 0.1787Average number of overlapping bounding boxes from RPN = 62.01 for 100 previous iterations
# 100/100 [==============================] - 2371s 24s/step - rpn_cls: 0.9024 - rpn_regr: 0.0906 - detector_cls: 0.3499 - detector_regr: 0.1788
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 61.85
# Classifier accuracy for bounding boxes from RPN: 0.844375
# Loss RPN classifier: 0.9024469072074521
# Loss RPN regression: 0.09059142718091608
# Loss Detector classifier: 0.34990483827888963
# Loss Detector regression: 0.17881133120507
# Elapsed time: 2370.6630132198334
# Total loss decreased from 1.6028957856813062 to 1.521754503872328, saving weights
# Epoch 35/200
#  89/100 [=========================>....] - ETA: 4:26 - rpn_cls: 0.9673 - rpn_regr: 0.0876 - detector_cls: 0.3580 - detector_regr: 0.1824
