# %%
## start CNN for image processing - 28-01-00

# %%
# Loading data or images

import matplotlib.pyplot as plt

from PIL import Image

from matplotlib import image
from matplotlib import pyplot

# %%
inv_1 = image.imread('INVOICE.jpg')
inv_2 = image.imread('INVOICE1.jpg')
inv_3 = image.imread('INVOICE2.jpg')

# %%
print(inv_1.dtype)
print(inv_1.shape)
print(inv_2.shape)
print(inv_3.shape)
# Out:
# uint8
# (3504, 2528, 3)
# (3504, 2528, 3)
# (3504, 2528, 3)

# %%
# display the array of pixels as an image
pyplot.imshow(inv_1)
pyplot.show()

# %%
# Increase size of the plot by changing 'figsize'
plt.figure(figsize=(30,15))
pyplot.imshow(inv_2)
pyplot.show()

# %%
import keras

from keras.layers import Conv2D

model = keras.models.Sequential()

model.add(Conv2D(2, kernel_size=(3,3), input_shape = (3504, 2528, 3)))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 3502, 2526, 2)     56
# ...
# Total params: 56
# Trainable params: 56
# Non-trainable params: 0
# _________________________________________________________________
