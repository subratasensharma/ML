# %%
cd models/research/object_detection
# Out:
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/models/research/object_detection

# %%
import numpy as np
import math
import pandas as pd
import cv2
import os
import tqdm
from scipy.io import loadmat

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

from PIL import Image
import pytesseract

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras import backend as K

from utils import *

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam, SGD
from keras.layers import *

from keras.applications import MobileNetV2
from keras.applications import InceptionResNetV2

from keras.models import Model
from keras.models import model_from_json

# %%
target_size = [480, 480]
target_w = 480 # target sizes of image in model input
target_h = 480 #target sizes of image in model input

grid_size = [15, 15]
grid_y_axis = 15  # each image is to be segmented to 13 x 13 grid
grid_x_axis = 15  # # each image is to be segmented to 13 x 13 grid

grid_w = target_w / grid_x_axis  # grid cell width
grid_h = target_h / grid_y_axis  # grid cell height

channels = 3
num_anchors = 3
class_num = 5 # vendor, invoice, inv_date, po, buyer
info = 5 + class_num    # pc, x, y, h, w, and class probabilities

categories = ['vendor', 'invoice', 'inv_date', 'po', 'buyer'] # details of classes

# %%
# Making a list of image path

inv_directory = '/home/scar3crow/Downloads/8-6-new-scan'  ## 'invoices' is a zip file of jpg images in ...../Downloads 
                                                        
inv_new_image = ['/home/scar3crow/Downloads/8-6-new-scan/{}'.format(i) for i in os.listdir(inv_directory)] # making the list
inv_new_image.sort() # Sorting the list

num_images = len(inv_new_image)

print('Number of images = ', num_images)
inv_new_image[24]
# Out:
# Number of images =  36
# '/home/scar3crow/Downloads/8-6-new-scan/50a.jpg'

# %%
# Check sizes of exiting images & Create a Dataframe with image id and height(row) and width(column):

rows = []
columns = []
image_sl = []
df_new = pd.DataFrame()

for i in range(len(inv_new_image)):
    image = cv2.imread(inv_new_image[i]) ## Loading image
    height, width, _ = image.shape
    rows.append(height)
    columns.append(width)
    image_sl.append(inv_new_image[i])
    
row_values = pd.Series(rows)
col_values = pd.Series(columns)
image_num = pd.Series(image_sl)


df_new.insert(loc=0, column='image_serial', value=image_num)
df_new.insert(loc=1, column='rows', value=row_values)
df_new.insert(loc=2, column='columns', value=col_values)

df_new.head(3)
# Out:
#                                       image_serial  rows  columns
# 0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg   160      416
# 1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg   406      870
# 2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   260      416

# %%
# Loading output of VGG Image Annotation tool and create a dataframe

r_new_data = pd.read_csv('/home/scar3crow/Downloads/via_new_data.csv')
num_obj = r_new_data['region_count'][0] # number of objects in each photo
r_new_data.drop(r_new_data.columns[[1, 2, 3, 4]], axis=1, inplace=True) # reduce unnecessary columns
r_new_data.sort_values(by=['#filename'], ascending=True) # Sorting based on image-id
num_images = r_new_data["#filename"].nunique() # Find out number of unique images

print('Number of classes = ', num_obj)
print('Number of unique images = ', num_images)
r_new_data[58:61]
# Out:
# Number of classes =  5
# Number of unique images =  36
#    #filename                            region_shape_attributes  \
# 58   63a.jpg  {"name":"rect","x":211,"y":64,"width":76,"heig...
# 59   63a.jpg  {"name":"rect","x":2,"y":68,"width":165,"heigh...
# 60  101a.jpg  {"name":"rect","x":6,"y":23,"width":119,"heigh...
#
#     region_attributes
# 58      {"text":"po"}
# 59   {"text":"buyer"}
# 60  {"text":"vendor"}

# %%
# Making a dataframe for Image_id, x, y, width, height, class, image_width and image_height

x = []
y = []
width = []
height = []
obj_class = []
i_width = []
i_height = []
img_path = []
img_index = []

for i in range(len(r_new_data)):
    
    r_size = r_new_data.values[i, 1][1:(len(r_new_data.values[i, 1])-1)]
    r_size_par = r_size.split(",")
    
    x.append(int("".join(filter(str.isdigit, r_size_par[1]))))
    y.append(int("".join(filter(str.isdigit, r_size_par[2]))))
    width.append(int("".join(filter(str.isdigit, r_size_par[3]))))
    height.append(int("".join(filter(str.isdigit, r_size_par[4]))))
    
    r_attribs = r_new_data.values[i, 2][1:(len(r_new_data.values[i, 2])-1)]
    r_attribs_par = r_attribs.split(':')[1]
    obj_class.append(r_attribs_par[1:(len(r_attribs_par)-1)])
    
    foto_id = r_new_data['#filename'][i]
    i_path = '/home/scar3crow/Downloads/8-6-new-scan/' + foto_id
    foto_index = int(df_new[df_new['image_serial'] == i_path].index[0])
    foto_width = df_new['columns'][foto_index]
    foto_height = df_new['rows'][foto_index]
    i_width.append(foto_width)
    i_height.append(foto_height)
    img_path.append(i_path)
    img_index.append(foto_index)
    
x_values = pd.Series(x)
y_values = pd.Series(y)
width_values = pd.Series(width)
height_values = pd.Series(height)
class_values = pd.Series(obj_class)
i_width_values = pd.Series(i_width)
i_height_values = pd.Series(i_height)
img_path_values = pd.Series(img_path)
img_index_values = pd.Series(img_index)

r_new_data.insert(loc=1, column='img_idx', value=img_index_values)
r_new_data.insert(loc=2, column='i_path', value=img_path_values)
r_new_data.insert(loc=3, column='x', value=x_values)
r_new_data.insert(loc=4, column='y', value=y_values)
r_new_data.insert(loc=5, column='width', value=width_values)
r_new_data.insert(loc=6, column='height', value=height_values)
r_new_data.insert(loc=7, column='obj_class', value=class_values)
r_new_data.insert(loc=8, column='img_wd', value=i_width_values)
r_new_data.insert(loc=9, column='img_ht', value=i_height_values)

r_new_data.drop(r_new_data.columns[[10, 11]], axis=1, inplace=True) # reduce unnecessary columns

r_new_data.rename({'#filename': 'img_id'}, axis=1, inplace=True) # changing column name

r_new_data[3:6]
# Out:
#     img_id  img_idx                                          i_path    x   y  \
# 3  50a.jpg       24  /home/scar3crow/Downloads/8-6-new-scan/50a.jpg  221  59
# 4  50a.jpg       24  /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5  57
# 5  51a.jpg       25  /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    5   0
#
#    width  height obj_class  img_wd  img_ht
# 3    103      24        po     416     209
# 4    206      56     buyer     416     209
# 5    120      56    vendor     416     194

# %%
print('Number of unique images = ', r_new_data['img_id'].nunique())  # print total no, of unique images
print('Number of classes in diff. categories = ', r_new_data['obj_class'].value_counts())
# Out:
# Number of unique images =  36
# Number of classes in diff. categories =  buyer      38
# invoice    36
# vendor     36
# date       36
# po         33
# order       1
# Name: obj_class, dtype: int64

# %%
# We have to correct above :

# To find smallest width & height boxes in 'buyer' which should be 'po'
gb = r_new_data.groupby('obj_class')    
[gb.get_group('buyer') for x in gb.groups]
# Out:
# [       img_id  img_idx                                           i_path    x  \
#  4     50a.jpg       24   /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5
#  9     51a.jpg       25   /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    4
#  14    52a.jpg       26   /home/scar3crow/Downloads/8-6-new-scan/52a.jpg    1
#  19    53a.jpg       27   /home/scar3crow/Downloads/8-6-new-scan/53a.jpg    0
#  24    54a.jpg       28   /home/scar3crow/Downloads/8-6-new-scan/54a.jpg   31
#  29    55a.jpg       29   /home/scar3crow/Downloads/8-6-new-scan/55a.jpg    1
#  34    56a.jpg       30   /home/scar3crow/Downloads/8-6-new-scan/56a.jpg    1
#  39    59a.jpg       31   /home/scar3crow/Downloads/8-6-new-scan/59a.jpg    3
#  44    60a.jpg       32   /home/scar3crow/Downloads/8-6-new-scan/60a.jpg    0
#  49    61a.jpg       33   /home/scar3crow/Downloads/8-6-new-scan/61a.jpg    1
#  54    62a.jpg       34   /home/scar3crow/Downloads/8-6-new-scan/62a.jpg    4
#  59    63a.jpg       35   /home/scar3crow/Downloads/8-6-new-scan/63a.jpg    2
#  64   101a.jpg        0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg    6
#  69   102a.jpg        1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg  431
#  74   103a.jpg        2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   12
#  79   104a.jpg        3  /home/scar3crow/Downloads/8-6-new-scan/104a.jpg   21
#  84   105a.jpg        4  /home/scar3crow/Downloads/8-6-new-scan/105a.jpg    4
#  88   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg  230
#  89   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg    1
#  94   107a.jpg        6  /home/scar3crow/Downloads/8-6-new-scan/107a.jpg    2
#  99   108a.jpg        7  /home/scar3crow/Downloads/8-6-new-scan/108a.jpg  219
#  104  109a.jpg        8  /home/scar3crow/Downloads/8-6-new-scan/109a.jpg  220
#  109  110a.jpg        9  /home/scar3crow/Downloads/8-6-new-scan/110a.jpg   22
#  114  111a.jpg       10  /home/scar3crow/Downloads/8-6-new-scan/111a.jpg    8
#  119  112a.jpg       11  /home/scar3crow/Downloads/8-6-new-scan/112a.jpg    2
#  124  113a.jpg       12  /home/scar3crow/Downloads/8-6-new-scan/113a.jpg    4
#  129  114a.jpg       13  /home/scar3crow/Downloads/8-6-new-scan/114a.jpg    6
#  134  115a.jpg       14  /home/scar3crow/Downloads/8-6-new-scan/115a.jpg    2
#  139  116a.jpg       15  /home/scar3crow/Downloads/8-6-new-scan/116a.jpg    4
#  144  117a.jpg       16  /home/scar3crow/Downloads/8-6-new-scan/117a.jpg    2
#  149  118a.jpg       17  /home/scar3crow/Downloads/8-6-new-scan/118a.jpg    1
#  154  119a.jpg       18  /home/scar3crow/Downloads/8-6-new-scan/119a.jpg    0
#  159  120a.jpg       19  /home/scar3crow/Downloads/8-6-new-scan/120a.jpg    1
#  163  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg  211
#  164  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg    1
#  169  122a.jpg       21  /home/scar3crow/Downloads/8-6-new-scan/122a.jpg   25
#  174  123a.jpg       22  /home/scar3crow/Downloads/8-6-new-scan/123a.jpg    1
#  179  124a.jpg       23  /home/scar3crow/Downloads/8-6-new-scan/124a.jpg    1
#
#         y  width  height obj_class  img_wd  img_ht
#  4     57    206      56     buyer     416     209
#  9     53    152      64     buyer     416     194
#  14    50    161      74     buyer     416     188
#  19    50    177      76     buyer     416     194
#  24   103    186      61     buyer     416     168
#  29    56    183      74     buyer     416     144
#  34    56    166      62     buyer     416     123
#  39    58    175      62     buyer     416     200
#  44    44    165      52     buyer     416     106
#  49    56    155      63     buyer     416     121
#  54    58    163      61     buyer     416     123
#  59    68    165      55     buyer     416     191
#  64    66    142      47     buyer     416     160
#  69   140    307     164     buyer     870     406
#  74   126    154      68     buyer     416     260
#  79   249    431     152     buyer     911     405
#  84    53    158      80     buyer     416     147
#  88    63     89      22     buyer     416     134
#  89    53    154      72     buyer     416     134
#  94    47    144      50     buyer     416     140
#  99   155    141      71     buyer     416     228
#  104  142    153      73     buyer     416     218
#  109  144    188      60     buyer     416     211
#  114   87    206      76     buyer     416     166
#  119   59    177      62     buyer     416     206
#  124  112    190      40     buyer     416     201
#  129   83    189      46     buyer     416     138
#  134   57    191      65     buyer     416     190
#  139   59    175      71     buyer     416     145
#  144   52    172      72     buyer     416     191
#  149   56    188      65     buyer     416     168
#  154   62    169      78     buyer     416     146
#  159   59    171      78     buyer     416     147
#  163   66     79      26     buyer     416     192
#  164   68    168      58     buyer     416     192
#  169   98    192      74     buyer     416     174
#  174   57    171      64     buyer     416     121
#  179  117    190      42     buyer     416     203  ,
#         img_id  img_idx                                           i_path    x  \
#  4     50a.jpg       24   /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5
#  9     51a.jpg       25   /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    4
#  14    52a.jpg       26   /home/scar3crow/Downloads/8-6-new-scan/52a.jpg    1
#  19    53a.jpg       27   /home/scar3crow/Downloads/8-6-new-scan/53a.jpg    0
#  24    54a.jpg       28   /home/scar3crow/Downloads/8-6-new-scan/54a.jpg   31
#  29    55a.jpg       29   /home/scar3crow/Downloads/8-6-new-scan/55a.jpg    1
#  34    56a.jpg       30   /home/scar3crow/Downloads/8-6-new-scan/56a.jpg    1
#  39    59a.jpg       31   /home/scar3crow/Downloads/8-6-new-scan/59a.jpg    3
#  44    60a.jpg       32   /home/scar3crow/Downloads/8-6-new-scan/60a.jpg    0
#  49    61a.jpg       33   /home/scar3crow/Downloads/8-6-new-scan/61a.jpg    1
#  54    62a.jpg       34   /home/scar3crow/Downloads/8-6-new-scan/62a.jpg    4
#  59    63a.jpg       35   /home/scar3crow/Downloads/8-6-new-scan/63a.jpg    2
#  64   101a.jpg        0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg    6
#  69   102a.jpg        1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg  431
#  74   103a.jpg        2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   12
#  79   104a.jpg        3  /home/scar3crow/Downloads/8-6-new-scan/104a.jpg   21
#  84   105a.jpg        4  /home/scar3crow/Downloads/8-6-new-scan/105a.jpg    4
#  88   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg  230
#  89   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg    1
#  94   107a.jpg        6  /home/scar3crow/Downloads/8-6-new-scan/107a.jpg    2
#  99   108a.jpg        7  /home/scar3crow/Downloads/8-6-new-scan/108a.jpg  219
#  104  109a.jpg        8  /home/scar3crow/Downloads/8-6-new-scan/109a.jpg  220
#  109  110a.jpg        9  /home/scar3crow/Downloads/8-6-new-scan/110a.jpg   22
#  114  111a.jpg       10  /home/scar3crow/Downloads/8-6-new-scan/111a.jpg    8
#  119  112a.jpg       11  /home/scar3crow/Downloads/8-6-new-scan/112a.jpg    2
#  124  113a.jpg       12  /home/scar3crow/Downloads/8-6-new-scan/113a.jpg    4
#  129  114a.jpg       13  /home/scar3crow/Downloads/8-6-new-scan/114a.jpg    6
#  134  115a.jpg       14  /home/scar3crow/Downloads/8-6-new-scan/115a.jpg    2
#  139  116a.jpg       15  /home/scar3crow/Downloads/8-6-new-scan/116a.jpg    4
#  144  117a.jpg       16  /home/scar3crow/Downloads/8-6-new-scan/117a.jpg    2
#  149  118a.jpg       17  /home/scar3crow/Downloads/8-6-new-scan/118a.jpg    1
#  154  119a.jpg       18  /home/scar3crow/Downloads/8-6-new-scan/119a.jpg    0
#  159  120a.jpg       19  /home/scar3crow/Downloads/8-6-new-scan/120a.jpg    1
#  163  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg  211
#  164  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg    1
#  169  122a.jpg       21  /home/scar3crow/Downloads/8-6-new-scan/122a.jpg   25
#  174  123a.jpg       22  /home/scar3crow/Downloads/8-6-new-scan/123a.jpg    1
#  179  124a.jpg       23  /home/scar3crow/Downloads/8-6-new-scan/124a.jpg    1
#
#         y  width  height obj_class  img_wd  img_ht
#  4     57    206      56     buyer     416     209
#  9     53    152      64     buyer     416     194
#  14    50    161      74     buyer     416     188
#  19    50    177      76     buyer     416     194
#  24   103    186      61     buyer     416     168
#  29    56    183      74     buyer     416     144
#  34    56    166      62     buyer     416     123
#  39    58    175      62     buyer     416     200
#  44    44    165      52     buyer     416     106
#  49    56    155      63     buyer     416     121
#  54    58    163      61     buyer     416     123
#  59    68    165      55     buyer     416     191
#  64    66    142      47     buyer     416     160
#  69   140    307     164     buyer     870     406
#  74   126    154      68     buyer     416     260
#  79   249    431     152     buyer     911     405
#  84    53    158      80     buyer     416     147
#  88    63     89      22     buyer     416     134
#  89    53    154      72     buyer     416     134
#  94    47    144      50     buyer     416     140
#  99   155    141      71     buyer     416     228
#  104  142    153      73     buyer     416     218
#  109  144    188      60     buyer     416     211
#  114   87    206      76     buyer     416     166
#  119   59    177      62     buyer     416     206
#  124  112    190      40     buyer     416     201
#  129   83    189      46     buyer     416     138
#  134   57    191      65     buyer     416     190
#  139   59    175      71     buyer     416     145
#  144   52    172      72     buyer     416     191
#  149   56    188      65     buyer     416     168
#  154   62    169      78     buyer     416     146
#  159   59    171      78     buyer     416     147
#  163   66     79      26     buyer     416     192
#  164   68    168      58     buyer     416     192
#  169   98    192      74     buyer     416     174
#  174   57    171      64     buyer     416     121
#  179  117    190      42     buyer     416     203  ,
#         img_id  img_idx                                           i_path    x  \
#  4     50a.jpg       24   /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5
#  9     51a.jpg       25   /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    4
#  14    52a.jpg       26   /home/scar3crow/Downloads/8-6-new-scan/52a.jpg    1
#  19    53a.jpg       27   /home/scar3crow/Downloads/8-6-new-scan/53a.jpg    0
#  24    54a.jpg       28   /home/scar3crow/Downloads/8-6-new-scan/54a.jpg   31
#  29    55a.jpg       29   /home/scar3crow/Downloads/8-6-new-scan/55a.jpg    1
#  34    56a.jpg       30   /home/scar3crow/Downloads/8-6-new-scan/56a.jpg    1
#  39    59a.jpg       31   /home/scar3crow/Downloads/8-6-new-scan/59a.jpg    3
#  44    60a.jpg       32   /home/scar3crow/Downloads/8-6-new-scan/60a.jpg    0
#  49    61a.jpg       33   /home/scar3crow/Downloads/8-6-new-scan/61a.jpg    1
#  54    62a.jpg       34   /home/scar3crow/Downloads/8-6-new-scan/62a.jpg    4
#  59    63a.jpg       35   /home/scar3crow/Downloads/8-6-new-scan/63a.jpg    2
#  64   101a.jpg        0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg    6
#  69   102a.jpg        1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg  431
#  74   103a.jpg        2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   12
#  79   104a.jpg        3  /home/scar3crow/Downloads/8-6-new-scan/104a.jpg   21
#  84   105a.jpg        4  /home/scar3crow/Downloads/8-6-new-scan/105a.jpg    4
#  88   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg  230
#  89   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg    1
#  94   107a.jpg        6  /home/scar3crow/Downloads/8-6-new-scan/107a.jpg    2
#  99   108a.jpg        7  /home/scar3crow/Downloads/8-6-new-scan/108a.jpg  219
#  104  109a.jpg        8  /home/scar3crow/Downloads/8-6-new-scan/109a.jpg  220
#  109  110a.jpg        9  /home/scar3crow/Downloads/8-6-new-scan/110a.jpg   22
#  114  111a.jpg       10  /home/scar3crow/Downloads/8-6-new-scan/111a.jpg    8
#  119  112a.jpg       11  /home/scar3crow/Downloads/8-6-new-scan/112a.jpg    2
#  124  113a.jpg       12  /home/scar3crow/Downloads/8-6-new-scan/113a.jpg    4
#  129  114a.jpg       13  /home/scar3crow/Downloads/8-6-new-scan/114a.jpg    6
#  134  115a.jpg       14  /home/scar3crow/Downloads/8-6-new-scan/115a.jpg    2
#  139  116a.jpg       15  /home/scar3crow/Downloads/8-6-new-scan/116a.jpg    4
#  144  117a.jpg       16  /home/scar3crow/Downloads/8-6-new-scan/117a.jpg    2
#  149  118a.jpg       17  /home/scar3crow/Downloads/8-6-new-scan/118a.jpg    1
#  154  119a.jpg       18  /home/scar3crow/Downloads/8-6-new-scan/119a.jpg    0
#  159  120a.jpg       19  /home/scar3crow/Downloads/8-6-new-scan/120a.jpg    1
#  163  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg  211
#  164  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg    1
#  169  122a.jpg       21  /home/scar3crow/Downloads/8-6-new-scan/122a.jpg   25
#  174  123a.jpg       22  /home/scar3crow/Downloads/8-6-new-scan/123a.jpg    1
#  179  124a.jpg       23  /home/scar3crow/Downloads/8-6-new-scan/124a.jpg    1
#
#         y  width  height obj_class  img_wd  img_ht
#  4     57    206      56     buyer     416     209
#  9     53    152      64     buyer     416     194
#  14    50    161      74     buyer     416     188
#  19    50    177      76     buyer     416     194
#  24   103    186      61     buyer     416     168
#  29    56    183      74     buyer     416     144
#  34    56    166      62     buyer     416     123
#  39    58    175      62     buyer     416     200
#  44    44    165      52     buyer     416     106
#  49    56    155      63     buyer     416     121
#  54    58    163      61     buyer     416     123
#  59    68    165      55     buyer     416     191
#  64    66    142      47     buyer     416     160
#  69   140    307     164     buyer     870     406
#  74   126    154      68     buyer     416     260
#  79   249    431     152     buyer     911     405
#  84    53    158      80     buyer     416     147
#  88    63     89      22     buyer     416     134
#  89    53    154      72     buyer     416     134
#  94    47    144      50     buyer     416     140
#  99   155    141      71     buyer     416     228
#  104  142    153      73     buyer     416     218
#  109  144    188      60     buyer     416     211
#  114   87    206      76     buyer     416     166
#  119   59    177      62     buyer     416     206
#  124  112    190      40     buyer     416     201
#  129   83    189      46     buyer     416     138
#  134   57    191      65     buyer     416     190
#  139   59    175      71     buyer     416     145
#  144   52    172      72     buyer     416     191
#  149   56    188      65     buyer     416     168
#  154   62    169      78     buyer     416     146
#  159   59    171      78     buyer     416     147
#  163   66     79      26     buyer     416     192
#  164   68    168      58     buyer     416     192
#  169   98    192      74     buyer     416     174
#  174   57    171      64     buyer     416     121
#  179  117    190      42     buyer     416     203  ,
#         img_id  img_idx                                           i_path    x  \
#  4     50a.jpg       24   /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5
#  9     51a.jpg       25   /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    4
#  14    52a.jpg       26   /home/scar3crow/Downloads/8-6-new-scan/52a.jpg    1
#  19    53a.jpg       27   /home/scar3crow/Downloads/8-6-new-scan/53a.jpg    0
#  24    54a.jpg       28   /home/scar3crow/Downloads/8-6-new-scan/54a.jpg   31
#  29    55a.jpg       29   /home/scar3crow/Downloads/8-6-new-scan/55a.jpg    1
#  34    56a.jpg       30   /home/scar3crow/Downloads/8-6-new-scan/56a.jpg    1
#  39    59a.jpg       31   /home/scar3crow/Downloads/8-6-new-scan/59a.jpg    3
#  44    60a.jpg       32   /home/scar3crow/Downloads/8-6-new-scan/60a.jpg    0
#  49    61a.jpg       33   /home/scar3crow/Downloads/8-6-new-scan/61a.jpg    1
#  54    62a.jpg       34   /home/scar3crow/Downloads/8-6-new-scan/62a.jpg    4
#  59    63a.jpg       35   /home/scar3crow/Downloads/8-6-new-scan/63a.jpg    2
#  64   101a.jpg        0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg    6
#  69   102a.jpg        1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg  431
#  74   103a.jpg        2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   12
#  79   104a.jpg        3  /home/scar3crow/Downloads/8-6-new-scan/104a.jpg   21
#  84   105a.jpg        4  /home/scar3crow/Downloads/8-6-new-scan/105a.jpg    4
#  88   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg  230
#  89   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg    1
#  94   107a.jpg        6  /home/scar3crow/Downloads/8-6-new-scan/107a.jpg    2
#  99   108a.jpg        7  /home/scar3crow/Downloads/8-6-new-scan/108a.jpg  219
#  104  109a.jpg        8  /home/scar3crow/Downloads/8-6-new-scan/109a.jpg  220
#  109  110a.jpg        9  /home/scar3crow/Downloads/8-6-new-scan/110a.jpg   22
#  114  111a.jpg       10  /home/scar3crow/Downloads/8-6-new-scan/111a.jpg    8
#  119  112a.jpg       11  /home/scar3crow/Downloads/8-6-new-scan/112a.jpg    2
#  124  113a.jpg       12  /home/scar3crow/Downloads/8-6-new-scan/113a.jpg    4
#  129  114a.jpg       13  /home/scar3crow/Downloads/8-6-new-scan/114a.jpg    6
#  134  115a.jpg       14  /home/scar3crow/Downloads/8-6-new-scan/115a.jpg    2
#  139  116a.jpg       15  /home/scar3crow/Downloads/8-6-new-scan/116a.jpg    4
#  144  117a.jpg       16  /home/scar3crow/Downloads/8-6-new-scan/117a.jpg    2
#  149  118a.jpg       17  /home/scar3crow/Downloads/8-6-new-scan/118a.jpg    1
#  154  119a.jpg       18  /home/scar3crow/Downloads/8-6-new-scan/119a.jpg    0
#  159  120a.jpg       19  /home/scar3crow/Downloads/8-6-new-scan/120a.jpg    1
#  163  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg  211
#  164  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg    1
#  169  122a.jpg       21  /home/scar3crow/Downloads/8-6-new-scan/122a.jpg   25
#  174  123a.jpg       22  /home/scar3crow/Downloads/8-6-new-scan/123a.jpg    1
#  179  124a.jpg       23  /home/scar3crow/Downloads/8-6-new-scan/124a.jpg    1
#
#         y  width  height obj_class  img_wd  img_ht
#  4     57    206      56     buyer     416     209
#  9     53    152      64     buyer     416     194
#  14    50    161      74     buyer     416     188
#  19    50    177      76     buyer     416     194
#  24   103    186      61     buyer     416     168
#  29    56    183      74     buyer     416     144
#  34    56    166      62     buyer     416     123
#  39    58    175      62     buyer     416     200
#  44    44    165      52     buyer     416     106
#  49    56    155      63     buyer     416     121
#  54    58    163      61     buyer     416     123
#  59    68    165      55     buyer     416     191
#  64    66    142      47     buyer     416     160
#  69   140    307     164     buyer     870     406
#  74   126    154      68     buyer     416     260
#  79   249    431     152     buyer     911     405
#  84    53    158      80     buyer     416     147
#  88    63     89      22     buyer     416     134
#  89    53    154      72     buyer     416     134
#  94    47    144      50     buyer     416     140
#  99   155    141      71     buyer     416     228
#  104  142    153      73     buyer     416     218
#  109  144    188      60     buyer     416     211
#  114   87    206      76     buyer     416     166
#  119   59    177      62     buyer     416     206
#  124  112    190      40     buyer     416     201
#  129   83    189      46     buyer     416     138
#  134   57    191      65     buyer     416     190
#  139   59    175      71     buyer     416     145
#  144   52    172      72     buyer     416     191
#  149   56    188      65     buyer     416     168
#  154   62    169      78     buyer     416     146
#  159   59    171      78     buyer     416     147
#  163   66     79      26     buyer     416     192
#  164   68    168      58     buyer     416     192
#  169   98    192      74     buyer     416     174
#  174   57    171      64     buyer     416     121
#  179  117    190      42     buyer     416     203  ,
#         img_id  img_idx                                           i_path    x  \
#  4     50a.jpg       24   /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5
#  9     51a.jpg       25   /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    4
#  14    52a.jpg       26   /home/scar3crow/Downloads/8-6-new-scan/52a.jpg    1
#  19    53a.jpg       27   /home/scar3crow/Downloads/8-6-new-scan/53a.jpg    0
#  24    54a.jpg       28   /home/scar3crow/Downloads/8-6-new-scan/54a.jpg   31
#  29    55a.jpg       29   /home/scar3crow/Downloads/8-6-new-scan/55a.jpg    1
#  34    56a.jpg       30   /home/scar3crow/Downloads/8-6-new-scan/56a.jpg    1
#  39    59a.jpg       31   /home/scar3crow/Downloads/8-6-new-scan/59a.jpg    3
#  44    60a.jpg       32   /home/scar3crow/Downloads/8-6-new-scan/60a.jpg    0
#  49    61a.jpg       33   /home/scar3crow/Downloads/8-6-new-scan/61a.jpg    1
#  54    62a.jpg       34   /home/scar3crow/Downloads/8-6-new-scan/62a.jpg    4
#  59    63a.jpg       35   /home/scar3crow/Downloads/8-6-new-scan/63a.jpg    2
#  64   101a.jpg        0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg    6
#  69   102a.jpg        1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg  431
#  74   103a.jpg        2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   12
#  79   104a.jpg        3  /home/scar3crow/Downloads/8-6-new-scan/104a.jpg   21
#  84   105a.jpg        4  /home/scar3crow/Downloads/8-6-new-scan/105a.jpg    4
#  88   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg  230
#  89   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg    1
#  94   107a.jpg        6  /home/scar3crow/Downloads/8-6-new-scan/107a.jpg    2
#  99   108a.jpg        7  /home/scar3crow/Downloads/8-6-new-scan/108a.jpg  219
#  104  109a.jpg        8  /home/scar3crow/Downloads/8-6-new-scan/109a.jpg  220
#  109  110a.jpg        9  /home/scar3crow/Downloads/8-6-new-scan/110a.jpg   22
#  114  111a.jpg       10  /home/scar3crow/Downloads/8-6-new-scan/111a.jpg    8
#  119  112a.jpg       11  /home/scar3crow/Downloads/8-6-new-scan/112a.jpg    2
#  124  113a.jpg       12  /home/scar3crow/Downloads/8-6-new-scan/113a.jpg    4
#  129  114a.jpg       13  /home/scar3crow/Downloads/8-6-new-scan/114a.jpg    6
#  134  115a.jpg       14  /home/scar3crow/Downloads/8-6-new-scan/115a.jpg    2
#  139  116a.jpg       15  /home/scar3crow/Downloads/8-6-new-scan/116a.jpg    4
#  144  117a.jpg       16  /home/scar3crow/Downloads/8-6-new-scan/117a.jpg    2
#  149  118a.jpg       17  /home/scar3crow/Downloads/8-6-new-scan/118a.jpg    1
#  154  119a.jpg       18  /home/scar3crow/Downloads/8-6-new-scan/119a.jpg    0
#  159  120a.jpg       19  /home/scar3crow/Downloads/8-6-new-scan/120a.jpg    1
#  163  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg  211
#  164  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg    1
#  169  122a.jpg       21  /home/scar3crow/Downloads/8-6-new-scan/122a.jpg   25
#  174  123a.jpg       22  /home/scar3crow/Downloads/8-6-new-scan/123a.jpg    1
#  179  124a.jpg       23  /home/scar3crow/Downloads/8-6-new-scan/124a.jpg    1
#
#         y  width  height obj_class  img_wd  img_ht
#  4     57    206      56     buyer     416     209
#  9     53    152      64     buyer     416     194
#  14    50    161      74     buyer     416     188
#  19    50    177      76     buyer     416     194
#  24   103    186      61     buyer     416     168
#  29    56    183      74     buyer     416     144
#  34    56    166      62     buyer     416     123
#  39    58    175      62     buyer     416     200
#  44    44    165      52     buyer     416     106
#  49    56    155      63     buyer     416     121
#  54    58    163      61     buyer     416     123
#  59    68    165      55     buyer     416     191
#  64    66    142      47     buyer     416     160
#  69   140    307     164     buyer     870     406
#  74   126    154      68     buyer     416     260
#  79   249    431     152     buyer     911     405
#  84    53    158      80     buyer     416     147
#  88    63     89      22     buyer     416     134
#  89    53    154      72     buyer     416     134
#  94    47    144      50     buyer     416     140
#  99   155    141      71     buyer     416     228
#  104  142    153      73     buyer     416     218
#  109  144    188      60     buyer     416     211
#  114   87    206      76     buyer     416     166
#  119   59    177      62     buyer     416     206
#  124  112    190      40     buyer     416     201
#  129   83    189      46     buyer     416     138
#  134   57    191      65     buyer     416     190
#  139   59    175      71     buyer     416     145
#  144   52    172      72     buyer     416     191
#  149   56    188      65     buyer     416     168
#  154   62    169      78     buyer     416     146
#  159   59    171      78     buyer     416     147
#  163   66     79      26     buyer     416     192
#  164   68    168      58     buyer     416     192
#  169   98    192      74     buyer     416     174
#  174   57    171      64     buyer     416     121
#  179  117    190      42     buyer     416     203  ,
#         img_id  img_idx                                           i_path    x  \
#  4     50a.jpg       24   /home/scar3crow/Downloads/8-6-new-scan/50a.jpg    5
#  9     51a.jpg       25   /home/scar3crow/Downloads/8-6-new-scan/51a.jpg    4
#  14    52a.jpg       26   /home/scar3crow/Downloads/8-6-new-scan/52a.jpg    1
#  19    53a.jpg       27   /home/scar3crow/Downloads/8-6-new-scan/53a.jpg    0
#  24    54a.jpg       28   /home/scar3crow/Downloads/8-6-new-scan/54a.jpg   31
#  29    55a.jpg       29   /home/scar3crow/Downloads/8-6-new-scan/55a.jpg    1
#  34    56a.jpg       30   /home/scar3crow/Downloads/8-6-new-scan/56a.jpg    1
#  39    59a.jpg       31   /home/scar3crow/Downloads/8-6-new-scan/59a.jpg    3
#  44    60a.jpg       32   /home/scar3crow/Downloads/8-6-new-scan/60a.jpg    0
#  49    61a.jpg       33   /home/scar3crow/Downloads/8-6-new-scan/61a.jpg    1
#  54    62a.jpg       34   /home/scar3crow/Downloads/8-6-new-scan/62a.jpg    4
#  59    63a.jpg       35   /home/scar3crow/Downloads/8-6-new-scan/63a.jpg    2
#  64   101a.jpg        0  /home/scar3crow/Downloads/8-6-new-scan/101a.jpg    6
#  69   102a.jpg        1  /home/scar3crow/Downloads/8-6-new-scan/102a.jpg  431
#  74   103a.jpg        2  /home/scar3crow/Downloads/8-6-new-scan/103a.jpg   12
#  79   104a.jpg        3  /home/scar3crow/Downloads/8-6-new-scan/104a.jpg   21
#  84   105a.jpg        4  /home/scar3crow/Downloads/8-6-new-scan/105a.jpg    4
#  88   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg  230
#  89   106a.jpg        5  /home/scar3crow/Downloads/8-6-new-scan/106a.jpg    1
#  94   107a.jpg        6  /home/scar3crow/Downloads/8-6-new-scan/107a.jpg    2
#  99   108a.jpg        7  /home/scar3crow/Downloads/8-6-new-scan/108a.jpg  219
#  104  109a.jpg        8  /home/scar3crow/Downloads/8-6-new-scan/109a.jpg  220
#  109  110a.jpg        9  /home/scar3crow/Downloads/8-6-new-scan/110a.jpg   22
#  114  111a.jpg       10  /home/scar3crow/Downloads/8-6-new-scan/111a.jpg    8
#  119  112a.jpg       11  /home/scar3crow/Downloads/8-6-new-scan/112a.jpg    2
#  124  113a.jpg       12  /home/scar3crow/Downloads/8-6-new-scan/113a.jpg    4
#  129  114a.jpg       13  /home/scar3crow/Downloads/8-6-new-scan/114a.jpg    6
#  134  115a.jpg       14  /home/scar3crow/Downloads/8-6-new-scan/115a.jpg    2
#  139  116a.jpg       15  /home/scar3crow/Downloads/8-6-new-scan/116a.jpg    4
#  144  117a.jpg       16  /home/scar3crow/Downloads/8-6-new-scan/117a.jpg    2
#  149  118a.jpg       17  /home/scar3crow/Downloads/8-6-new-scan/118a.jpg    1
#  154  119a.jpg       18  /home/scar3crow/Downloads/8-6-new-scan/119a.jpg    0
#  159  120a.jpg       19  /home/scar3crow/Downloads/8-6-new-scan/120a.jpg    1
#  163  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg  211
#  164  121a.jpg       20  /home/scar3crow/Downloads/8-6-new-scan/121a.jpg    1
#  169  122a.jpg       21  /home/scar3crow/Downloads/8-6-new-scan/122a.jpg   25
#  174  123a.jpg       22  /home/scar3crow/Downloads/8-6-new-scan/123a.jpg    1
#  179  124a.jpg       23  /home/scar3crow/Downloads/8-6-new-scan/124a.jpg    1
#
#         y  width  height obj_class  img_wd  img_ht
#  4     57    206      56     buyer     416     209
#  9     53    152      64     buyer     416     194
#  14    50    161      74     buyer     416     188
#  19    50    177      76     buyer     416     194
#  24   103    186      61     buyer     416     168
#  29    56    183      74     buyer     416     144
#  34    56    166      62     buyer     416     123
#  39    58    175      62     buyer     416     200
#  44    44    165      52     buyer     416     106
#  49    56    155      63     buyer     416     121
#  54    58    163      61     buyer     416     123
#  59    68    165      55     buyer     416     191
#  64    66    142      47     buyer     416     160
#  69   140    307     164     buyer     870     406
#  74   126    154      68     buyer     416     260
#  79   249    431     152     buyer     911     405
#  84    53    158      80     buyer     416     147
#  88    63     89      22     buyer     416     134
#  89    53    154      72     buyer     416     134
#  94    47    144      50     buyer     416     140
#  99   155    141      71     buyer     416     228
#  104  142    153      73     buyer     416     218
#  109  144    188      60     buyer     416     211
#  114   87    206      76     buyer     416     166
#  119   59    177      62     buyer     416     206
#  124  112    190      40     buyer     416     201
#  129   83    189      46     buyer     416     138
#  134   57    191      65     buyer     416     190
#  139   59    175      71     buyer     416     145
#  144   52    172      72     buyer     416     191
#  149   56    188      65     buyer     416     168
#  154   62    169      78     buyer     416     146
#  159   59    171      78     buyer     416     147
#  163   66     79      26     buyer     416     192
#  164   68    168      58     buyer     416     192
#  169   98    192      74     buyer     416     174
#  174   57    171      64     buyer     416     121
#  179  117    190      42     buyer     416     203  ]

# %%
# Correcting above wrong spelling & converting buyer to po of object classes and rechecking

id_1 = r_new_data.index[r_new_data['obj_class'] == 'order'] # Finding the index
id_2 = r_new_data.index[r_new_data['obj_class'] == 'date'] # to change 'date' to 'inv_date' to be consistent with old data

r_new_data.at[id_1, 'obj_class'] = 'po' # writing the correct spelling 
r_new_data.at[88, 'obj_class'] = 'po' # # 'buyer' to 'po'
r_new_data.at[163, 'obj_class'] = 'po' # # 'buyer' to 'po'
r_new_data.at[id_2, 'obj_class'] = 'inv_date' # # 'date' to 'inv_date'

print('Number of unique images = ', r_new_data['img_id'].nunique())  # print total no, of unique images
print('Number of unique classes = ', r_new_data['obj_class'].nunique())
print('Number of classes in diff. categories = ', r_new_data['obj_class'].value_counts())

# r_new_data.drop(r_new_data.columns[[0]], axis=1, inplace=True) # reduce unnecessary columns
# Out:
# Number of unique images =  36
# Number of unique classes =  5
# Number of classes in diff. categories =  invoice     36
# buyer       36
# inv_date    36
# vendor      36
# po          36
# Name: obj_class, dtype: int64

# %%
## For each image, we have to find : (a) line_index = integer, (b) img_path = string, (c) boxes = shape [N, 4], 
## N is the ground truth count, elements in the second dimension are [x_min, y_min, x_max, y_max] (d) labels = shape
## [N]. class index. (e) img_width = int.  =f) img_height = int

def single_image_info(lines):
    
    ## lines will be a dataframe like, for i in range(num_images), lines = r_new_data[i*5:(i+1)*5]
    
    line_idx = lines.iat[0, 1]
    pic_path = lines.iat[0, 2]
    img_width = lines.iat[0, 8]
    img_height = lines.iat[0, 9]
    
    boxes = []
    labels = []
    for i in range(len(lines)):
        label, x_min, y_min, x_max, y_max = int(i), float(lines.iat[i,3]), float(lines.iat[i,4]), float(lines.iat[i,3]+lines.iat[i,5]), float(lines.iat[i,4]+lines.iat[i,6])
        boxes.append([x_min, y_min, x_max, y_max])
        labels.append(label)
        
    boxes = np.asarray(boxes, np.float32)
    labels = np.asarray(labels, np.int64)
    
    return line_idx, pic_path, boxes, labels, img_width, img_height  ## boxes are in format xmin, ymin, xmax, ymax

# %%
## Creating the complete data set :

all_image_line = []
for i in range(num_images):
    image_line = []
    limit_lower = i*5
    limit_upper = limit_lower+5
    lines = r_new_data[limit_lower:limit_upper]
    line_idx, pic_path, boxes, labels, img_width, img_height = single_image_info(lines)
    image_line.append(line_idx)
    image_line.append(pic_path)
    image_line.append(boxes)
    image_line.append(labels)
    image_line.append(img_width)
    image_line.append(img_height)
    all_image_line.append(image_line)
    
print(len(all_image_line))
print(all_image_line[1])   ##  boxes are in format xmin, ymin, xmax, ymax
# Out:
# 36
# [25, '/home/scar3crow/Downloads/8-6-new-scan/51a.jpg', array([[  5.,   0., 125.,  56.],
#        [239.,   1., 279.,  20.],
#        [328.,   1., 382.,  21.],
#        [238.,  51., 302.,  74.],
#        [  4.,  53., 156., 117.]], dtype=float32), array([0, 1, 2, 3, 4]), 416, 194]

# %%
# Train and Test split

data_train, data_val = train_test_split(all_image_line, train_size = 0.8 , shuffle = True)

num_all_bbox = len(all_image_line) * len(all_image_line[0][2])
num_bb_train = len(data_train) * len(data_train[0][2])
num_bb_val = len(data_val) * len(data_val[0][2])
print(num_all_bbox, num_bb_train, num_bb_val)
# Out:
# 180 140 40
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
## calculating anchors from true boundary boxes :

def iou_kmeans(box, clusters):
    """
    Calculates the Intersection over Union (IoU) between a box and k clusters.
    :param box: tuple or array, shifted to the origin (i. e. width and height)
    :param clusters: numpy array of shape (k, 2) where k is the number of clusters
    :return: numpy array of shape (k, 0) where k is the number of clusters
    """
    x = np.minimum(clusters[:, 0], box[0])
    y = np.minimum(clusters[:, 1], box[1])
    if np.count_nonzero(x == 0) > 0 or np.count_nonzero(y == 0) > 0:
        raise ValueError("Box has no area")

    intersection = x * y
    box_area = box[0] * box[1]
    cluster_area = clusters[:, 0] * clusters[:, 1]

    iou = intersection / (box_area + cluster_area - intersection)

    return iou

def kmeans(boxes, k, dist=np.median):
    """
    Calculates k-means clustering with the Intersection over Union (IoU) metric.
    :param boxes: numpy array of shape (r, 2), where r is the number of rows
    :param k: number of clusters
    :param dist: distance function
    :return: numpy array of shape (k, 2)
    """
    rows = boxes.shape[0]

    distances = np.empty((rows, k))
    last_clusters = np.zeros((rows,))

    np.random.seed()

    # the Forgy method will fail if the whole array contains the same rows
    clusters = boxes[np.random.choice(rows, k, replace=False)]


    while True:
        for row in range(rows):
            distances[row] = 1 - iou_kmeans(boxes[row], clusters)

        nearest_clusters = np.argmin(distances, axis=1)

        if (last_clusters == nearest_clusters).all():
            break

        for cluster in range(k):
            clusters[cluster] = dist(boxes[nearest_clusters == cluster], axis=0)

        last_clusters = nearest_clusters

    return clusters

# %%
## Finding out anchors :
## Firstly, converting true boundary box width, height to width & height with respect to target image :
## finaly find anchors. Anchors here are in absolute size w.r.t. target image but not as % of target image or 
## as multiple of unit grids.

# num_all_bb = len(r_new_data) # if no. of bboxes varies for images, this formula should be used 

anchors_wrt_target = np.zeros((3,2))

num_all_bb = len(all_image_line) * len(all_image_line[0][2])  ## from all image line data

b_box_wrt_target = np.zeros((num_all_bb,2))

for i in range(num_all_bb):
    
    image_w = r_new_data['img_wd'][i]
    image_h = r_new_data['img_ht'][i]

    x_ratio = target_w / image_w 
    y_ratio = target_h / image_h
    
    anchor_w = r_new_data['width'][i] * x_ratio
    anchor_h = r_new_data['height'][i] * y_ratio
    b_box_wrt_target[i, 0] = anchor_w
    b_box_wrt_target[i, 1] = anchor_h
    
anchors_wrt_target = kmeans(b_box_wrt_target, num_anchors)

print(anchors_wrt_target.shape)
print(anchors_wrt_target)     ## anchors wrt target image in abs. value and in format width, height
# Out:
# (3, 2)
# [[189.80769231 160.36697248]
#  [129.23076923  37.92592593]
#  [ 68.07692308  65.30612245]]

# %%
## Pre-processing the original data to get y_true :

def process_box(ori_boxes, ori_img_width, ori_img_height, labels, target_size, class_num, anchors):
    '''
    Generate the y_true label, i.e. the ground truth feature_map.
    params:
        boxes: [N, 5] shape, float32 dtype. `x_min, y_min, x_max, y_mix, mixup_weight`.
        labels: [N] shape, int64 dtype.
        class_num: int64 num.
        anchors: [3,2] shape, float32 dtype.
    '''
    
    img_width = ori_img_width
    img_height = ori_img_height
    boxes = ori_boxes           ## boxes in format xmin, ymin, xmax, ymax
    
    x_ratio = target_size[1] / img_width
    y_ratio = target_size[0] / img_height
    
    boxes_wrt_target = np.zeros((5,4))
    box_centers_target = np.zeros((5,2))

    boxes_wrt_target[:,0] = boxes[:,0] * x_ratio  # xmin absolute value wrt target image
    boxes_wrt_target[:,1] = boxes[:,1] * y_ratio  # ymin absolute value wrt target image
    boxes_wrt_target[:,2] = boxes[:,2] * x_ratio  # xmax absolute value wrt target image
    boxes_wrt_target[:,3] = boxes[:,3] * y_ratio  # ymax absolute value wrt target image
    
    # In above, boxes_wrt_target shape is (5, 4), now this will be taken to (5. 5) by adding 1 at end
#    boxes_wrt_target = np.concatenate((boxes_wrt_target, np.full(shape=(boxes_wrt_target.shape[0], 1), fill_value=1., dtype=np.float32)), axis=-1)
    box_centers_target = (boxes_wrt_target[:, 0:2] + boxes_wrt_target[:, 2:4]) / 2  ## centers wrt target, abs values
    
    box_sizes = boxes[:, 2:4] - boxes[:, 0:2]  #xmax-xmin = width and ymax-ymin = height wrt original image
    box_sizes[:,0] = box_sizes[:,0] * x_ratio  # width w.r.t target image in absolute value
    box_sizes[:,1] = box_sizes[:,1] * y_ratio  # width w.r.t target image in absolute value
    
#    y_true_13 = np.zeros((target_size[1] // 32, target_size[0] // 32, 3, 6 + class_num), np.float32)
    y_true_13 = np.zeros((target_size[1] // 32, target_size[0] // 32, 3, 5 + class_num), np.float32)

#    y_true = [y_true_13]
    
    box_sizes = np.expand_dims(box_sizes, 1)
    mins = np.maximum(- box_sizes / 2, - anchors / 2)
    maxs = np.minimum(box_sizes / 2, anchors / 2)
    whs = maxs - mins

    iou = (whs[:, :, 0] * whs[:, :, 1]) / (
                box_sizes[:, :, 0] * box_sizes[:, :, 1] + anchors[:, 0] * anchors[:, 1] - whs[:, :, 0] * whs[:, :,
                                                                                                         1] + 1e-10)
    best_match_idx = np.argmax(iou, axis=1)

    anchor_mask = np.zeros((target_size[1] // 32, target_size[0] // 32, 3))

    cell_size = 32  ## = targetsize / no. of grid cells
    
    for i, idx in enumerate(best_match_idx):

        x = int(np.floor(box_centers_target[i, 0] / cell_size))
        y = int(np.floor(box_centers_target[i, 1] / cell_size))
        k = int(idx)
        c = int(labels[i])

#        print(x, y, k, c)

# Very Imp : Now preparing y_true: all values x_center, y_cemter, width & height are being taken to % of target image
        
        y_true_13[y, x, k, :2] = box_centers_target[i] / target_size[0] #since target_size[0] = target_size[1]
        y_true_13[y, x, k, 2:4] = box_sizes[i] / target_size[0]
        y_true_13[y, x, k, 4] = 1.
        y_true_13[y, x, k, 5 + c] = 1.
#        y_true[0][y, x, k, -1] = boxes_wrt_target[i, -1]
        anchor_mask[y, x, k] = 1

    return y_true_13, anchor_mask  ## all data are w.r.to target image in % of target image and NOT w,r,t, grid cells

# %%
## Single image-wise image/boundary box preprocessing:

def parse_data(line, class_num, target_size, anchors):   ## (mode, letterbox_resize):
    '''
    param:
        line: a line from the training/test txt file
        class_num: totol class nums.
        target_size: the size of image to be resized to. [width, height] format.
        anchors: anchors.
        mode: 'train' or 'val'. When set to 'train', data_augmentation will be applied.
        letterbox_resize: whether to use the letterbox resize, i.e., keep the original aspect ratio in the resized image.
    '''
    
    img_idx, pic_path, boxes, labels,img_width, img_height = line  # boxes in format xmin, ymin, xmax, ymax
    img = cv2.imread(pic_path)
    img_resized = cv2.resize(img,(target_size[0], target_size[1]))
    
    # expand the 2nd dimension, mix up weight default to 1.
    boxes = np.concatenate((boxes, np.full(shape=(boxes.shape[0], 1), fill_value=1., dtype=np.float32)), axis=-1)

    img_resized = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB).astype(np.float32)

    # the input of yolo_v3 should be in range 0~1, lets change to -0.5 to +0.5
    img_resized = (img_resized - 127.5)/ 255.

    y_true_13, anchor_mask = process_box(boxes, img_width, img_height, labels, target_size, class_num, anchors)

    return img_idx, img_resized, y_true_13, anchor_mask

# %%
## Making the data ready for entering into network :

anchors = anchors_wrt_target
image_index = []
image_resized = []
image_y_true = []
image_anchor_mask = []

for i in range(len(data_train)):

    line = data_train[i]
    
    img_idx, img_resized, y_true, anchor_mask = parse_data(line, class_num, target_size, anchors)
    
    
    image_index.append(img_idx)
    image_resized.append(img_resized)
    image_y_true.append(y_true)
    image_anchor_mask.append(anchor_mask)
    
train_image_index = image_index
X_train = np.array(image_resized)
Y_train = np.array(image_y_true)
train_anchor_mask = np.array(image_anchor_mask)

image_index = []
image_resized = []
image_y_true = []
image_anchor_mask = []

for i in range(len(data_val)):
    line = data_val[i]
    
    img_idx, img_resized, y_true, anchor_mask = parse_data(line, class_num, target_size, anchors)
    image_index.append(img_idx)
    image_resized.append(img_resized)
    image_y_true.append(y_true)
    image_anchor_mask.append(anchor_mask)
val_image_index = image_index
X_val = np.array(image_resized)
Y_val = np.array(image_y_true)
val_anchor_mask = np.array(image_anchor_mask)

image_index = []
image_resized = []
image_y_true = []

# %%
print(len(X_train), len(Y_train), len(train_image_index), len(X_val), len(Y_val), len(val_image_index))
print(train_image_index)
print(X_train.shape, Y_train.shape)
print(train_image_index[0], X_train[0].shape, Y_train[0].shape)
print(train_anchor_mask.shape, 'and', train_anchor_mask[0].shape)
# Out:
# 28 28 28 8 8 8
# [11, 2, 5, 31, 30, 17, 18, 1, 16, 24, 32, 35, 3, 34, 23, 8, 29, 6, 12, 20, 7, 0, 4, 9, 33, 21, 26, 15]
# (28, 480, 480, 3) (28, 15, 15, 3, 10)
# 11 (480, 480, 3) (15, 15, 3, 10)
# (28, 15, 15, 3) and (15, 15, 3)

# %%
# https://github.com/ethanyanjiali/deep-vision/blob/master/YOLO/tensorflow/utils.py

def xywh_to_x1y1x2y2(box):
    xy = box[..., 0:2]
    wh = box[..., 2:4]

    x1y1 = xy - wh / 2
    x2y2 = xy + wh / 2

    y_box = K.concatenate([x1y1, x2y2], axis=-1)
    return y_box

def broadcast_iou(box_a, box_b):
    """
    calculate iou between box_a and multiple box_b in a broadcast way
    inputs: box_a: a tensor full of boxes, eg. (B, N, 4), box is in x1y1x2y2
            box_b: another tensor full of boxes, eg. (B, M, 4)
    """

    # (B, N, 1, 4)
    box_a = tf.expand_dims(box_a, -2)
    # (B, 1, M, 4)
    box_b = tf.expand_dims(box_b, -3)
    # (B, N, M, 4)
    new_shape = tf.broadcast_dynamic_shape(tf.shape(box_a), tf.shape(box_b))

    # (B, N, M, 4)
    # (B, N, M, 4)
    box_a = tf.broadcast_to(box_a, new_shape)
    box_b = tf.broadcast_to(box_b, new_shape)

    # (B, N, M, 1)
    al, at, ar, ab = tf.split(box_a, 4, -1)
    bl, bt, br, bb = tf.split(box_b, 4, -1)

    # (B, N, M, 1)
    left = tf.math.maximum(al, bl)
    right = tf.math.minimum(ar, br)
    top = tf.math.maximum(at, bt)
    bot = tf.math.minimum(ab, bb)

    # (B, N, M, 1)
    iw = tf.clip_by_value(right - left, 0, 1)
    ih = tf.clip_by_value(bot - top, 0, 1)
    i = iw * ih

    # (B, N, M, 1)
    area_a = (ar - al) * (ab - at)
    area_b = (br - bl) * (bb - bt)
    union = area_a + area_b - i

    # (B, N, M)
    iou = tf.squeeze(i / (union + 1e-7), axis=-1)

    return iou

## https://github.com/ethanyanjiali/deep-vision/blob/master/YOLO/tensorflow/yolov3.py#L213

def calc_ignore_mask(ignore_thresh, true_box, pred_box):
    
        # YOLOv3:
        # "If the bounding box prior is not the best but does overlap a ground
        # truth object by more than some threshold we ignore the prediction,
        # following [17]. We use the threshold of .5."
        # calculate the iou for each pair of pred bbox and true bbox, then find the best among them

        # (None, 13, 13, 3, 4)
        
        true_box_reorganised = xywh_to_x1y1x2y2(true_box)  # reorganised to x1, y1, x2, y2
        pred_box_reorganised = xywh_to_x1y1x2y2(pred_box)
        
        true_box_shape = tf.shape(true_box_reorganised)  
        # (None, 13, 13, 3, 4)
        pred_box_shape = tf.shape(pred_box_reorganised)  
        # (None, 507, 4)
        true_box_reorganised = tf.reshape(true_box_reorganised, [true_box_shape[0], -1, 4])
        # sort true_box to have non-zero boxes rank first
        true_box_reorganised = tf.sort(true_box_reorganised, axis=1, direction="DESCENDING")
        # (None, 100, 4)
        # only use maximum 100 boxes per groundtruth to calcualte IOU, otherwise
        # GPU emory comsumption would explode for a matrix like (16, 52*52*3, 52*52*3, 4)
        true_box_reorganised = true_box_reorganised[:, 0:100, :]
        # (None, 507, 4)
        pred_box_reorganised = tf.reshape(pred_box_reorganised, [pred_box_shape[0], -1, 4])

        # https://github.com/dmlc/gluon-cv/blob/06bb7ec2044cdf3f433721be9362ab84b02c5a90/gluoncv/model_zoo/yolo/yolo_target.py#L198
        # (None, 507, 507)
        iou = broadcast_iou(pred_box_reorganised, true_box_reorganised)
        # (None, 507)
        best_iou = tf.reduce_max(iou, axis=-1)
        # (None, 13, 13, 3)
        best_iou = tf.reshape(best_iou, [pred_box_shape[0], pred_box_shape[1], pred_box_shape[2], pred_box_shape[3]])
        # ignore_mask = 1 => don't ignore
        # ignore_mask = 0 => should ignore
        ignore_mask = tf.cast(best_iou < ignore_thresh, tf.float32)
        # (None, 13, 13, 3, 1)
        ignore_mask = tf.expand_dims(ignore_mask, axis=-1)
        
        return ignore_mask

# %%
def binary_cross_entropy(logits, labels):
    epsilon = 1e-7
    logits = tf.clip_by_value(logits, epsilon, 1 - epsilon)
    return -(labels * tf.math.log(logits) +
             (1 - labels) * tf.math.log(1 - logits))

def my_sigmoid(x):
    result = 1/(1 + np.exp(-x))
    return result

# %%
# def yolo_my_loss(y_true, y_pred, anchors_wrt_target):
def yolo_my_loss(y_true, y_pred):
    
    '''Return yolo_loss
    Parameters
    ----------
    yolo_outputs: list of tensor, the output of yolo_body or tiny_yolo_body
    y_true: list of array, the output of preprocess_true_boxes
    anchors: array, shape=(N, 2), wh ## w.r.t. target size
    num_classes: integer
    ignore_thresh: float, the iou threshold whether to ignore object confidence loss
    Returns
    -------
    loss: tensor, shape=(1,)
    '''
    
    grid_size = [15., 15.]
    ratio = 480./15.      ## ratio = 32
    ignore_thresh = 0.5
    Lambda_Coord = 5.0
    Lambda_no_obj = 0.5
    
    grid_x = np.arange(grid_size[1])
    grid_y = np.arange(grid_size[0])
    
    a = np.array(np.meshgrid(grid_x, grid_y))
    b = np.array(np.meshgrid(grid_x, grid_y))
    c = np.array(np.meshgrid(grid_x, grid_y))
    d = np.concatenate((a,b,c), axis = 0)
    e = d.transpose(2, 1, 0)
    grid_final = np.reshape(e,[15,15,3,2])
    
#    grid_x = np.arange(grid_size[1])
#    grid_y = np.arange(grid_size[0])
#    grid_x, grid_y = np.meshgrid(grid_x, grid_y)
#    grid_1st = np.dstack((grid_x, grid_y))
#    grid_2nd = np.dstack((grid_1st, grid_x, grid_y))
#    grid_3rd = np.dstack((grid_2nd, grid_x, grid_y)) 
#    grid_final = np.reshape(grid_3rd, [1,15,15,3,2])
    
    loss = tf.zeros(1, dtype='float32')
    
    
#    m = y_true.shape[0]
#    m = np.expand_dims(m, axis=-1)
#    mf = K.cast(m, dtype='float32')

    
    obj_mask = y_true[..., 4:5]
#    obj_mask = K.cast(obj_mask_y, dtype='float32')
    
#    true_box_wh = y_true[..., 2:4]
#    weight = 2 - true_box_wh[..., 0] * true_box_wh[..., 1]
#    weight = np.expand_dims(weight, axis=-1)
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++    
    pred_box_xy = K.sigmoid(y_pred[..., :2]) + grid_final  # this gives x & y in no. of cells. x & y w.r.t. target
                                                            # image = (x & y in no. of cells) / no. of cells
#    pred_box_xy = my_sigmoid(y_pred[..., :2]) + grid_final  # this gives x & y in no. of cells. x & y w.r.t. target
                                                            # image = (x & y in no. of cells) / no. of cells
        
#    pred_box_xy = K.eval(pred_box_xy)  
        
#    Lambda_Coord = K.cast(Lambda_Coord, dtype = 'float32')
    pred_box_xy_wrt_target_image = (pred_box_xy * ratio) / 480.
    true_box_xy_wrt_target_image = y_true[..., :2]
    
#    pred_box_xy_wrt_ti = K.cast(pred_box_xy_wrt_target_image, dtype = 'float32')
#    true_box_xy_wrt_ti = K.cast(true_box_xy_wrt_target_image, dtype = 'float32')
    
#    xy_arr = K.cast((true_box_xy_wrt_ti - pred_box_xy_wrt_ti), dtype='float32')

    xy_arr = np.power((true_box_xy_wrt_target_image - pred_box_xy_wrt_target_image), 2)
    
    xy_loss = K.cast((Lambda_Coord * np.sum(xy_arr * obj_mask)), dtype = 'float32')
    
#    xy_loss = K.cast(Lambda_Coord * tf.reduce_sum(tf.square(xy_arr) * obj_mask), dtype = 'float32')
    
#    xy_loss = (Lambda_Coord *np.sum(mean_squared_error(true_box_xy_wrt_ti, pred_box_xy_wrt_ti) * obj_mask*weight)) / m
    
#    xy_loss = (Lambda_Coord *np.sum(mean_squared_error(true_box_xy_wrt_ti, pred_box_xy_wrt_ti) * obj_mask*weight)) / m
    
#    xy_loss = (Lambda_Coord*tf.reduce_sum(tf.square(true_box_xy_wrt_ti - pred_box_xy_wrt_ti) *obj_mask))/m
#    wh_loss = tf.reduce_sum(tf.square(true_tw_th - pred_tw_th) * object_mask * box_loss_scale * mix_w) / N
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++    
    pred_box_wdht = K.exp(y_pred[..., 2:4]) * (anchors_wrt_target / 480.)
    
#    pred_box_wdht = np.exp(y_pred[..., 2:4]) * (anchors_wrt_target / 480.)
    
#    pred_box_wh = K.cast(pred_box_wdht, dtype = 'float32')
    true_box_wdht = y_true[..., 2:4]
#    true_box_wh = K.cast(true_box_wdht, dtype = 'float32')
    
#    wh_arr = K.cast((K.sqrt(true_box_wh) - K.sqrt(pred_box_wh)), dtype='float32')
    
    wh_arr = np.power((true_box_wdht - pred_box_wdht), 2)
    
    wh_loss = K.cast((Lambda_Coord * np.sum(wh_arr * obj_mask)), dtype = 'float32')
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ 

    pred_obj_mask = K.cast(K.sigmoid(y_pred[..., 4:5]), dtype = 'float32')  # shape = 28, 15, 15, 3, 1
       
    true_box_wrt_ti = K.concatenate([true_box_xy_wrt_target_image, true_box_wdht], axis = -1)  ## in x,y,w,h format
    pred_box_wrt_ti = K.concatenate([pred_box_xy_wrt_target_image, pred_box_wdht], axis = -1)  ## in x,y,w,h format
    
    
    
    
#    true_box_wrt_ti = xywh_to_x1y1x2y2(true_box_wrt_ti)  ## converted to x1,y1,x2,y2 format
#    pred_box_wrt_ti = xywh_to_x1y1x2y2(pred_box_wrt_ti)  ## converted to x1,y1,x2,y2 format
    
    ignore_mask = calc_ignore_mask(ignore_thresh, true_box_wrt_ti, pred_box_wrt_ti)
    
#    ignore_mask = K.cast(ignore_mask, dtype = 'float32')                               

    obj_loss = K.cast(K.sum(K.binary_crossentropy(obj_mask, pred_obj_mask) * obj_mask), dtype = 'float32')
    
    no_obj_mask = 1. - obj_mask
#    no_obj_mask = K.cast(no_obj_mask, dtype  = 'float32')
    
    noobj_loss = K.cast(Lambda_no_obj * K.sum(binary_cross_entropy(obj_mask, pred_obj_mask) * no_obj_mask * ignore_mask), dtype='float32')
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

    true_classes = K.cast(y_true[..., 5:10], dtype = 'float32')
    
    pred_classes = K.cast(y_pred[..., 5:10], dtype = 'float32')
    
    class_loss = K.cast(K.sum(binary_cross_entropy(true_classes, pred_classes) * obj_mask), dtype = 'float32')

    loss = xy_loss + wh_loss + obj_loss + noobj_loss + class_loss
    
    return loss

# %%
def yolo_model(input_shape):
    
    
    inp = Input(input_shape)
   
    model = InceptionResNetV2( input_tensor= inp , include_top=False, weights='imagenet')
    last_layer = model.output
    
    new_last_layer = UpSampling2D(2)(last_layer)
    
    conv = Conv2D(512,(3,3) , padding='valid')(new_last_layer)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    conv = Conv2D(256,(3,3) , padding='valid')(lr)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    another_up_layer = UpSampling2D(2)(lr)
    
    conv = Conv2D(256,(3,3) , padding='valid')(another_up_layer)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    conv = Conv2D(256,(3,3) , padding='valid')(lr)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    conv = Conv2D(128,(3,3) , strides = (2, 2), padding='valid')(lr)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    conv = Conv2D(64,(3,3) , padding='valid')(lr)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    conv = Conv2D(64,(3,3) , padding='valid')(lr)
    conv = Dropout(0.4)(conv)
    bn = BatchNormalization()(conv)
    lr = LeakyReLU(alpha=0.1)(bn)
    
    conv = Conv2D(30,(1,1) , padding='same')(lr)
#    conv = Dropout(0.4)(conv)
#    bn = BatchNormalization()(conv)
#    lr = LeakyRelu(alpha=0.1)(bn)

    final = Reshape((grid_y_axis,grid_x_axis,num_anchors,info))(conv)

    model = Model(inp,final)
    features = model.output

    return model, features

input_size = (target_w, target_h, 3)
my_yolo_invoice_model, features_1 = yolo_model(input_size)


my_model_1, features_2 = yolo_model(input_size)
my_model_2, features_3 = yolo_model(input_size)

print(my_model_1.summary())
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 480, 480, 3)  0
# __________________________________________________________________________________________________
# conv2d_845 (Conv2D)             (None, 239, 239, 32) 864         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_841 (BatchN (None, 239, 239, 32) 96          conv2d_845[0][0]
# __________________________________________________________________________________________________
# activation_813 (Activation)     (None, 239, 239, 32) 0           batch_normalization_841[0][0]
# __________________________________________________________________________________________________
# conv2d_846 (Conv2D)             (None, 237, 237, 32) 9216        activation_813[0][0]
# __________________________________________________________________________________________________
# batch_normalization_842 (BatchN (None, 237, 237, 32) 96          conv2d_846[0][0]
# __________________________________________________________________________________________________
# activation_814 (Activation)     (None, 237, 237, 32) 0           batch_normalization_842[0][0]
# __________________________________________________________________________________________________
# conv2d_847 (Conv2D)             (None, 237, 237, 64) 18432       activation_814[0][0]
# __________________________________________________________________________________________________
# batch_normalization_843 (BatchN (None, 237, 237, 64) 192         conv2d_847[0][0]
# __________________________________________________________________________________________________
# activation_815 (Activation)     (None, 237, 237, 64) 0           batch_normalization_843[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 118, 118, 64) 0           activation_815[0][0]
# __________________________________________________________________________________________________
# conv2d_848 (Conv2D)             (None, 118, 118, 80) 5120        max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_844 (BatchN (None, 118, 118, 80) 240         conv2d_848[0][0]
# __________________________________________________________________________________________________
# activation_816 (Activation)     (None, 118, 118, 80) 0           batch_normalization_844[0][0]
# __________________________________________________________________________________________________
# conv2d_849 (Conv2D)             (None, 116, 116, 192 138240      activation_816[0][0]
# __________________________________________________________________________________________________
# batch_normalization_845 (BatchN (None, 116, 116, 192 576         conv2d_849[0][0]
# __________________________________________________________________________________________________
# activation_817 (Activation)     (None, 116, 116, 192 0           batch_normalization_845[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 57, 57, 192)  0           activation_817[0][0]
# __________________________________________________________________________________________________
# conv2d_853 (Conv2D)             (None, 57, 57, 64)   12288       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_849 (BatchN (None, 57, 57, 64)   192         conv2d_853[0][0]
# __________________________________________________________________________________________________
# activation_821 (Activation)     (None, 57, 57, 64)   0           batch_normalization_849[0][0]
# __________________________________________________________________________________________________
# conv2d_851 (Conv2D)             (None, 57, 57, 48)   9216        max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_854 (Conv2D)             (None, 57, 57, 96)   55296       activation_821[0][0]
# __________________________________________________________________________________________________
# batch_normalization_847 (BatchN (None, 57, 57, 48)   144         conv2d_851[0][0]
# __________________________________________________________________________________________________
# batch_normalization_850 (BatchN (None, 57, 57, 96)   288         conv2d_854[0][0]
# __________________________________________________________________________________________________
# activation_819 (Activation)     (None, 57, 57, 48)   0           batch_normalization_847[0][0]
# __________________________________________________________________________________________________
# activation_822 (Activation)     (None, 57, 57, 96)   0           batch_normalization_850[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 57, 57, 192)  0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_850 (Conv2D)             (None, 57, 57, 96)   18432       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_852 (Conv2D)             (None, 57, 57, 64)   76800       activation_819[0][0]
# __________________________________________________________________________________________________
# conv2d_855 (Conv2D)             (None, 57, 57, 96)   82944       activation_822[0][0]
# __________________________________________________________________________________________________
# conv2d_856 (Conv2D)             (None, 57, 57, 64)   12288       average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_846 (BatchN (None, 57, 57, 96)   288         conv2d_850[0][0]
# __________________________________________________________________________________________________
# batch_normalization_848 (BatchN (None, 57, 57, 64)   192         conv2d_852[0][0]
# __________________________________________________________________________________________________
# batch_normalization_851 (BatchN (None, 57, 57, 96)   288         conv2d_855[0][0]
# __________________________________________________________________________________________________
# batch_normalization_852 (BatchN (None, 57, 57, 64)   192         conv2d_856[0][0]
# __________________________________________________________________________________________________
# activation_818 (Activation)     (None, 57, 57, 96)   0           batch_normalization_846[0][0]
# __________________________________________________________________________________________________
# activation_820 (Activation)     (None, 57, 57, 64)   0           batch_normalization_848[0][0]
# __________________________________________________________________________________________________
# activation_823 (Activation)     (None, 57, 57, 96)   0           batch_normalization_851[0][0]
# __________________________________________________________________________________________________
# activation_824 (Activation)     (None, 57, 57, 64)   0           batch_normalization_852[0][0]
# __________________________________________________________________________________________________
# mixed_5b (Concatenate)          (None, 57, 57, 320)  0           activation_818[0][0]
#                                                                  activation_820[0][0]
#                                                                  activation_823[0][0]
#                                                                  activation_824[0][0]
# __________________________________________________________________________________________________
# conv2d_860 (Conv2D)             (None, 57, 57, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# batch_normalization_856 (BatchN (None, 57, 57, 32)   96          conv2d_860[0][0]
# __________________________________________________________________________________________________
# activation_828 (Activation)     (None, 57, 57, 32)   0           batch_normalization_856[0][0]
# __________________________________________________________________________________________________
# conv2d_858 (Conv2D)             (None, 57, 57, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_861 (Conv2D)             (None, 57, 57, 48)   13824       activation_828[0][0]
# __________________________________________________________________________________________________
# batch_normalization_854 (BatchN (None, 57, 57, 32)   96          conv2d_858[0][0]
# __________________________________________________________________________________________________
# batch_normalization_857 (BatchN (None, 57, 57, 48)   144         conv2d_861[0][0]
# __________________________________________________________________________________________________
# activation_826 (Activation)     (None, 57, 57, 32)   0           batch_normalization_854[0][0]
# __________________________________________________________________________________________________
# activation_829 (Activation)     (None, 57, 57, 48)   0           batch_normalization_857[0][0]
# __________________________________________________________________________________________________
# conv2d_857 (Conv2D)             (None, 57, 57, 32)   10240       mixed_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_859 (Conv2D)             (None, 57, 57, 32)   9216        activation_826[0][0]
# __________________________________________________________________________________________________
# conv2d_862 (Conv2D)             (None, 57, 57, 64)   27648       activation_829[0][0]
# __________________________________________________________________________________________________
# batch_normalization_853 (BatchN (None, 57, 57, 32)   96          conv2d_857[0][0]
# __________________________________________________________________________________________________
# batch_normalization_855 (BatchN (None, 57, 57, 32)   96          conv2d_859[0][0]
# __________________________________________________________________________________________________
# batch_normalization_858 (BatchN (None, 57, 57, 64)   192         conv2d_862[0][0]
# __________________________________________________________________________________________________
# activation_825 (Activation)     (None, 57, 57, 32)   0           batch_normalization_853[0][0]
# __________________________________________________________________________________________________
# activation_827 (Activation)     (None, 57, 57, 32)   0           batch_normalization_855[0][0]
# __________________________________________________________________________________________________
# activation_830 (Activation)     (None, 57, 57, 64)   0           batch_normalization_858[0][0]
# __________________________________________________________________________________________________
# block35_1_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_825[0][0]
#                                                                  activation_827[0][0]
#                                                                  activation_830[0][0]
# __________________________________________________________________________________________________
# block35_1_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_1_mixed[0][0]
# __________________________________________________________________________________________________
# block35_1 (Lambda)              (None, 57, 57, 320)  0           mixed_5b[0][0]
#                                                                  block35_1_conv[0][0]
# __________________________________________________________________________________________________
# block35_1_ac (Activation)       (None, 57, 57, 320)  0           block35_1[0][0]
# __________________________________________________________________________________________________
# conv2d_866 (Conv2D)             (None, 57, 57, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_862 (BatchN (None, 57, 57, 32)   96          conv2d_866[0][0]
# __________________________________________________________________________________________________
# activation_834 (Activation)     (None, 57, 57, 32)   0           batch_normalization_862[0][0]
# __________________________________________________________________________________________________
# conv2d_864 (Conv2D)             (None, 57, 57, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_867 (Conv2D)             (None, 57, 57, 48)   13824       activation_834[0][0]
# __________________________________________________________________________________________________
# batch_normalization_860 (BatchN (None, 57, 57, 32)   96          conv2d_864[0][0]
# __________________________________________________________________________________________________
# batch_normalization_863 (BatchN (None, 57, 57, 48)   144         conv2d_867[0][0]
# __________________________________________________________________________________________________
# activation_832 (Activation)     (None, 57, 57, 32)   0           batch_normalization_860[0][0]
# __________________________________________________________________________________________________
# activation_835 (Activation)     (None, 57, 57, 48)   0           batch_normalization_863[0][0]
# __________________________________________________________________________________________________
# conv2d_863 (Conv2D)             (None, 57, 57, 32)   10240       block35_1_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_865 (Conv2D)             (None, 57, 57, 32)   9216        activation_832[0][0]
# __________________________________________________________________________________________________
# conv2d_868 (Conv2D)             (None, 57, 57, 64)   27648       activation_835[0][0]
# __________________________________________________________________________________________________
# batch_normalization_859 (BatchN (None, 57, 57, 32)   96          conv2d_863[0][0]
# __________________________________________________________________________________________________
# batch_normalization_861 (BatchN (None, 57, 57, 32)   96          conv2d_865[0][0]
# __________________________________________________________________________________________________
# batch_normalization_864 (BatchN (None, 57, 57, 64)   192         conv2d_868[0][0]
# __________________________________________________________________________________________________
# activation_831 (Activation)     (None, 57, 57, 32)   0           batch_normalization_859[0][0]
# __________________________________________________________________________________________________
# activation_833 (Activation)     (None, 57, 57, 32)   0           batch_normalization_861[0][0]
# __________________________________________________________________________________________________
# activation_836 (Activation)     (None, 57, 57, 64)   0           batch_normalization_864[0][0]
# __________________________________________________________________________________________________
# block35_2_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_831[0][0]
#                                                                  activation_833[0][0]
#                                                                  activation_836[0][0]
# __________________________________________________________________________________________________
# block35_2_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_2_mixed[0][0]
# __________________________________________________________________________________________________
# block35_2 (Lambda)              (None, 57, 57, 320)  0           block35_1_ac[0][0]
#                                                                  block35_2_conv[0][0]
# __________________________________________________________________________________________________
# block35_2_ac (Activation)       (None, 57, 57, 320)  0           block35_2[0][0]
# __________________________________________________________________________________________________
# conv2d_872 (Conv2D)             (None, 57, 57, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_868 (BatchN (None, 57, 57, 32)   96          conv2d_872[0][0]
# __________________________________________________________________________________________________
# activation_840 (Activation)     (None, 57, 57, 32)   0           batch_normalization_868[0][0]
# __________________________________________________________________________________________________
# conv2d_870 (Conv2D)             (None, 57, 57, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_873 (Conv2D)             (None, 57, 57, 48)   13824       activation_840[0][0]
# __________________________________________________________________________________________________
# batch_normalization_866 (BatchN (None, 57, 57, 32)   96          conv2d_870[0][0]
# __________________________________________________________________________________________________
# batch_normalization_869 (BatchN (None, 57, 57, 48)   144         conv2d_873[0][0]
# __________________________________________________________________________________________________
# activation_838 (Activation)     (None, 57, 57, 32)   0           batch_normalization_866[0][0]
# __________________________________________________________________________________________________
# activation_841 (Activation)     (None, 57, 57, 48)   0           batch_normalization_869[0][0]
# __________________________________________________________________________________________________
# conv2d_869 (Conv2D)             (None, 57, 57, 32)   10240       block35_2_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_871 (Conv2D)             (None, 57, 57, 32)   9216        activation_838[0][0]
# __________________________________________________________________________________________________
# conv2d_874 (Conv2D)             (None, 57, 57, 64)   27648       activation_841[0][0]
# __________________________________________________________________________________________________
# batch_normalization_865 (BatchN (None, 57, 57, 32)   96          conv2d_869[0][0]
# __________________________________________________________________________________________________
# batch_normalization_867 (BatchN (None, 57, 57, 32)   96          conv2d_871[0][0]
# __________________________________________________________________________________________________
# batch_normalization_870 (BatchN (None, 57, 57, 64)   192         conv2d_874[0][0]
# __________________________________________________________________________________________________
# activation_837 (Activation)     (None, 57, 57, 32)   0           batch_normalization_865[0][0]
# __________________________________________________________________________________________________
# activation_839 (Activation)     (None, 57, 57, 32)   0           batch_normalization_867[0][0]
# __________________________________________________________________________________________________
# activation_842 (Activation)     (None, 57, 57, 64)   0           batch_normalization_870[0][0]
# __________________________________________________________________________________________________
# block35_3_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_837[0][0]
#                                                                  activation_839[0][0]
#                                                                  activation_842[0][0]
# __________________________________________________________________________________________________
# block35_3_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_3_mixed[0][0]
# __________________________________________________________________________________________________
# block35_3 (Lambda)              (None, 57, 57, 320)  0           block35_2_ac[0][0]
#                                                                  block35_3_conv[0][0]
# __________________________________________________________________________________________________
# block35_3_ac (Activation)       (None, 57, 57, 320)  0           block35_3[0][0]
# __________________________________________________________________________________________________
# conv2d_878 (Conv2D)             (None, 57, 57, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_874 (BatchN (None, 57, 57, 32)   96          conv2d_878[0][0]
# __________________________________________________________________________________________________
# activation_846 (Activation)     (None, 57, 57, 32)   0           batch_normalization_874[0][0]
# __________________________________________________________________________________________________
# conv2d_876 (Conv2D)             (None, 57, 57, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_879 (Conv2D)             (None, 57, 57, 48)   13824       activation_846[0][0]
# __________________________________________________________________________________________________
# batch_normalization_872 (BatchN (None, 57, 57, 32)   96          conv2d_876[0][0]
# __________________________________________________________________________________________________
# batch_normalization_875 (BatchN (None, 57, 57, 48)   144         conv2d_879[0][0]
# __________________________________________________________________________________________________
# activation_844 (Activation)     (None, 57, 57, 32)   0           batch_normalization_872[0][0]
# __________________________________________________________________________________________________
# activation_847 (Activation)     (None, 57, 57, 48)   0           batch_normalization_875[0][0]
# __________________________________________________________________________________________________
# conv2d_875 (Conv2D)             (None, 57, 57, 32)   10240       block35_3_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_877 (Conv2D)             (None, 57, 57, 32)   9216        activation_844[0][0]
# __________________________________________________________________________________________________
# conv2d_880 (Conv2D)             (None, 57, 57, 64)   27648       activation_847[0][0]
# __________________________________________________________________________________________________
# batch_normalization_871 (BatchN (None, 57, 57, 32)   96          conv2d_875[0][0]
# __________________________________________________________________________________________________
# batch_normalization_873 (BatchN (None, 57, 57, 32)   96          conv2d_877[0][0]
# __________________________________________________________________________________________________
# batch_normalization_876 (BatchN (None, 57, 57, 64)   192         conv2d_880[0][0]
# __________________________________________________________________________________________________
# activation_843 (Activation)     (None, 57, 57, 32)   0           batch_normalization_871[0][0]
# __________________________________________________________________________________________________
# activation_845 (Activation)     (None, 57, 57, 32)   0           batch_normalization_873[0][0]
# __________________________________________________________________________________________________
# activation_848 (Activation)     (None, 57, 57, 64)   0           batch_normalization_876[0][0]
# __________________________________________________________________________________________________
# block35_4_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_843[0][0]
#                                                                  activation_845[0][0]
#                                                                  activation_848[0][0]
# __________________________________________________________________________________________________
# block35_4_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_4_mixed[0][0]
# __________________________________________________________________________________________________
# block35_4 (Lambda)              (None, 57, 57, 320)  0           block35_3_ac[0][0]
#                                                                  block35_4_conv[0][0]
# __________________________________________________________________________________________________
# block35_4_ac (Activation)       (None, 57, 57, 320)  0           block35_4[0][0]
# __________________________________________________________________________________________________
# conv2d_884 (Conv2D)             (None, 57, 57, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_880 (BatchN (None, 57, 57, 32)   96          conv2d_884[0][0]
# __________________________________________________________________________________________________
# activation_852 (Activation)     (None, 57, 57, 32)   0           batch_normalization_880[0][0]
# __________________________________________________________________________________________________
# conv2d_882 (Conv2D)             (None, 57, 57, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_885 (Conv2D)             (None, 57, 57, 48)   13824       activation_852[0][0]
# __________________________________________________________________________________________________
# batch_normalization_878 (BatchN (None, 57, 57, 32)   96          conv2d_882[0][0]
# __________________________________________________________________________________________________
# batch_normalization_881 (BatchN (None, 57, 57, 48)   144         conv2d_885[0][0]
# __________________________________________________________________________________________________
# activation_850 (Activation)     (None, 57, 57, 32)   0           batch_normalization_878[0][0]
# __________________________________________________________________________________________________
# activation_853 (Activation)     (None, 57, 57, 48)   0           batch_normalization_881[0][0]
# __________________________________________________________________________________________________
# conv2d_881 (Conv2D)             (None, 57, 57, 32)   10240       block35_4_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_883 (Conv2D)             (None, 57, 57, 32)   9216        activation_850[0][0]
# __________________________________________________________________________________________________
# conv2d_886 (Conv2D)             (None, 57, 57, 64)   27648       activation_853[0][0]
# __________________________________________________________________________________________________
# batch_normalization_877 (BatchN (None, 57, 57, 32)   96          conv2d_881[0][0]
# __________________________________________________________________________________________________
# batch_normalization_879 (BatchN (None, 57, 57, 32)   96          conv2d_883[0][0]
# __________________________________________________________________________________________________
# batch_normalization_882 (BatchN (None, 57, 57, 64)   192         conv2d_886[0][0]
# __________________________________________________________________________________________________
# activation_849 (Activation)     (None, 57, 57, 32)   0           batch_normalization_877[0][0]
# __________________________________________________________________________________________________
# activation_851 (Activation)     (None, 57, 57, 32)   0           batch_normalization_879[0][0]
# __________________________________________________________________________________________________
# activation_854 (Activation)     (None, 57, 57, 64)   0           batch_normalization_882[0][0]
# __________________________________________________________________________________________________
# block35_5_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_849[0][0]
#                                                                  activation_851[0][0]
#                                                                  activation_854[0][0]
# __________________________________________________________________________________________________
# block35_5_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_5_mixed[0][0]
# __________________________________________________________________________________________________
# block35_5 (Lambda)              (None, 57, 57, 320)  0           block35_4_ac[0][0]
#                                                                  block35_5_conv[0][0]
# __________________________________________________________________________________________________
# block35_5_ac (Activation)       (None, 57, 57, 320)  0           block35_5[0][0]
# __________________________________________________________________________________________________
# conv2d_890 (Conv2D)             (None, 57, 57, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_886 (BatchN (None, 57, 57, 32)   96          conv2d_890[0][0]
# __________________________________________________________________________________________________
# activation_858 (Activation)     (None, 57, 57, 32)   0           batch_normalization_886[0][0]
# __________________________________________________________________________________________________
# conv2d_888 (Conv2D)             (None, 57, 57, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_891 (Conv2D)             (None, 57, 57, 48)   13824       activation_858[0][0]
# __________________________________________________________________________________________________
# batch_normalization_884 (BatchN (None, 57, 57, 32)   96          conv2d_888[0][0]
# __________________________________________________________________________________________________
# batch_normalization_887 (BatchN (None, 57, 57, 48)   144         conv2d_891[0][0]
# __________________________________________________________________________________________________
# activation_856 (Activation)     (None, 57, 57, 32)   0           batch_normalization_884[0][0]
# __________________________________________________________________________________________________
# activation_859 (Activation)     (None, 57, 57, 48)   0           batch_normalization_887[0][0]
# __________________________________________________________________________________________________
# conv2d_887 (Conv2D)             (None, 57, 57, 32)   10240       block35_5_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_889 (Conv2D)             (None, 57, 57, 32)   9216        activation_856[0][0]
# __________________________________________________________________________________________________
# conv2d_892 (Conv2D)             (None, 57, 57, 64)   27648       activation_859[0][0]
# __________________________________________________________________________________________________
# batch_normalization_883 (BatchN (None, 57, 57, 32)   96          conv2d_887[0][0]
# __________________________________________________________________________________________________
# batch_normalization_885 (BatchN (None, 57, 57, 32)   96          conv2d_889[0][0]
# __________________________________________________________________________________________________
# batch_normalization_888 (BatchN (None, 57, 57, 64)   192         conv2d_892[0][0]
# __________________________________________________________________________________________________
# activation_855 (Activation)     (None, 57, 57, 32)   0           batch_normalization_883[0][0]
# __________________________________________________________________________________________________
# activation_857 (Activation)     (None, 57, 57, 32)   0           batch_normalization_885[0][0]
# __________________________________________________________________________________________________
# activation_860 (Activation)     (None, 57, 57, 64)   0           batch_normalization_888[0][0]
# __________________________________________________________________________________________________
# block35_6_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_855[0][0]
#                                                                  activation_857[0][0]
#                                                                  activation_860[0][0]
# __________________________________________________________________________________________________
# block35_6_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_6_mixed[0][0]
# __________________________________________________________________________________________________
# block35_6 (Lambda)              (None, 57, 57, 320)  0           block35_5_ac[0][0]
#                                                                  block35_6_conv[0][0]
# __________________________________________________________________________________________________
# block35_6_ac (Activation)       (None, 57, 57, 320)  0           block35_6[0][0]
# __________________________________________________________________________________________________
# conv2d_896 (Conv2D)             (None, 57, 57, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_892 (BatchN (None, 57, 57, 32)   96          conv2d_896[0][0]
# __________________________________________________________________________________________________
# activation_864 (Activation)     (None, 57, 57, 32)   0           batch_normalization_892[0][0]
# __________________________________________________________________________________________________
# conv2d_894 (Conv2D)             (None, 57, 57, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_897 (Conv2D)             (None, 57, 57, 48)   13824       activation_864[0][0]
# __________________________________________________________________________________________________
# batch_normalization_890 (BatchN (None, 57, 57, 32)   96          conv2d_894[0][0]
# __________________________________________________________________________________________________
# batch_normalization_893 (BatchN (None, 57, 57, 48)   144         conv2d_897[0][0]
# __________________________________________________________________________________________________
# activation_862 (Activation)     (None, 57, 57, 32)   0           batch_normalization_890[0][0]
# __________________________________________________________________________________________________
# activation_865 (Activation)     (None, 57, 57, 48)   0           batch_normalization_893[0][0]
# __________________________________________________________________________________________________
# conv2d_893 (Conv2D)             (None, 57, 57, 32)   10240       block35_6_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_895 (Conv2D)             (None, 57, 57, 32)   9216        activation_862[0][0]
# __________________________________________________________________________________________________
# conv2d_898 (Conv2D)             (None, 57, 57, 64)   27648       activation_865[0][0]
# __________________________________________________________________________________________________
# batch_normalization_889 (BatchN (None, 57, 57, 32)   96          conv2d_893[0][0]
# __________________________________________________________________________________________________
# batch_normalization_891 (BatchN (None, 57, 57, 32)   96          conv2d_895[0][0]
# __________________________________________________________________________________________________
# batch_normalization_894 (BatchN (None, 57, 57, 64)   192         conv2d_898[0][0]
# __________________________________________________________________________________________________
# activation_861 (Activation)     (None, 57, 57, 32)   0           batch_normalization_889[0][0]
# __________________________________________________________________________________________________
# activation_863 (Activation)     (None, 57, 57, 32)   0           batch_normalization_891[0][0]
# __________________________________________________________________________________________________
# activation_866 (Activation)     (None, 57, 57, 64)   0           batch_normalization_894[0][0]
# __________________________________________________________________________________________________
# block35_7_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_861[0][0]
#                                                                  activation_863[0][0]
#                                                                  activation_866[0][0]
# __________________________________________________________________________________________________
# block35_7_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_7_mixed[0][0]
# __________________________________________________________________________________________________
# block35_7 (Lambda)              (None, 57, 57, 320)  0           block35_6_ac[0][0]
#                                                                  block35_7_conv[0][0]
# __________________________________________________________________________________________________
# block35_7_ac (Activation)       (None, 57, 57, 320)  0           block35_7[0][0]
# __________________________________________________________________________________________________
# conv2d_902 (Conv2D)             (None, 57, 57, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_898 (BatchN (None, 57, 57, 32)   96          conv2d_902[0][0]
# __________________________________________________________________________________________________
# activation_870 (Activation)     (None, 57, 57, 32)   0           batch_normalization_898[0][0]
# __________________________________________________________________________________________________
# conv2d_900 (Conv2D)             (None, 57, 57, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_903 (Conv2D)             (None, 57, 57, 48)   13824       activation_870[0][0]
# __________________________________________________________________________________________________
# batch_normalization_896 (BatchN (None, 57, 57, 32)   96          conv2d_900[0][0]
# __________________________________________________________________________________________________
# batch_normalization_899 (BatchN (None, 57, 57, 48)   144         conv2d_903[0][0]
# __________________________________________________________________________________________________
# activation_868 (Activation)     (None, 57, 57, 32)   0           batch_normalization_896[0][0]
# __________________________________________________________________________________________________
# activation_871 (Activation)     (None, 57, 57, 48)   0           batch_normalization_899[0][0]
# __________________________________________________________________________________________________
# conv2d_899 (Conv2D)             (None, 57, 57, 32)   10240       block35_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_901 (Conv2D)             (None, 57, 57, 32)   9216        activation_868[0][0]
# __________________________________________________________________________________________________
# conv2d_904 (Conv2D)             (None, 57, 57, 64)   27648       activation_871[0][0]
# __________________________________________________________________________________________________
# batch_normalization_895 (BatchN (None, 57, 57, 32)   96          conv2d_899[0][0]
# __________________________________________________________________________________________________
# batch_normalization_897 (BatchN (None, 57, 57, 32)   96          conv2d_901[0][0]
# __________________________________________________________________________________________________
# batch_normalization_900 (BatchN (None, 57, 57, 64)   192         conv2d_904[0][0]
# __________________________________________________________________________________________________
# activation_867 (Activation)     (None, 57, 57, 32)   0           batch_normalization_895[0][0]
# __________________________________________________________________________________________________
# activation_869 (Activation)     (None, 57, 57, 32)   0           batch_normalization_897[0][0]
# __________________________________________________________________________________________________
# activation_872 (Activation)     (None, 57, 57, 64)   0           batch_normalization_900[0][0]
# __________________________________________________________________________________________________
# block35_8_mixed (Concatenate)   (None, 57, 57, 128)  0           activation_867[0][0]
#                                                                  activation_869[0][0]
#                                                                  activation_872[0][0]
# __________________________________________________________________________________________________
# block35_8_conv (Conv2D)         (None, 57, 57, 320)  41280       block35_8_mixed[0][0]
# __________________________________________________________________________________________________
# block35_8 (Lambda)              (None, 57, 57, 320)  0           block35_7_ac[0][0]
#                                                                  block35_8_conv[0][0]
# __________________________________________________________________________________________________
# block35_8_ac (Activation)       (None, 57, 57, 320)  0           block35_8[0][0]
# __________________________________________________________________________________________________
# conv2d_908 (Conv2D)             (None, 57, 57, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_904 (BatchN (None, 57, 57, 32)   96          conv2d_908[0][0]
# __________________________________________________________________________________________________
# activation_876 (Activation)     (None, 57, 57, 32)   0           batch_normalization_904[0][0]
# __________________________________________________________________________________________________
# conv2d_906 (Conv2D)             (None, 57, 57, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_909 (Conv2D)             (None, 57, 57, 48)   13824       activation_876[0][0]
# __________________________________________________________________________________________________
# batch_normalization_902 (BatchN (None, 57, 57, 32)   96          conv2d_906[0][0]
# __________________________________________________________________________________________________
# batch_normalization_905 (BatchN (None, 57, 57, 48)   144         conv2d_909[0][0]
# __________________________________________________________________________________________________
# activation_874 (Activation)     (None, 57, 57, 32)   0           batch_normalization_902[0][0]
# __________________________________________________________________________________________________
# activation_877 (Activation)     (None, 57, 57, 48)   0           batch_normalization_905[0][0]
# __________________________________________________________________________________________________
# conv2d_905 (Conv2D)             (None, 57, 57, 32)   10240       block35_8_ac[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv2d_1036 (Conv2D)            (None, 13, 13, 192)  399360      block8_7_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1039 (Conv2D)            (None, 13, 13, 256)  172032      activation_1006[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1032 (Batch (None, 13, 13, 192)  576         conv2d_1036[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1035 (Batch (None, 13, 13, 256)  768         conv2d_1039[0][0]
# __________________________________________________________________________________________________
# activation_1004 (Activation)    (None, 13, 13, 192)  0           batch_normalization_1032[0][0]
# __________________________________________________________________________________________________
# activation_1007 (Activation)    (None, 13, 13, 256)  0           batch_normalization_1035[0][0]
# __________________________________________________________________________________________________
# block8_8_mixed (Concatenate)    (None, 13, 13, 448)  0           activation_1004[0][0]
#                                                                  activation_1007[0][0]
# __________________________________________________________________________________________________
# block8_8_conv (Conv2D)          (None, 13, 13, 2080) 933920      block8_8_mixed[0][0]
# __________________________________________________________________________________________________
# block8_8 (Lambda)               (None, 13, 13, 2080) 0           block8_7_ac[0][0]
#                                                                  block8_8_conv[0][0]
# __________________________________________________________________________________________________
# block8_8_ac (Activation)        (None, 13, 13, 2080) 0           block8_8[0][0]
# __________________________________________________________________________________________________
# conv2d_1041 (Conv2D)            (None, 13, 13, 192)  399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1037 (Batch (None, 13, 13, 192)  576         conv2d_1041[0][0]
# __________________________________________________________________________________________________
# activation_1009 (Activation)    (None, 13, 13, 192)  0           batch_normalization_1037[0][0]
# __________________________________________________________________________________________________
# conv2d_1042 (Conv2D)            (None, 13, 13, 224)  129024      activation_1009[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1038 (Batch (None, 13, 13, 224)  672         conv2d_1042[0][0]
# __________________________________________________________________________________________________
# activation_1010 (Activation)    (None, 13, 13, 224)  0           batch_normalization_1038[0][0]
# __________________________________________________________________________________________________
# conv2d_1040 (Conv2D)            (None, 13, 13, 192)  399360      block8_8_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1043 (Conv2D)            (None, 13, 13, 256)  172032      activation_1010[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1036 (Batch (None, 13, 13, 192)  576         conv2d_1040[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1039 (Batch (None, 13, 13, 256)  768         conv2d_1043[0][0]
# __________________________________________________________________________________________________
# activation_1008 (Activation)    (None, 13, 13, 192)  0           batch_normalization_1036[0][0]
# __________________________________________________________________________________________________
# activation_1011 (Activation)    (None, 13, 13, 256)  0           batch_normalization_1039[0][0]
# __________________________________________________________________________________________________
# block8_9_mixed (Concatenate)    (None, 13, 13, 448)  0           activation_1008[0][0]
#                                                                  activation_1011[0][0]
# __________________________________________________________________________________________________
# block8_9_conv (Conv2D)          (None, 13, 13, 2080) 933920      block8_9_mixed[0][0]
# __________________________________________________________________________________________________
# block8_9 (Lambda)               (None, 13, 13, 2080) 0           block8_8_ac[0][0]
#                                                                  block8_9_conv[0][0]
# __________________________________________________________________________________________________
# block8_9_ac (Activation)        (None, 13, 13, 2080) 0           block8_9[0][0]
# __________________________________________________________________________________________________
# conv2d_1045 (Conv2D)            (None, 13, 13, 192)  399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1041 (Batch (None, 13, 13, 192)  576         conv2d_1045[0][0]
# __________________________________________________________________________________________________
# activation_1013 (Activation)    (None, 13, 13, 192)  0           batch_normalization_1041[0][0]
# __________________________________________________________________________________________________
# conv2d_1046 (Conv2D)            (None, 13, 13, 224)  129024      activation_1013[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1042 (Batch (None, 13, 13, 224)  672         conv2d_1046[0][0]
# __________________________________________________________________________________________________
# activation_1014 (Activation)    (None, 13, 13, 224)  0           batch_normalization_1042[0][0]
# __________________________________________________________________________________________________
# conv2d_1044 (Conv2D)            (None, 13, 13, 192)  399360      block8_9_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1047 (Conv2D)            (None, 13, 13, 256)  172032      activation_1014[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1040 (Batch (None, 13, 13, 192)  576         conv2d_1044[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1043 (Batch (None, 13, 13, 256)  768         conv2d_1047[0][0]
# __________________________________________________________________________________________________
# activation_1012 (Activation)    (None, 13, 13, 192)  0           batch_normalization_1040[0][0]
# __________________________________________________________________________________________________
# activation_1015 (Activation)    (None, 13, 13, 256)  0           batch_normalization_1043[0][0]
# __________________________________________________________________________________________________
# block8_10_mixed (Concatenate)   (None, 13, 13, 448)  0           activation_1012[0][0]
#                                                                  activation_1015[0][0]
# __________________________________________________________________________________________________
# block8_10_conv (Conv2D)         (None, 13, 13, 2080) 933920      block8_10_mixed[0][0]
# __________________________________________________________________________________________________
# block8_10 (Lambda)              (None, 13, 13, 2080) 0           block8_9_ac[0][0]
#                                                                  block8_10_conv[0][0]
# __________________________________________________________________________________________________
# conv_7b (Conv2D)                (None, 13, 13, 1536) 3194880     block8_10[0][0]
# __________________________________________________________________________________________________
# conv_7b_bn (BatchNormalization) (None, 13, 13, 1536) 4608        conv_7b[0][0]
# __________________________________________________________________________________________________
# conv_7b_ac (Activation)         (None, 13, 13, 1536) 0           conv_7b_bn[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_9 (UpSampling2D)  (None, 26, 26, 1536) 0           conv_7b_ac[0][0]
# __________________________________________________________________________________________________
# conv2d_1048 (Conv2D)            (None, 24, 24, 512)  7078400     up_sampling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 24, 24, 512)  0           conv2d_1048[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1044 (Batch (None, 24, 24, 512)  2048        dropout_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 24, 24, 512)  0           batch_normalization_1044[0][0]
# __________________________________________________________________________________________________
# conv2d_1049 (Conv2D)            (None, 22, 22, 256)  1179904     leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 22, 22, 256)  0           conv2d_1049[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1045 (Batch (None, 22, 22, 256)  1024        dropout_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 22, 22, 256)  0           batch_normalization_1045[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 44, 44, 256)  0           leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_1050 (Conv2D)            (None, 42, 42, 256)  590080      up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 42, 42, 256)  0           conv2d_1050[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1046 (Batch (None, 42, 42, 256)  1024        dropout_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 42, 42, 256)  0           batch_normalization_1046[0][0]
# __________________________________________________________________________________________________
# conv2d_1051 (Conv2D)            (None, 40, 40, 256)  590080      leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 40, 40, 256)  0           conv2d_1051[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1047 (Batch (None, 40, 40, 256)  1024        dropout_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 40, 40, 256)  0           batch_normalization_1047[0][0]
# __________________________________________________________________________________________________
# conv2d_1052 (Conv2D)            (None, 19, 19, 128)  295040      leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 19, 19, 128)  0           conv2d_1052[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1048 (Batch (None, 19, 19, 128)  512         dropout_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 19, 19, 128)  0           batch_normalization_1048[0][0]
# __________________________________________________________________________________________________
# conv2d_1053 (Conv2D)            (None, 17, 17, 64)   73792       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 17, 17, 64)   0           conv2d_1053[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1049 (Batch (None, 17, 17, 64)   256         dropout_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 17, 17, 64)   0           batch_normalization_1049[0][0]
# __________________________________________________________________________________________________
# conv2d_1054 (Conv2D)            (None, 15, 15, 64)   36928       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 15, 15, 64)   0           conv2d_1054[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1050 (Batch (None, 15, 15, 64)   256         dropout_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 15, 15, 64)   0           batch_normalization_1050[0][0]
# __________________________________________________________________________________________________
# conv2d_1055 (Conv2D)            (None, 15, 15, 30)   1950        leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 15, 15, 3, 10 0           conv2d_1055[0][0]
# ==================================================================================================
# Total params: 64,189,054
# Trainable params: 64,125,438
# Non-trainable params: 63,616
# __________________________________________________________________________________________________
# None

# %%
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
my_model_1.compile(optimizer= opt,loss=yolo_my_loss,metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
my_model_1.fit(X_train ,Y_train ,epochs= 5,batch_size = 4, validation_data=(X_val,Y_val))
# Out:
# WARNING:tensorflow:From /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 28 samples, validate on 8 samples
# Epoch 1/5
# 28/28 [==============================] - 263s 9s/step - loss: 11018.0586 - accuracy: 0.0890 - val_loss: 11245.3071 - val_accuracy: 0.0559
# Epoch 2/5
# 28/28 [==============================] - 133s 5s/step - loss: 10681.1616 - accuracy: 0.0914 - val_loss: 11318.3384 - val_accuracy: 0.0537
# Epoch 3/5
# 28/28 [==============================] - 135s 5s/step - loss: 10222.7691 - accuracy: 0.0863 - val_loss: 11400.0112 - val_accuracy: 0.0456
# Epoch 4/5
# 28/28 [==============================] - 132s 5s/step - loss: 10153.8807 - accuracy: 0.0880 - val_loss: 11495.7954 - val_accuracy: 0.0441
# Epoch 5/5
# 28/28 [==============================] - 132s 5s/step - loss: 9716.8817 - accuracy: 0.0877 - val_loss: 11648.3584 - val_accuracy: 0.0496

# %%
my_model_1.fit(X_train ,Y_train ,epochs= 25,batch_size = 4, validation_data=(X_val,Y_val))
# Out:
# Train on 28 samples, validate on 8 samples
# Epoch 1/25
# 28/28 [==============================] - 128s 5s/step - loss: 9519.4439 - accuracy: 0.0852 - val_loss: 11801.4580 - val_accuracy: 0.0483
# Epoch 2/25
# 28/28 [==============================] - 134s 5s/step - loss: 9179.6208 - accuracy: 0.0859 - val_loss: 11993.4897 - val_accuracy: 0.0574
# Epoch 3/25
# 28/28 [==============================] - 133s 5s/step - loss: 8956.3172 - accuracy: 0.0822 - val_loss: 12133.5542 - val_accuracy: 0.0794
# Epoch 4/25
# 28/28 [==============================] - 133s 5s/step - loss: 8555.5830 - accuracy: 0.0780 - val_loss: 11807.0200 - val_accuracy: 0.0650
# Epoch 5/25
# 28/28 [==============================] - 134s 5s/step - loss: 8357.1784 - accuracy: 0.0750 - val_loss: 11219.6484 - val_accuracy: 0.0522
# Epoch 6/25
# 28/28 [==============================] - 137s 5s/step - loss: 8170.1319 - accuracy: 0.0805 - val_loss: 10907.4922 - val_accuracy: 0.0744
# Epoch 7/25
# 28/28 [==============================] - 133s 5s/step - loss: 14505.9230 - accuracy: 0.0764 - val_loss: 10199.2046 - val_accuracy: 0.0648
# Epoch 8/25
# 28/28 [==============================] - 139s 5s/step - loss: 8065.7194 - accuracy: 0.0763 - val_loss: 9356.1128 - val_accuracy: 0.0331
# Epoch 9/25
# 28/28 [==============================] - 137s 5s/step - loss: 8141.5970 - accuracy: 0.0783 - val_loss: 9053.8174 - val_accuracy: 0.0250
# Epoch 10/25
# 28/28 [==============================] - 137s 5s/step - loss: 7872.6092 - accuracy: 0.0774 - val_loss: 8876.9194 - val_accuracy: 0.0254
# Epoch 11/25
# 28/28 [==============================] - 135s 5s/step - loss: 7742.9950 - accuracy: 0.0754 - val_loss: 8698.5024 - val_accuracy: 0.0265
# Epoch 12/25
# 28/28 [==============================] - 136s 5s/step - loss: 7717.6633 - accuracy: 0.0774 - val_loss: 8527.4194 - val_accuracy: 0.0261
# Epoch 13/25
# 28/28 [==============================] - 140s 5s/step - loss: 7738.5191 - accuracy: 0.0770 - val_loss: 8357.0620 - val_accuracy: 0.0261
# Epoch 14/25
# 28/28 [==============================] - 133s 5s/step - loss: 7535.4916 - accuracy: 0.0757 - val_loss: 8194.4851 - val_accuracy: 0.0269
# Epoch 15/25
# 28/28 [==============================] - 132s 5s/step - loss: 7315.8249 - accuracy: 0.0783 - val_loss: 8058.1936 - val_accuracy: 0.0243
# Epoch 16/25
# 28/28 [==============================] - 140s 5s/step - loss: 7248.2480 - accuracy: 0.0749 - val_loss: 7948.2515 - val_accuracy: 0.0215
# Epoch 17/25
# 28/28 [==============================] - 136s 5s/step - loss: 7059.7533 - accuracy: 0.0789 - val_loss: 7846.4475 - val_accuracy: 0.0196
# Epoch 18/25
# 28/28 [==============================] - 137s 5s/step - loss: 7002.8111 - accuracy: 0.0779 - val_loss: 7769.9448 - val_accuracy: 0.0170
# Epoch 19/25
# 28/28 [==============================] - 136s 5s/step - loss: 6809.5015 - accuracy: 0.0771 - val_loss: 7689.5305 - val_accuracy: 0.0156
# Epoch 20/25
# 28/28 [==============================] - 139s 5s/step - loss: 6738.9862 - accuracy: 0.0764 - val_loss: 7599.4617 - val_accuracy: 0.0119
# Epoch 21/25
# 28/28 [==============================] - 138s 5s/step - loss: 6789.3622 - accuracy: 0.0695 - val_loss: 7506.6533 - val_accuracy: 0.0109
# Epoch 22/25
# 28/28 [==============================] - 138s 5s/step - loss: 6561.4579 - accuracy: 0.0779 - val_loss: 7461.5042 - val_accuracy: 0.0100
# Epoch 23/25
# 28/28 [==============================] - 138s 5s/step - loss: 6448.2326 - accuracy: 0.0760 - val_loss: 7444.4275 - val_accuracy: 0.0096
# Epoch 24/25
# 28/28 [==============================] - 143s 5s/step - loss: 6273.9413 - accuracy: 0.0780 - val_loss: 7416.9207 - val_accuracy: 0.0085
# Epoch 25/25
# 28/28 [==============================] - 136s 5s/step - loss: 6222.8195 - accuracy: 0.0757 - val_loss: 7374.7837 - val_accuracy: 0.0076

# %%
opt = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
my_model_2.compile(optimizer= opt,loss=yolo_my_loss,metrics=['accuracy'])

# %%
my_model_2.fit(X_train ,Y_train ,epochs= 5,batch_size = 4, validation_data=(X_val,Y_val))
# Out:
# Train on 28 samples, validate on 8 samples
# Epoch 1/5
# 28/28 [==============================] - 504s 18s/step - loss: 9626.5866 - accuracy: 0.2033 - val_loss: 12685.5366 - val_accuracy: 0.3159
# Epoch 2/5
# 28/28 [==============================] - 133s 5s/step - loss: 8461.3539 - accuracy: 0.2063 - val_loss: 14104.6489 - val_accuracy: 0.4013
# Epoch 3/5
# 28/28 [==============================] - 133s 5s/step - loss: 7762.9158 - accuracy: 0.2106 - val_loss: 13005.4937 - val_accuracy: 0.3128
# Epoch 4/5
# 28/28 [==============================] - 133s 5s/step - loss: 6672.9540 - accuracy: 0.1940 - val_loss: 12789.0327 - val_accuracy: 0.3096
# Epoch 5/5
# 28/28 [==============================] - 135s 5s/step - loss: 6046.9941 - accuracy: 0.1923 - val_loss: 100872.4155 - val_accuracy: 0.2867

# %%
my_model_2.fit(X_train ,Y_train ,epochs= 25,batch_size = 4, validation_data=(X_val,Y_val))
# Out:
# Train on 28 samples, validate on 8 samples
# Epoch 1/25
# 28/28 [==============================] - 125s 4s/step - loss: 5301.2705 - accuracy: 0.1896 - val_loss: nan - val_accuracy: 0.3128
# Epoch 2/25
# 28/28 [==============================] - 133s 5s/step - loss: 4686.7521 - accuracy: 0.1905 - val_loss: nan - val_accuracy: 0.3172
# Epoch 3/25
# 28/28 [==============================] - 133s 5s/step - loss: 4306.9745 - accuracy: 0.1996 - val_loss: 27718636796361.4023 - val_accuracy: 0.1969
# Epoch 4/25
# 28/28 [==============================] - 131s 5s/step - loss: 3814.9216 - accuracy: 0.2006 - val_loss: nan - val_accuracy: 0.1844
# Epoch 5/25
# 28/28 [==============================] - 135s 5s/step - loss: 3172.4505 - accuracy: 0.2125 - val_loss: 2264.3157 - val_accuracy: 0.1896
# Epoch 6/25
# 28/28 [==============================] - 135s 5s/step - loss: 2578.1837 - accuracy: 0.2216 - val_loss: 2875000.7246 - val_accuracy: 0.2244
# Epoch 7/25
# 28/28 [==============================] - 137s 5s/step - loss: 1971.2811 - accuracy: 0.2435 - val_loss: nan - val_accuracy: 0.2391
# Epoch 8/25
# 28/28 [==============================] - 136s 5s/step - loss: 1500.3010 - accuracy: 0.2512 - val_loss: -2323.4938 - val_accuracy: 0.1330
# Epoch 9/25
# 28/28 [==============================] - 143s 5s/step - loss: 860.4349 - accuracy: 0.2513 - val_loss: 165030.1328 - val_accuracy: 0.1081
# Epoch 10/25
# 28/28 [==============================] - 140s 5s/step - loss: 393.9876 - accuracy: 0.2629 - val_loss: 1095808361.2500 - val_accuracy: 0.1261
# Epoch 11/25
# 28/28 [==============================] - 137s 5s/step - loss: -495.9941 - accuracy: 0.2774 - val_loss: 84446931.8750 - val_accuracy: 0.0965
# Epoch 12/25
# 28/28 [==============================] - 137s 5s/step - loss: 194.5966 - accuracy: 0.2902 - val_loss: nan - val_accuracy: 0.3341
# Epoch 13/25
# 28/28 [==============================] - 155s 6s/step - loss: 176.9515 - accuracy: 0.2953 - val_loss: nan - val_accuracy: 0.3387
# Epoch 14/25
# 28/28 [==============================] - 140s 5s/step - loss: -559.6186 - accuracy: 0.3057 - val_loss: nan - val_accuracy: 0.2769
# Epoch 15/25
# 28/28 [==============================] - 155s 6s/step - loss: -1055.8284 - accuracy: 0.3217 - val_loss: nan - val_accuracy: 0.2554
# Epoch 16/25
# 28/28 [==============================] - 136s 5s/step - loss: -1719.8988 - accuracy: 0.3282 - val_loss: -6943.9836 - val_accuracy: 0.1256
# Epoch 17/25
# 28/28 [==============================] - 130s 5s/step - loss: -2097.5605 - accuracy: 0.3269 - val_loss: 24284.7808 - val_accuracy: 0.1539
# Epoch 18/25
# 28/28 [==============================] - 133s 5s/step - loss: -3149.5047 - accuracy: 0.3411 - val_loss: nan - val_accuracy: 0.1889
# Epoch 19/25
# 28/28 [==============================] - 135s 5s/step - loss: -3647.9377 - accuracy: 0.3439 - val_loss: nan - val_accuracy: 0.1522
# Epoch 20/25
# 28/28 [==============================] - 132s 5s/step - loss: -3970.7145 - accuracy: 0.3504 - val_loss: 392659231333446320128.0000 - val_accuracy: 0.1978
# Epoch 21/25
# 28/28 [==============================] - 135s 5s/step - loss: -5239.9425 - accuracy: 0.3483 - val_loss: -26256.3721 - val_accuracy: 0.3156
# Epoch 22/25
# 28/28 [==============================] - 135s 5s/step - loss: -5823.7729 - accuracy: 0.3563 - val_loss: -5269.2264 - val_accuracy: 0.3265
# Epoch 23/25
# 28/28 [==============================] - 137s 5s/step - loss: -6392.4933 - accuracy: 0.3611 - val_loss: -17913.7207 - val_accuracy: 0.3220
# Epoch 24/25
# 28/28 [==============================] - 138s 5s/step - loss: -7600.5730 - accuracy: 0.3617 - val_loss: -16939.0845 - val_accuracy: 0.3320
# Epoch 25/25
# 28/28 [==============================] - 138s 5s/step - loss: -7575.1823 - accuracy: 0.3775 - val_loss: -25459.0527 - val_accuracy: 0.5867

# %%
# def yolo_my_loss(y_true, y_pred, anchors_wrt_target):
def yolo_loss(y_true, y_pred):
    
    '''Return yolo_loss
    Parameters
    ----------
    yolo_outputs: list of tensor, the output of yolo_body or tiny_yolo_body
    y_true: list of array, the output of preprocess_true_boxes
    anchors: array, shape=(N, 2), wh ## w.r.t. target size
    num_classes: integer
    ignore_thresh: float, the iou threshold whether to ignore object confidence loss
    Returns
    -------
    loss: tensor, shape=(1,)
    '''
    grid_size = [15., 15.]
    ratio = 480./15.      ## ratio = 32
    ignore_thresh = 0.5
    Lambda_Coord = 5.0
    Lambda_no_obj = 0.5
    
    grid_x = np.arange(grid_size[1])
    grid_y = np.arange(grid_size[0])
    
    a = np.array(np.meshgrid(grid_x, grid_y))
    b = np.array(np.meshgrid(grid_x, grid_y))
    c = np.array(np.meshgrid(grid_x, grid_y))
    d = np.concatenate((a,b,c), axis = 0)
    e = d.transpose(2, 1, 0)
    grid_final = np.reshape(e,[15,15,3,2])
    
#    grid_x = np.arange(grid_size[1])
#    grid_y = np.arange(grid_size[0])
#    grid_x, grid_y = np.meshgrid(grid_x, grid_y)
#    grid_1st = np.dstack((grid_x, grid_y))
#    grid_2nd = np.dstack((grid_1st, grid_x, grid_y))
#    grid_3rd = np.dstack((grid_2nd, grid_x, grid_y)) 
#    grid_final = np.reshape(grid_3rd, [1,15,15,3,2])
    
    loss = tf.zeros(1, dtype='float32')
    
    
#    m = y_true.shape[0]
#    m = np.expand_dims(m, axis=-1)
#    mf = K.cast(m, dtype='float32')

    
    obj_mask = y_true[..., 4:5]
#    obj_mask = K.cast(obj_mask_y, dtype='float32')
    
#    true_box_wh = y_true[..., 2:4]
#    weight = 2 - true_box_wh[..., 0] * true_box_wh[..., 1]
#    weight = np.expand_dims(weight, axis=-1)
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++    
    pred_box_xy = K.sigmoid(y_pred[..., :2]) + grid_final  # this gives x & y in no. of cells. x & y w.r.t. target
                                                            # image = (x & y in no. of cells) / no. of cells
#    pred_box_xy = my_sigmoid(y_pred[..., :2]) + grid_final  # this gives x & y in no. of cells. x & y w.r.t. target
                                                            # image = (x & y in no. of cells) / no. of cells
        
#    pred_box_xy = K.eval(pred_box_xy)  
        
#    Lambda_Coord = K.cast(Lambda_Coord, dtype = 'float32')
    pred_box_xy_wrt_target_image = (pred_box_xy * ratio) / 480.
    true_box_xy_wrt_target_image = y_true[..., :2]
    
#    pred_box_xy_wrt_ti = K.cast(pred_box_xy_wrt_target_image, dtype = 'float32')
#    true_box_xy_wrt_ti = K.cast(true_box_xy_wrt_target_image, dtype = 'float32')
    
#    xy_arr = K.cast((true_box_xy_wrt_ti - pred_box_xy_wrt_ti), dtype='float32')

    xy_arr = np.power((true_box_xy_wrt_target_image - pred_box_xy_wrt_target_image), 2)
    
    xy_loss = K.cast((Lambda_Coord * np.sum(xy_arr * obj_mask)), dtype = 'float32')
    
#    xy_loss = K.cast(Lambda_Coord * tf.reduce_sum(tf.square(xy_arr) * obj_mask), dtype = 'float32')
    
#    xy_loss = (Lambda_Coord *np.sum(mean_squared_error(true_box_xy_wrt_ti, pred_box_xy_wrt_ti) * obj_mask*weight)) / m
    
#    xy_loss = (Lambda_Coord *np.sum(mean_squared_error(true_box_xy_wrt_ti, pred_box_xy_wrt_ti) * obj_mask*weight)) / m
    
#    xy_loss = (Lambda_Coord*tf.reduce_sum(tf.square(true_box_xy_wrt_ti - pred_box_xy_wrt_ti) *obj_mask))/m
#    wh_loss = tf.reduce_sum(tf.square(true_tw_th - pred_tw_th) * object_mask * box_loss_scale * mix_w) / N
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++    
    pred_box_wdht = K.exp(y_pred[..., 2:4]) * (anchors_wrt_target / 480.)
    
#    pred_box_wdht = np.exp(y_pred[..., 2:4]) * (anchors_wrt_target / 480.)
    
#    pred_box_wh = K.cast(pred_box_wdht, dtype = 'float32')
    true_box_wdht = y_true[..., 2:4]
#    true_box_wh = K.cast(true_box_wdht, dtype = 'float32')
    
#    wh_arr = K.cast((K.sqrt(true_box_wh) - K.sqrt(pred_box_wh)), dtype='float32')
    
    wh_arr = np.power((true_box_wdht - pred_box_wdht), 2)
    
    wh_loss = K.cast((Lambda_Coord * np.sum(wh_arr * obj_mask)), dtype = 'float32')
    
## ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++ 

    pred_obj_mask = K.cast(K.sigmoid(y_pred[..., 4:5]), dtype = 'float32')  # shape = 28, 15, 15, 3, 1
       
    true_box_wrt_ti = K.concatenate([true_box_xy_wrt_target_image, true_box_wdht], axis = -1)  ## in x,y,w,h format
    pred_box_wrt_ti = K.concatenate([pred_box_xy_wrt_target_image, pred_box_wdht], axis = -1)  ## in x,y,w,h format
    
    
    
    
#    true_box_wrt_ti = xywh_to_x1y1x2y2(true_box_wrt_ti)  ## converted to x1,y1,x2,y2 format
#    pred_box_wrt_ti = xywh_to_x1y1x2y2(pred_box_wrt_ti)  ## converted to x1,y1,x2,y2 format
    
    ignore_mask = calc_ignore_mask(ignore_thresh, true_box_wrt_ti, pred_box_wrt_ti)
    
#    ignore_mask = K.cast(ignore_mask, dtype = 'float32')                               

    obj_loss = K.cast(K.sum(K.binary_crossentropy(obj_mask, pred_obj_mask) * obj_mask), dtype = 'float32')
    
    loss = (xy_loss + wh_loss +obj_loss) / 4.
    
    return loss

# %%
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
my_yolo_invoice_model.compile(optimizer= opt,loss=yolo_loss,metrics=['accuracy'])

# %%
my_yolo_invoice_model.fit(X_train ,Y_train, epochs= 5, batch_size = 4, validation_data=(X_val,Y_val))
# Out:
# Train on 28 samples, validate on 8 samples
# Epoch 1/5
# 28/28 [==============================] - 3797s 136s/step - loss: 0.0227 - accuracy: 0.0562 - val_loss: 0.0066 - val_accuracy: 0.0611
# Epoch 2/5
# 28/28 [==============================] - 2419s 86s/step - loss: 0.0751 - accuracy: 0.0528 - val_loss: 0.0066 - val_accuracy: 0.0602
# Epoch 3/5
# 28/28 [==============================] - 162s 6s/step - loss: 0.0176 - accuracy: 0.0562 - val_loss: 0.0066 - val_accuracy: 0.0694
# Epoch 4/5
# 28/28 [==============================] - 143s 5s/step - loss: 0.0302 - accuracy: 0.0530 - val_loss: 0.0066 - val_accuracy: 0.0559
# Epoch 5/5
# 28/28 [==============================] - 138s 5s/step - loss: 0.0436 - accuracy: 0.0534 - val_loss: 0.0066 - val_accuracy: 0.0394

# %%
opt = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
my_model_1.compile(optimizer= opt,loss=yolo_loss,metrics=['accuracy'])

# %%
my_model_1.fit(X_train ,Y_train, epochs= 5, batch_size = 4, validation_data=(X_val,Y_val))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-d300528bc973> in <module>()
# ----> 1 my_model_1.fit(X_train ,Y_train, epochs= 5, batch_size = 4, validation_data=(X_val,Y_val))
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1211         else:
#    1212             fit_inputs = x + y + sample_weights
# -> 1213         self._make_train_function()
#    1214         fit_function = self.train_function
#    1215
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/engine/training.py in _make_train_function(self)
#     314                     training_updates = self.optimizer.get_updates(
#     315                         params=self._collected_trainable_weights,
# --> 316                         loss=self.total_loss)
#     317                 updates = self.updates + training_updates
#     318
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/optimizers.py in get_updates(self, loss, params)
#     521               dtype=K.dtype(p),
#     522               name='v_' + str(i))
# --> 523               for (i, p) in enumerate(params)]
#     524
#     525         if self.amsgrad:
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/optimizers.py in <listcomp>(.0)
#     521               dtype=K.dtype(p),
#     522               name='v_' + str(i))
# --> 523               for (i, p) in enumerate(params)]
#     524
#     525         if self.amsgrad:
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in zeros(shape, dtype, name)
#     963         v = tf.zeros(shape=shape, dtype=dtype, name=name)
#     964         if py_all(v.shape.as_list()):
# --> 965             return variable(v, dtype=dtype, name=name)
#     966         return v
#     967
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in variable(value, dtype, name, constraint)
#     618     """
#     619     v = tf_keras_backend.variable(
# --> 620         value, dtype=dtype, name=name, constraint=constraint)
#     621     if hasattr(value, 'tocoo'):
#     622         v._keras_shape = value.tocoo().shape
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/keras/backend.py in variable(value, dtype, name, constraint)
#     780       dtype=dtypes_module.as_dtype(dtype),
#     781       name=name,
# --> 782       constraint=constraint)
#     783   if isinstance(value, np.ndarray):
#     784     v._keras_shape = value.shape
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     261       return cls._variable_v2_call(*args, **kwargs)
#     262     else:
# --> 263       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     264
#     265
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#     458           synchronization=synchronization,
#     459           aggregation=aggregation,
# --> 460           shape=shape)
#     461
#     462   def __repr__(self):
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, shape)
#     631           with ops.name_scope("IsInitialized"):
#     632             self._is_initialized_op = (
# --> 633                 gen_resource_variable_ops.var_is_initialized_op(self._handle))
#     634           if initial_value is not None:
#     635             with ops.name_scope("Assign") as n, ops.colocate_with(self._handle):
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py in var_is_initialized_op(resource, name)
#    1501   # Add nodes to the TensorFlow graph.
#    1502   _, _, _op = _op_def_lib._apply_op_helper(
# -> 1503         "VarIsInitializedOp", resource=resource, name=name)
#    1504   _result = _op.outputs[:]
#    1505   _inputs_flat = _op.inputs
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, dtypes=None, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3614           input_types=input_types,
#    3615           original_op=self._default_original_op,
# -> 3616           op_def=op_def)
#    3617       self._create_op_helper(ret, compute_device=compute_device)
#    3618     return ret
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2025           op_def, inputs, node_def.attr)
#    2026       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 2027                                 control_input_ops)
#    2028
#    2029     # Initialize self._outputs.
#
# ~/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1862
#    1863   try:
# -> 1864     c_op = c_api.TF_FinishOperation(op_desc)
#    1865   except errors.InvalidArgumentError as e:
#    1866     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:
