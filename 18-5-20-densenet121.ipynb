# %%
## https://www.kaggle.com/xhlulu/densenet-121-on-cifar-10-using-keras-beginner

# %%
## Here, we tell keras to download the model’s pretrained weights and save it in the variable conv_base

from keras.applications import DenseNet

conv_base_1 = DenseNet(weights='imagenet', input_shape=(150,150,3))
conv_base_2 = DenseNet(weights='imagenet', include_top=False, input_shape=(150,150,3))
# Out:
# Using TensorFlow backend.
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# ...

# %%
from keras.applications import DenseNet
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-72ea6744b74a> in <module>()
# ----> 1 from keras.applications import DenseNet
#
# ImportError: cannot import name 'DenseNet'

# %%
from tensorflow.keras.applications.densenet import DenseNet121

# %%
conv_base_1 = DenseNet121(weights='imagenet', input_shape=(224,224,3))
conv_base_2 = DenseNet121(weights='imagenet', include_top=False, input_shape=(150,150,3))
# Out:
# WARNING:tensorflow:From /home/scar3crow/Dropbox/WorkStation-Subrata/python/venv1/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
# 20578304/29084464 [====================>.........] - ETA: 29:05
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-6-45f5ce88d86f> in <module>()
#       1 conv_base_1 = DenseNet121(weights='imagenet', input_shape=(224,224,3))
# ----> 2 conv_base_2 = DenseNet121(weights='imagenet', include_top=False, input_shape=(150,150,3))
#
# ...

# %%
conv_base_1.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 112, 112, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 112, 112, 64) 0           conv1/bn[0][0]
# ...

# %%
conv_base_2 = DenseNet121(weights='imagenet', include_top=False, input_shape=(150,150,3))
# Out:
# ...
# 29089792/29084464 [==============================] - 2873s 99us/step

# %%
conv_base_2.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 156, 156, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 75, 75, 64)   9408        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 75, 75, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
conv_base_2 = DenseNet121(weights=None, include_top=False, input_shape=(150,150,3), classes=5)

# %%
conv_base_2.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 156, 156, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 75, 75, 64)   9408        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 75, 75, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from tensorflow.keras import layers, optimizers, regularizers, callbacks
from tensorflow.keras import Sequential

# %%
conv_base_2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
conv_base_2.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 156, 156, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 75, 75, 64)   9408        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 75, 75, 64)   256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# Define callbacks
checkpoint = callbacks.ModelCheckpoint('model.h5', monitor='val_acc', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')

# %%
# Train the model
hist = conv_base_2.fit(x=X_train, y=y_train, validation_split=0.1, batch_size=64, epochs=50, callbacks=[checkpoint], verbose=1)


model.load_weights('model.h5')
train_loss, train_score = conv_base_2.evaluate(X_train, y_train)
test_loss, test_score = conv_base_2.evaluate(X_test, y_test)
print("Train Loss:", train_loss)
print("Test Loss:", test_loss)
print("Train F1 Score:", train_score)
print("Test F1 Score:", test_score)

# %%
## https://notebooks.azure.com/kochansky/projects/lesson1/html/deeplearning2/densenet-keras.ipynb


model.compile(loss='sparse_categorical_crossentropy', 
      optimizer=keras.optimizers.SGD(0.1, 0.9, nesterov=True), metrics=["accuracy"])


parms = {'verbose': 2, 'callbacks': [TQDMNotebookCallback()]}

K.set_value(model.optimizer.lr, 0.1) # OR K.set_value(model.optimizer.lr, 0.01) OR K.set_value(model.optimizer.lr, 0.001)

# Train the model
conv_base_2.fit(x_train, y_train, 64, 20, validation_data=(x_test, y_test), **parms)

model.save_weights('models/93.h5')
