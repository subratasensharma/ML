# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

# %%
pwd
# Out:
# '/home/scar3crow/Dropbox/WorkStation-Subrata/python'

# %%
ls
# Out:
# 01-04-2019.ipynb
# 04-05-embedding.ipynb
# 05-04-19-svm.ipynb
# 0_zp.zip
# 10-04-1029-svm-back-up.ipynb
# 13_06_19_dmart.ipynb
# 14Mar_Gorky_one_labelled.xlsx
# 14Mar_Gorky_.xlsx
# 15-04-2019-svm.ipynb
# 19-04-19-svm.ipynb
# 1-A-IMP-02-05-2020-invoice-tests-1-contd.ipynb
# 1-B-06-05-2020-faster-rcnn-from-xml-file.ipynb
# 1-B-IMP-Detection.ipynb
# 1-IMP-29-04-2020-invoice-tests-1.ipynb
# 1.jpeg
# 1_zp.zip
# 21-04-2019-cvm.ipynb
# 21 Dec_PO Product Categorisation_Sent to Raghav.xlsx
# 21_Dec_Tranzact_IWI.xlsx
# 21_Dec_Tranzact_MESCO.xlsx
# 21_Dec_Tranzact.xlsx
# 22-04-2019-emb-rnn.ipynb
# 22-04-2019-w2v-rnn.ipynb
# 23-04-2019-svm.ipynb
# 23-4-2020-image-detection-segmentation.ipynb
# 24-03-2019.ipynb
# 24-4-2020-fast-r-cnn.ipynb
# 26-03-2019.ipynb
# 26-4-2020-pdf-jpg-edit.ipynb
# 27-03-2019.ipynb
# 28-03-2019.ipynb
# 28-03-2019-w2v_Vs_Tokenizer_Vs_Counter.ipynb
# 28-4-2020-face_detection.ipynb
# 29-03-2019.ipynb
# 29_4_model_keras.h5
# 29_4_model_wieghts.h5
# 2_zp.zip
# ...
