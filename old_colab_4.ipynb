# %%
import tensorflow as tf 
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive 
drive.mount('/mntDrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /mntDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import cv2
import os

# %%
image_path = '/content/drive/My Drive/seal_resized.jpg'
seal_1 = cv2.imread(image_path)
s1, s2, _ = seal_1.shape
print('s1 = ', s1, 's2 = ', s2)
seal_1_pil = Image.fromarray(seal_1)
display(seal_1_pil)
# Out:
# s1 =  800 s2 =  800
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F6BA61951D0>

# %%
# Making a list of image path

mtc_directory = '/content/drive/My Drive/sinocalci_wps'   
                                                        
mtc_image = ['/content/drive/My Drive/sinocalci_wps/{}'.format(i) for i in os.listdir(mtc_directory)] # making the list
mtc_image.sort() # Sorting the list

num_images = len(mtc_image)

print('Number of images = ', num_images)
# Out:
# Number of images =  6

# %%
m

# %%
mtc_1 = cv2.imread(mtc_image[0])
print(mtc_1.shape)
# Out:
# (14600, 10533, 3)

# %%
x = 600
y = 3870

cv2.rectangle(mtc_1, (x, y), (x+s1, y+s2), (0,255,0), 2)
mtc_1_pil = Image.fromarray(mtc_1)
#display(mtc_1_pil)

# %%
mtc_1 = cv2.imread(mtc_image[5])
# mtc_1[y:y+s1, x:x+s2] = cv2.rotate(seal_1, cv2.cv2.ROTATE_90_COUNTERCLOCKWISE)
mtc_1[y:y+s1, x:x+s2] = seal_1         
mtc_1_pil = Image.fromarray(mtc_1)
display(mtc_1_pil)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
mtc_1_pil.save('/content/drive/My Drive/wire_rope_tc.pdf', resolution = 300)

# %%
image_path = '/content/drive/My Drive/seal_resized.jpg'
img = Image.open(image_path) # ex : fr"D:\Prog\Automatisation\Photo tu preferes quoi\signature\signature_1.png"
img = img.convert("RGBA")
datas = img.getdata()

newData = []
for item in datas:
    if item[0] == 0 and item[1] == 0 and item[2] == 0:
        newData.append((0, 0, 0, 0))
    else:
        newData.append(item)

img.putdata(newData)
img.save("/content/drive/My Drive/image_transparente.png", "PNG") # ca enregistre l'image dans le même dossier que là où est le code

# %%
image_path = '/content/drive/My Drive/image_transparente.png'
seal_1 = cv2.imread(image_path)
s1 = 800
s2 = 800
print('s1 = ', s1, 's2 = ', s2)
seal_1_pil = Image.fromarray(seal_1)
display(seal_1_pil)
# Out:
# s1 =  800 s2 =  800
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7FBEBAD6FCF8>
