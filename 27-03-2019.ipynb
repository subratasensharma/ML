# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding, SpatialDropout1D, GRU
from keras.optimizers import RMSprop
from keras.preprocessing.text import Tokenizer

from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
## Loading Data - labelled data:

data_1 = pd.ExcelFile('RNN_Tranzact_Rohan_1_Regrouped_with_supplier.xlsx')
tranzact_data_1 = data_1.parse(0)

tranzact_data_1.tail()
# Out:
#        supplier_item_id                         to_company_name  \
# 13552             86390  CESARE BONETTI INTERNATIONAL PVT. LTD.
# 13553             89723  CESARE BONETTI INTERNATIONAL PVT. LTD.
# 13554             89995  CESARE BONETTI INTERNATIONAL PVT. LTD.
# 13555            117819             WAAREE INDUSTRIES PVT. LTD.
# 13556            169292  CESARE BONETTI INTERNATIONAL PVT. LTD.
#
#        supplier_item_id.1                      supplier_item_id.2  \
# 13552               86390  YOKE SLEEVE;8" # 150;GTV;  B150 C62300
# 13553               89723   YOKE SLEEVE 1½" #2700 BLY;B150 C62300
# 13554               89995    YOKE SLEEVE;4" #150 GTV; B150 C62300
# 13555              117819      YOKE SLEEVE;8" # 150;GTV;  A439 D2
# 13556              169292     YOKE SLEEVE; 1";#1500;CBD;A582 T416
#
#            product                        supplier   Done Atul Sugg. sub_type  \
# 13552  YOKE SLEEVE  CESARE BONETTI INDIA PVT. LTD.  278.0        NaN      NaN
# 13553  YOKE SLEEVE  CESARE BONETTI INDIA PVT. LTD.  278.0        NaN      NaN
# 13554  YOKE SLEEVE  CESARE BONETTI INDIA PVT. LTD.  278.0        NaN      NaN
# 13555    cicasting      Waaree Industries Pvt.Ltd.  278.0        NaN      NaN
# 13556  YOKE SLEEVE  CESARE BONETTI INDIA PVT. LTD.  278.0        NaN      NaN
#
#       material process   grade  spec brand
# 13552      NaN     NaN  C62300   NaN   NaN
# 13553      NaN     NaN  C62300   NaN   NaN
# 13554      NaN     NaN  C62300   NaN   NaN
# 13555      NaN     NaN     NaN   NaN   NaN
# 13556      NaN     NaN     NaN   NaN   NaN

# %%
## Loading Data - un-labelled data:

data_2 = pd.ExcelFile('14Mar_Gorky.xlsx')
tranzact_data_new_1 = data_2.parse(0)

tranzact_data_new_1.tail()
# Out:
#        buyer_item_id        buyer_itemid                    buyer_item_name  \
# 17763         289052        PLYBAG_10X15              POLYBAG_10X15 INCH_PP
# 17764         289639  HANDLENUTM12X5MMXX    HANDLE NUT 1" #600,HTB,A194 Gr8
# 17765          48512      RDBR50 (SS431)  ROUND BAR OD50 ASTM A276 TYPE 431
# 17766          57696  PGX618101601202200      PTV 6" #300 RF BVE WCB HW IBR
# 17767         274954           PPBOX_ST5                     PP_MONOBOX_ST5
#
#       from_company_id                       from_company_name to_company_id  \
# 17763           13872     R-Tech Products & Packaging Pvt Ltd         16730
# 17764             842          CESARE BONETTI INDIA PVT. LTD.          7434
# 17765             114                         Entech Controls           921
# 17766            7506  CESARE BONETTI INTERNATIONAL PVT. LTD.           842
# 17767           13872     R-Tech Products & Packaging Pvt Ltd         15527
#
#                           to_company_name
# 17763               GLORY PACK INDUSTRIES
# 17764                       Shah Brothers
# 17765                       ALPESH METALS
# 17766      CESARE BONETTI INDIA PVT. LTD.
# 17767  Shree Arun Packaging Co. Pvt. Ltd.

# %%
## Picking up required info from labelled data:

col = ['to_company_name', 'supplier_item_id.2', 'product', 'supplier']
tranzact_data_2 = tranzact_data_1[col]
tranzact_data_2.columns = ['OEM', 'item', 'product', 'supplier']

## Removing duplicate (item + supplier) combinations :

tranzact_data_2['find_duplicate'] = tranzact_data_2['item'].map(str)+tranzact_data_2['supplier'].map(str)
tranzact_data_2.drop_duplicates(subset='find_duplicate', keep = 'first', inplace = True)
tranzact_data_2 = tranzact_data_2.reset_index(drop=True)

# Creating separate dataframe for Cesare Bonetti International Pvt. Ltd. since these are unlabelled :

tranzact_data_2_cesare_international = tranzact_data_2.loc[tranzact_data_2['OEM'] \
                                                               == 'CESARE BONETTI INTERNATIONAL PVT. LTD.']

tranzact_data_labelled = tranzact_data_2.drop(tranzact_data_2_cesare_international.index)

tranzact_data_2_cesare_international = tranzact_data_2_cesare_international.reset_index(drop=True)
tranzact_data_labelled = tranzact_data_labelled.reset_index(drop=True)

print(len(tranzact_data_2_cesare_international))
        
print(len(tranzact_data_labelled))

tranzact_data_labelled.tail()
# Out:
# 1754
# 11803
#                                   OEM  \
# 11798  CESARE BONETTI INDIA PVT. LTD.
# 11799  CESARE BONETTI INDIA PVT. LTD.
# 11800  CESARE BONETTI INDIA PVT. LTD.
# 11801  CESARE BONETTI INDIA PVT. LTD.
# 11802     WAAREE INDUSTRIES PVT. LTD.
#
#                                               item              product  \
# 11798   YOKE CASTING 12" #2500 GTV, SA216 WCC, QAP           CS CASTING
# 11799      YOKE CAST, 3" #2500 GTV, SA216 WCC, QAP           CS CASTING
# 11800  YOKE CASTING 12" #2500 GTV, SA217 C12A, QAP  ALLOY STEEL CASTING
# 11801              YOKE CAST 10" #150 TCV; A217WC6  ALLOY STEEL CASTING
# 11802           YOKE SLEEVE;8" # 150;GTV;  A439 D2            cicasting
#
#                          supplier  \
# 11798                  AMI Alloys
# 11799     Tulip Casting Pvt. Ltd.
# 11800                  AMI Alloys
# 11801               RAJ ENGINEERS
# 11802  Waaree Industries Pvt.Ltd.
#
#                                           find_duplicate
# 11798  YOKE CASTING 12" #2500 GTV, SA216 WCC, QAPAMI ...
# 11799  YOKE CAST, 3" #2500 GTV, SA216 WCC, QAPTulip C...
# 11800  YOKE CASTING 12" #2500 GTV, SA217 C12A, QAPAMI...
# 11801       YOKE CAST 10" #150 TCV; A217WC6RAJ ENGINEERS
# 11802  YOKE SLEEVE;8" # 150;GTV;  A439 D2Waaree Indus...

# %%
## Picking up required info from un-labelled data:

col = ['from_company_name', 'buyer_item_name', 'to_company_name']
tranzact_data_new_2 = tranzact_data_new_1[col]
tranzact_data_new_2.columns = ['OEM', 'item', 'supplier']

## Removing duplicate (item + supplier) combinations :

tranzact_data_new_2['find_duplicate'] = tranzact_data_new_2['item'].map(str)+tranzact_data_new_2['supplier'].map(str)
tranzact_data_new_2.drop_duplicates(subset='find_duplicate', keep = 'first', inplace = True)
tranzact_data_un_labelled = tranzact_data_new_2.reset_index(drop=True)

print(len(tranzact_data_un_labelled))
tranzact_data_un_labelled.tail()
# Out:
# 17405
#                                           OEM  \
# 17400     R-Tech Products & Packaging Pvt Ltd
# 17401          CESARE BONETTI INDIA PVT. LTD.
# 17402                         Entech Controls
# 17403  CESARE BONETTI INTERNATIONAL PVT. LTD.
# 17404     R-Tech Products & Packaging Pvt Ltd
#
#                                     item                            supplier  \
# 17400              POLYBAG_10X15 INCH_PP               GLORY PACK INDUSTRIES
# 17401    HANDLE NUT 1" #600,HTB,A194 Gr8                       Shah Brothers
# 17402  ROUND BAR OD50 ASTM A276 TYPE 431                       ALPESH METALS
# 17403      PTV 6" #300 RF BVE WCB HW IBR      CESARE BONETTI INDIA PVT. LTD.
# 17404                     PP_MONOBOX_ST5  Shree Arun Packaging Co. Pvt. Ltd.
#
#                                           find_duplicate
# 17400         POLYBAG_10X15 INCH_PPGLORY PACK INDUSTRIES
# 17401       HANDLE NUT 1" #600,HTB,A194 Gr8Shah Brothers
# 17402     ROUND BAR OD50 ASTM A276 TYPE 431ALPESH METALS
# 17403  PTV 6" #300 RF BVE WCB HW IBRCESARE BONETTI IN...
# 17404   PP_MONOBOX_ST5Shree Arun Packaging Co. Pvt. Ltd.

# %%
## make all in lower case :

tranzact_data_labelled['OEM'] = tranzact_data_labelled['OEM'].map(lambda x: x if type(x)!=str else x.lower()) 
tranzact_data_labelled['item'] = tranzact_data_labelled['item'].map(lambda x: x if type(x)!=str else x.lower()) 
tranzact_data_labelled['product'] = tranzact_data_labelled['product'].map(lambda x: x if type(x)!=str else x.lower())

tranzact_data_un_labelled['OEM'] = tranzact_data_un_labelled['OEM'].map(lambda x: x if type(x)!=str else x.lower()) 
tranzact_data_un_labelled['item'] = tranzact_data_un_labelled['item'].map(lambda x: x if type(x)!=str else x.lower()) 

## remove rows with any cell value = none

tranzact_data_labelled_final = tranzact_data_labelled.dropna()
tranzact_data_un_labelled_final = tranzact_data_un_labelled.dropna()

tranzact_data_labelled_final = tranzact_data_labelled_final.reset_index(drop=True)
tranzact_data_un_labelled_final = tranzact_data_un_labelled_final.reset_index(drop=True)

print(len(tranzact_data_labelled_final))
print(len(tranzact_data_un_labelled_final))
# Out:
# 11803
# 17405

# %%
## digitising 'product' and creating a dictionary for labelled data :

tranzact_data_labelled_final['product_id'] = tranzact_data_labelled_final['product'].factorize()[0]

product_id_df = tranzact_data_labelled_final[['product', 'product_id']].drop_duplicates().sort_values('product_id')
product_to_id = dict(product_id_df.values)
id_to_product = dict(product_id_df[['product_id', 'product']].values)

## removing puncuations from items of both labelled and un-labelled data :

pd.options.mode.chained_assignment = None

tranzact_data_labelled_final['item'] = tranzact_data_labelled_final['item'].str.replace(r'\W',' ')
tranzact_data_un_labelled_final['item'] = tranzact_data_un_labelled_final['item'].str.replace(r'\W',' ')

## remove gaps between words to single gap

tranzact_data_labelled_final['item'] = tranzact_data_labelled_final['item'].str.replace(r'\s+',' ')
tranzact_data_un_labelled_final['item'] = tranzact_data_un_labelled_final['item'].str.replace(r'\s+',' ')

print(len(tranzact_data_labelled_final))
print(len(tranzact_data_un_labelled_final))
tranzact_data_labelled_final.tail()
# Out:
# 11803
# 17405
#                                   OEM  \
# 11798  cesare bonetti india pvt. ltd.
# 11799  cesare bonetti india pvt. ltd.
# 11800  cesare bonetti india pvt. ltd.
# 11801  cesare bonetti india pvt. ltd.
# 11802     waaree industries pvt. ltd.
#
#                                           item              product  \
# 11798   yoke casting 12 2500 gtv sa216 wcc qap           cs casting
# 11799       yoke cast 3 2500 gtv sa216 wcc qap           cs casting
# 11800  yoke casting 12 2500 gtv sa217 c12a qap  alloy steel casting
# 11801             yoke cast 10 150 tcv a217wc6  alloy steel casting
# 11802            yoke sleeve 8 150 gtv a439 d2            cicasting
#
#                          supplier  \
# 11798                  AMI Alloys
# 11799     Tulip Casting Pvt. Ltd.
# 11800                  AMI Alloys
# 11801               RAJ ENGINEERS
# 11802  Waaree Industries Pvt.Ltd.
#
#                                           find_duplicate  product_id
# 11798  YOKE CASTING 12" #2500 GTV, SA216 WCC, QAPAMI ...          18
# 11799  YOKE CAST, 3" #2500 GTV, SA216 WCC, QAPTulip C...          18
# 11800  YOKE CASTING 12" #2500 GTV, SA217 C12A, QAPAMI...          39
# 11801       YOKE CAST 10" #150 TCV; A217WC6RAJ ENGINEERS          39
# 11802  YOKE SLEEVE;8" # 150;GTV;  A439 D2Waaree Indus...          17

# %%
## DO NOT USE THIS STEP
# get stop words from nltk
stopWords = stopwords.words('english')

# pre processing data
def cleanData(sentence):
    processedList = ""
    
    # convert to lowercase, ignore all special characters - keep only alpha-numericals and spaces (not removing full-stop here)
    sentence = re.sub(r'[^A-Za-z0-9\s.]',r'',str(sentence).lower())
    sentence = re.sub(r'\n',r' ',sentence)
    
    # remove stop words
    sentence = " ".join([word for word in sentence.split() if word not in stopWords])
    
    return sentence

# %%
## DO NOT USE THIS STEP
# clean data of one example:
cleanData(data['Description'][2]) ## cleaning of dataframe 'data' column 'Description' index no. '2'

# clean data for whole dataframe
data['Description'] = data['Description'].map(lambda x: cleanData(x))

# %%
total_item_labelled_unlabelled = pd.DataFrame(pd.concat([tranzact_data_labelled_final['item'], \
                                            tranzact_data_un_labelled_final['item']]))
total_item_labelled_unlabelled.head()
# Out:
#                                                 item
# 0                               new cylinder 404 gas
# 1  accumulator model a as 5126 3 4 connection eme...
# 2            accumulator flokool 3 4 400 psi fksa596
# 3                       accumulator 1 5 8 connection
# 4                                   accumulator 7 8

# %%
print(len(total_item_labelled_unlabelled))
total_item_labelled_unlabelled.tail()
# Out:
# 29208
#                                     item
# 17400              polybag_10x15 inch_pp
# 17401      handle nut 1 600 htb a194 gr8
# 17402  round bar od50 astm a276 type 431
# 17403        ptv 6 300 rf bve wcb hw ibr
# 17404                     pp_monobox_st5

# %%
total_item_labelled_unlabelled = total_item_labelled_unlabelled.reset_index(drop=True)
total_item_labelled_unlabelled.tail()
# Out:
#                                     item
# 29203              polybag_10x15 inch_pp
# 29204      handle nut 1 600 htb a194 gr8
# 29205  round bar od50 astm a276 type 431
# 29206        ptv 6 300 rf bve wcb hw ibr
# 29207                     pp_monobox_st5

# %%
from gensim.models import Word2Vec
from nltk import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/scar3crow/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
total_item_labelled_unlabelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29208 entries, 0 to 29207
# Data columns (total 1 columns):
# item    29208 non-null object
# dtypes: object(1)
# memory usage: 228.3+ KB

# %%
tmp_corpus = total_item_labelled_unlabelled['item'].map(lambda x: x.split('.'))

# %%
print(type(tmp_corpus))
print(tmp_corpus)
# Out:
# <class 'pandas.core.series.Series'>
# 0                                   [new cylinder 404 gas]
# 1        [accumulator model a as 5126 3 4 connection em...
# 2                [accumulator flokool 3 4 400 psi fksa596]
# 3                           [accumulator 1 5 8 connection]
# 4                                       [accumulator 7 8 ]
# 5                                      [accumulator 13 8 ]
# 6                [accumulator flokool 5 8 400 psi fksa596]
# 7                                      [accumulator 1 1 8]
# 8                                      [accumulator 2 1 8]
# 9                                    [accumulator 5216 7s]
# 10                                        [buthyl acetate]
# 11                                         [ethyl acetate]
# 12                                 [npac n proyl acetate ]
# 13                                      [pma p m acetate ]
# 14         [flashback arrester acetylene cylinder mounted]
# 15                                [acetylene cylinder 4kg]
# 16                                         [acetylene gas]
# 17                                  [meta phosphoric acid]
# 18                                [standard ascorbic acid]
# 19                           [protobond acid for cleaning]
# 20                        [distilled rice bran fatty acid]
# 21                                           [citric acid]
# 22                                [uric acid des kit erba]
# 23                                           [lauric acid]
# 24                                       [palm fatty acid]
# 25                             [consumables hil acid 5ltf]
# 26              [spare kit iq range elect actuator rotork]
# 27       [pneumatic actuator rpa250sr 4 s air fail to o...
# 28                       [pneumatic actuator rpa100sr 4 s]
# 29                       [pneumatic actuator rpa150sr 4 s]
#                                ...
# 29178      [s1920 tandem diaphragm disc casting a00001858]
# 29179      [lower spring guide casting s g iron a00001666]
# 29180    [s1920 tandem upper spring guide casting a0000...
# 29181                                  [panel sticker tpw]
# 29182                                        [fc pouch 50]
# 29183                                   [connector filter]
# 29184                            [raken slide for pug m c]
# 29185                                         [flow meter]
# 29186           [enclosure 144 144 80 front blazel plain ]
# 29187                               [h 2319 for polishing]
# 29188    [aoh 24148 220 id x260 od x180 len for laser m...
# 29189         [evaporating coil 12 x 30 x 4 rows 3 8 tube]
# 29190                             [rubber grip rubber big]
# 29191                               [h 3130 for machining]
# 29192                                             [rework]
# 29193                 [bottom body machined service order]
# 29194                    [top body machined service order]
# 29195                                        [ss wiremesh]
# 29196                     [pinion en 8 module 12 teeth 15]
# 29197            [grinding disc 7 dia 180 5mm thick 22mm ]
# 29198                                  [inside caliper 6 ]
# 29199                            [inside caliper size 12 ]
# 29200                  [ms wire brush diameter 24mm x 6mm]
# 29201                  [ms wire brush diameter 12mm x 6mm]
# 29202                               [polybag 9x13 inch_pp]
# 29203                              [polybag_10x15 inch_pp]
# 29204                      [handle nut 1 600 htb a194 gr8]
# 29205                  [round bar od50 astm a276 type 431]
# 29206                        [ptv 6 300 rf bve wcb hw ibr]
# 29207                                     [pp_monobox_st5]
# Name: item, Length: 29208, dtype: object

# %%
from tqdm import tqdm

# %%
print(len(tmp_corpus))
print(tmp_corpus[29207])
# Out:
# 29208
# ['pp_monobox_st5']

# %%
corpus = []
for i in tqdm(range(len(tmp_corpus))):
    for line in tmp_corpus[i]:
        words = [x for x in line.split()]
        corpus.append(words)
# Out:
# 100%|██████████| 29208/29208 [00:00<00:00, 48421.05it/s]

# %%
print(corpus)
# Out:
# [['new', 'cylinder', '404', 'gas'], ['accumulator', 'model', 'a', 'as', '5126', '3', '4', 'connection', 'emerson', 'make'], ['accumulator', 'flokool', '3', '4', '400', 'psi', 'fksa596'], ['accumulator', '1', '5', '8', 'connection'], ['accumulator', '7', '8'], ['accumulator', '13', '8'], ['accumulator', 'flokool', '5', '8', '400', 'psi', 'fksa596'], ['accumulator', '1', '1', '8'], ['accumulator', '2', '1', '8'], ['accumulator', '5216', '7s'], ['buthyl', 'acetate'], ['ethyl', 'acetate'], ['npac', 'n', 'proyl', 'acetate'], ['pma', 'p', 'm', 'acetate'], ['flashback', 'arrester', 'acetylene', 'cylinder', 'mounted'], ['acetylene', 'cylinder', '4kg'], ['acetylene', 'gas'], ['meta', 'phosphoric', 'acid'], ['standard', 'ascorbic', 'acid'], ['protobond', 'acid', 'for', 'cleaning'], ['distilled', 'rice', 'bran', 'fatty', 'acid'], ['citric', 'acid'], ['uric', 'acid', 'des', 'kit', 'erba'], ['lauric', 'acid'], ['palm', 'fatty', 'acid'], ['consumables', 'hil', 'acid', '5ltf'], ['spare', 'kit', 'iq', 'range', 'elect', 'actuator', 'rotork'], ['pneumatic', 'actuator', 'rpa250sr', '4', 's', 'air', 'fail', 'to', 'open'], ['pneumatic', 'actuator', 'rpa100sr', '4', 's'], ['pneumatic', 'actuator', 'rpa150sr', '4', 's'], ['pneumatic', 'actuator', 'rpa330sr', '4', 's', 'air', 'fail', 'to', 'open'], ['rotex', 'make', 'double', 'acting', 'actuator'], ['rotex', 'make', 'pneumatic', 'positioner', 'single', 'acting', 'actuator', '3', '15', 'psi', 'sensor', 'model', 'p', 'f', 'make', 'proximity', 'type', 'rating', '8vdc', '3ma', 'nc', 'sensor', 'model', 'nj2', 'v3', 'n', 'cable', 'entry', '1', '2', 'npt', 'aluminium', 'enclosure'], ['pneumatic', 'actuator', 'model', 'rpa80sr', 's', '1'], ['actuator', 'mounting', 'details', 'for', '10', 'f10'], ['pneumatic', 'actuator', 'model', 'rpa150sr', '3', 'with', 'handwheel'], ['actuator', 'mounting', 'details', 'for', '1', '1', '2', '1500', 'floating'], ['actuator', 'mounting', 'details', 'for', '1', '1500', 'floating'], ['actuator', 'mounting', 'details', 'for', '2', '150', 'floating'], ['pneumatic', 'actuator', 'model', 'rpa150sr', '2', 'with', 'handwheel'], ['pneumatic', 'actuator', 'model', 'rpa150sr', '4', 'with', 'handwheel'], ['actuator', 'mounting', 'details', 'for', '2', '1500', 'floating'], ['pneumatic', 'actuator', 'model', 'rpa200sr', '4', 'with', 'handwheel', 'air', 'fail', 'to', 'close'], ['actuator', 'mounting', 'details', 'for', '4', '150', 'floating'], ['pneumatic', 'actuator', 'model', 'rpa200sr', '4', 'with', 'handwheel', 'air', 'fail', 'to', 'open'], ['actuator', 'mounting', 'details', 'for', '3', '900', 'floating'], ['pneumatic', 'actuator', 'model', 'rpa250sr', '3', 'with', 'handwheel'], ['pneumatic', 'actuator', 'model', 'rpa200sr', '4', 'with', 'handwheel'], ['actuator', 'mounting', 'details', 'for', '4', '300', 'floating'], ['actuator', 'mounting', 'details', 'for', '1', '150', 'floating'], ['pneumatic', 'actuator', 'model', 'rpa', '500d', 'with', 'handwheel', 'fail', 'to', 'close', 'tubings', 'and', 'fitting', 'shall', 'be', 'double', 'ferrule', 'ss', '316', 'material'], ['actuator', 'rpa100sr', 's1', 'fail', 'open', 'operation', 'modulating', 'single', 'acting', 'piston', 'spring', 'return', 'type'], ['actuator', 'rpa100sr', 's2', 'fail', 'close', 'operation', 'modulating', 'single', 'acting', 'piston', 'spring', 'return', 'type'], ['actuator', 'rpa100sr', 's2', 'fail', 'close', 'operation', 'modulating', 'single', 'acting', 'piston', 'spring', 'return', 'type', 'fire', 'proof', 'arrangement', 'to', 'be', 'provided', 'for', 'actuator'], ['electrical', 'actuator', 'make', 'rotork', 'model', 'k600f14a', 'syncropak', 'mounting', 'flange', 'f14', 'rpm', '48rpm', 'enclosure', 'wt', 'ip68', 'duty', 'on', 'off', 'handwheel', 'top', 'mounted', 'wiring', 'diagram', '1687z00'], ['pneumatic', 'act', 'pa250', 'travel', '7', 'reverse', 'acting', 'fail', 'safe', 'close', 'spring', 'range', '1', '4', '4', 'bar', 'thrust', '743kg', 'cm²'], ['rotork', 'electric', 'actuator', 'model', 'no', 'iq10f10', 'b4', ...

# %%
num_of_items = len(corpus)
num_of_words = 0
for line in corpus:
    num_of_words += len(line)

print('Num of sentences - %s'%(num_of_items))
print('Num of words - %s'%(num_of_words))
# Out:
# Num of sentences - 29208
# Num of words - 216958

# %%
emb_dim = 80

model_1 = Word2Vec(corpus, size = emb_dim, window=5, \
               min_count=1, negative = 15, iter = 10, workers = 10, sg=1)

# %%
print(corpus[0])
print(corpus[29207])
print(len(corpus[0]))
print(len(corpus))
# Out:
# ['new', 'cylinder', '404', 'gas']
# ['pp_monobox_st5']
# 4
# 29208

# %%
print(model_1)
aa = model_1.wv[corpus[0]]
bb = model_1.wv[corpus[29207]]
print(aa.shape)
print(bb.shape)
print(type(aa))

max_length = 0

for i in range(len(corpus)):
    
    if len(corpus[i]) > max_length:
        max_length = len(corpus[i])
        
    if i == len(corpus) - 1:
        break
    
print(max_length)
# Out:
# Word2Vec(vocab=14883, size=100, alpha=0.025)
# (4, 100)
# (1, 100)
# <class 'numpy.ndarray'>
# 121

# %%
print(aa)
# Out:
# [[-1.36920251e-02 -1.91915229e-01 -1.46016665e-02  8.07005912e-02
#   -1.80989224e-02  5.16877532e-01 -2.04599530e-01  1.07788868e-01
#    3.32666226e-02 -3.43482345e-02  1.15733638e-01  2.02077240e-01
#    4.36292171e-01 -1.76608190e-01  6.16484284e-01 -1.31123522e-02
#   -7.63806477e-02 -2.20596582e-01 -3.72356921e-01  1.43678457e-01
#   -1.24736115e-01  1.79737985e-01 -2.43175581e-01  8.72581825e-02
#    1.21714175e-01  1.86870128e-01  1.36669576e-01  1.64705753e-01
#    2.73718208e-01  1.67318031e-01  1.41399726e-01  8.67116228e-02
#   -2.48927683e-01 -3.29021993e-03 -1.58707965e-02  1.77948549e-01
#   -4.24034715e-01 -3.37334305e-01  2.38433525e-01  7.04402402e-02
#    3.78370821e-01  1.23624459e-01  1.94320753e-01 -2.27703750e-01
#   -9.49257314e-02  1.12994745e-01 -1.00431852e-01 -1.98412076e-01
#    1.59588024e-01 -2.86482777e-02  5.55917919e-01 -1.85782760e-01
#   -1.59414515e-01 -3.26369673e-01  5.73112845e-01  2.12961122e-01
#   -7.46857822e-01  7.34304041e-02 -8.19399178e-01  6.63788915e-02
#    3.63458022e-02 -1.09131165e-01  8.91536474e-02  3.76309790e-02
#   -4.78541583e-01  1.56541631e-01  1.65026151e-02 -5.94679236e-01
#   -1.18457623e-01 -2.14745656e-01 -6.03856817e-02  1.37543872e-01
#   -4.16906297e-01 -8.79004300e-02  4.69422862e-02 -3.59543450e-02
#    4.19280857e-01  2.03286722e-01 -1.06893525e-01  4.07775730e-01
#    4.65942055e-01 -5.22864051e-02 -1.80672616e-01 -3.86943758e-01
#    3.51565719e-01  2.56985217e-01  3.96263897e-01 -1.71030119e-01
#    4.69496280e-01 -3.61665040e-02 -7.79508412e-01 -5.21037988e-02
#   -1.24936298e-01  9.91407782e-02 -4.79008526e-01 -5.90782352e-02
#   -5.41072607e-01  3.37880552e-01  9.64771137e-02  3.46475244e-01]]

# %%
tokenizer_obj = Tokenizer()
tokenizer_obj_1 = Tokenizer()

tokenizer_obj.fit_on_texts(total_item_labelled_unlabelled['item'])
tokenizer_obj_1.fit_on_texts(tranzact_data_labelled_final['item'])

## pad sequences :

max_length = max([len(s.split()) for s in total_item_labelled_unlabelled['item']])
min_length = min([len(s.split()) for s in total_item_labelled_unlabelled['item']])

## define vocabulary size :

vocab_size = len(tokenizer_obj.word_index) + 1
vocab_size_1 = len(tokenizer_obj_1.word_index) + 1

total_item_tokens = tokenizer_obj.texts_to_sequences(total_item_labelled_unlabelled['item'])
total_item_tokens_1 = tokenizer_obj_1.texts_to_sequences(tranzact_data_labelled_final['item'])

total_item_pad = pad_sequences(total_item_tokens, maxlen = max_length, padding = 'post')
total_item_pad_1 = pad_sequences(total_item_tokens_1, maxlen = max_length, padding = 'post')

# %%
wd_index = tokenizer_obj.word_index
print(wd_index)
# Out:
': 3854, '01': 537, 'le18b22rd': 6359, '69': 2116, 'hexagonal': 2012, '2440': 2560, 'electronik': 2542, 'dn30': 2890, 's20r': 4212, '2018': 3665, '4pin': 2976, '1220x1500x5': 6102, 'm24': 766, 'f304': 296, '415v': 1539, 'hs1m': 3056, 'logic': 6141, 'bellow': 3811, '434': 5528, 'cobra': 5316, 'water': 773, '808053083': 5586, '70mm': 923, 'uc18h7tft': 6387, 'pipe': 24, 'ssr': 1389, '300mw': 4748, 'a00000440': 6180, 'throughbeam': 7023, '6206zz': 4156, 'd220': 1895, '24148': 6551, '1840': 5399, 'stell': 7821, '90dg': 1264, 'bwø294xø240': 3821, 'channel': 519, 'siliciumcarbid': 6299, 'mmsz5231bt1g': 4701, '36mm': 3426, '168': 1984, 'allenkey': 1750, ...

# %%
wrd = 'prmium'
print(model_1.wv.word_vec(wrd))
# Out:
# [ 0.24179202  0.06549174 -0.38604274  0.2220079  -0.17099561 -0.00210161
#  -0.19163914  0.02628648  0.1819302  -0.13675494  0.03219317 -0.00996133
#  -0.05369972  0.2527915   0.2741835   0.12086015 -0.04894331 -0.16053675
#  -0.00583438  0.00325824  0.06969016 -0.11515658  0.0805554   0.09401441
#   0.2272013   0.03878359  0.27700585 -0.00347151  0.03068962  0.12152074
#   0.20699036  0.09057083  0.06172016  0.08677412  0.16805473  0.0134774
#  -0.09955977 -0.23010123  0.11060134  0.06406747  0.2174236  -0.03278314
#   0.10400584  0.06704241 -0.21097016 -0.12631032 -0.05094669 -0.09503785
#  -0.10903387 -0.0955196   0.22453734 -0.03931703 -0.17506832 -0.19794413
#   0.3891973   0.35113436 -0.5200029   0.1512953  -0.04274882 -0.15493187
#   0.07763566 -0.08534835  0.02209762  0.04802343 -0.04624603  0.12014635
#  -0.162002   -0.21071538 -0.04798426  0.07724632 -0.19445488 -0.2439696
#  -0.23706     0.02334258 -0.12904176 -0.14800826  0.02665363  0.13792053
#   0.11965785  0.28002065]

# %%
j = 0

# %%
## prepare embeddings

## Preparing embedding matrix

nb_words = min(vocab_size, vocab_size_1)-1

embedding_matrix = np.zeros((nb_words, emb_dim))

    
for word, i in word_index.items():
        
        
    if word in model_1.wv.vocab:
            
        embedding_matrix[j] = model_1.wv.word_vec(word)
        j = j+1
    
    else:
                
        print(word)
        
        
print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
# Out:
# iot
# le18b22rd
# uc18h7tft
# 18g16sk
# ver1
# txmr
# 1ohm
# m66
# 935uh
# le18b28pid
# 1755uh
# le15k17cl
# 52uh
# 05w
# 54w
# gaurds
# le18h23ap
# 16uh
# le18j27dg2
# jsw
# guards
# le17h8ap
# le18k1m
# 18b3sk
# le17l2ap
# le18j19ap
# jsav150
# le18h16dg2
# le18l12dg2
# 89x74
# atomfan4
# 48x38
# le17f5wc
# elettro
# tft
# Null word embeddings: 35

# %%
print(type(embedding_matrix))
print(embedding_matrix.shape)
print(embedding_matrix[0])
# Out:
# <class 'numpy.ndarray'>
# (7948, 80)
# [ 0.24179202  0.06549174 -0.38604274  0.2220079  -0.17099561 -0.00210161
#  -0.19163914  0.02628648  0.1819302  -0.13675494  0.03219317 -0.00996133
#  -0.05369972  0.25279149  0.27418351  0.12086015 -0.04894331 -0.16053675
#  -0.00583438  0.00325824  0.06969016 -0.11515658  0.0805554   0.09401441
#   0.2272013   0.03878359  0.27700585 -0.00347151  0.03068962  0.12152074
#   0.20699036  0.09057083  0.06172016  0.08677412  0.16805473  0.0134774
#  -0.09955977 -0.23010123  0.11060134  0.06406747  0.2174236  -0.03278314
#   0.10400584  0.06704241 -0.21097016 -0.12631032 -0.05094669 -0.09503785
#  -0.10903387 -0.0955196   0.22453734 -0.03931703 -0.17506832 -0.19794413
#   0.38919729  0.35113436 -0.5200029   0.1512953  -0.04274882 -0.15493187
#   0.07763566 -0.08534835  0.02209762  0.04802343 -0.04624603  0.12014635
#  -0.162002   -0.21071538 -0.04798426  0.07724632 -0.19445488 -0.2439696
#  -0.23706     0.02334258 -0.12904176 -0.14800826  0.02665363  0.13792053
#   0.11965785  0.28002065]

# %%
## Total no. of unique words = vocab_size = 14707
## each word has got 150 parameters as per Embedding Dimension defined.
## Hence total Param # = 14707 * 150 = 2206050

# %%
from keras.models import Sequential

model_2 = Sequential()
model_2.add(Embedding(vocab_size_1, emb_dim, weights=[embedding_matrix],\
                    input_length=max_length, trainable=False))
model_2.add(SpatialDropout1D(0.2))
#model.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2))
model_2.add(GRU(units=32, dropout=0.2, recurrent_dropout=0.2))
model_2.add(Dense(256, activation='relu'))
model_2.add(Dense(71, activation='softmax'))
model_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

model_2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 121, 100)          794900
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 121, 100)          0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 32)                12768
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8448
# _________________________________________________________________
# dense_2 (Dense)              (None, 71)                18247
# =================================================================
# Total params: 834,363
# Trainable params: 39,463
# Non-trainable params: 794,900
# _________________________________________________________________

# %%
## Creating X and Y variables for training. X = Items or item 'feature'. Y = 'product' or product category

X = []
for i in range(len(tranzact_data_labelled_final)):
    
    X.append(tranzact_data_labelled_final.iloc[i]['item'])
#Q = np.array(tranzact_data_3["product"])
Y = tranzact_data_labelled_final['product']
print(X[1])

print(Y[1])
# Out:
# accumulator model a as 5126 3 4 connection emerson make
# cooling

# %%
#train test split in 80% / 20% ratio

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state = 5)

# %%
## X_train and X_test word embedding :

X_train_tokens = tokenizer_obj_1.texts_to_sequences(X_train)
X_test_tokens = tokenizer_obj_1.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_tokens, maxlen = max_length, padding = 'post')
X_test_pad = pad_sequences(X_test_tokens, maxlen = max_length, padding = 'post')

# %%
print(X_train_pad.shape)
print(X_test_pad.shape)
print(max_length)
print(vocab_size_1)
# Out:
# (9442, 121)
# (2361, 121)
# 121
# 7949

# %%
from sklearn.preprocessing import LabelBinarizer

encoder = LabelBinarizer()

Y_train_coded = encoder.fit_transform(Y_train)
Y_test_coded = encoder.fit_transform(Y_test)

print(Y_train_coded.shape)
print(Y_test_coded.shape)
# Out:
# (9442, 71)
# (2361, 69)

# %%
model_2.fit(X_train_pad,Y_train_coded,batch_size=128,epochs=25,
          validation_split=0.2)
# Out:
# Train on 7553 samples, validate on 1889 samples
# Epoch 1/25
# 7553/7553 [==============================] - 8s 1ms/step - loss: 3