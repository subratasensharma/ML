# %%
import os
import pandas as pd
import json
import numpy as np

data = []
os.chdir('/home/scar3crow/Downloads/')
with open('via_new.json', encoding="utf8") as data_file:    
     for line in data_file:
        data.append(json.loads(line))

dataframe = pd.DataFrame(data)        
dataframe.head()
# Out:
#                                        101a.jpg14939  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        102a.jpg22722  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        103a.jpg23069  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        104a.jpg21988  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        105a.jpg15143  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        106a.jpg14403  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        107a.jpg13723  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        108a.jpg21444  \
# 0  {'base64_img_data': '', 'file_attributes': {},...
#
#                                        109a.jpg22227  \
# ...

# %%
aa = dataframe['101a.jpg14939'][0]
aa
# Out:
# {'base64_img_data': '',
#  'file_attributes': {},
#  'filename': '101a.jpg',
#  'fileref': '',
#  'regions': {'0': {'region_attributes': {'text': 'vendor'},
#    'shape_attributes': {'height': 48,
#     'name': 'rect',
#     'width': 143,
#     'x': 8,
#     'y': 29}},
#   '1': {'region_attributes': {'text': 'invoice'},
#    'shape_attributes': {'height': 23,
#     'name': 'rect',
#     'width': 50,
#     'x': 292,
#     'y': 27}},
#   '2': {'region_attributes': {'text': 'inv_date'},
#    'shape_attributes': {'height': 26,
#     'name': 'rect',
#     'width': 66,
#     'x': 380,
#     'y': 22}},
#   '3': {'region_attributes': {'text': 'po'},
#    'shape_attributes': {'height': 25,
#     'name': 'rect',
#     'width': 86,
#     'x': 290,
#     'y': 79}},
#   '4': {'region_attributes': {'text': 'buyer'},
#    'shape_attributes': {'height': 51,
#     'name': 'rect',
#     'width': 171,
#     'x': 5,
#     'y': 126}}},
#  'size': 14939}

# %%
import json

import csv

# Opening JSON file and loading the data 
# into the variable data 
with open('/home/scar3crow/Downloads/via_new.json') as json_file: 
    data = json.load(json_file) 
print(type(data))    
for x in data:
  print(data[x])
print(type(x))
# Out:
# <class 'dict'>
# {'base64_img_data': '', 'file_attributes': {}, 'regions': {'3': {'region_attributes': {'text': 'po'}, 'shape_attributes': {'height': 21, 'name': 'rect', 'y': 203, 'x': 289, 'width': 169}}, '4': {'region_attributes': {'text': 'buyer'}, 'shape_attributes': {'height': 75, 'name': 'rect', 'y': 166, 'x': 23, 'width': 219}}, '1': {'region_attributes': {'text': 'invoice'}, 'shape_attributes': {'height': 22, 'name': 'rect', 'y': 163, 'x': 286, 'width': 114}}, '0': {'region_attributes': {'text': 'vendor'}, 'shape_attributes': {'height': 69, 'name': 'rect', 'y': 49, 'x': 90, 'width': 304}}, '2': {'region_attributes': {'text': 'inv_date'}, 'shape_attributes': {'height': 19, 'name': 'rect', 'y': 184, 'x': 289, 'width': 126}}}, 'filename': '110a.jpg', 'fileref': '', 'size': 20159}
# {'base64_img_data': '', 'file_attributes': {}, 'regions': {}, 'filename': '56a.jpg', 'fileref': '', 'size': 22138}
# ...

# %%
photo_data
# Out:
# {'base64_img_data': '',
#  'file_attributes': {},
#  'filename': '101a.jpg',
#  'fileref': '',
#  'regions': {'0': {'region_attributes': {'text': 'vendor'},
#    'shape_attributes': {'height': 48,
#     'name': 'rect',
#     'width': 143,
#     'x': 8,
#     'y': 29}},
#   '1': {'region_attributes': {'text': 'invoice'},
#    'shape_attributes': {'height': 23,
#     'name': 'rect',
#     'width': 50,
#     'x': 292,
#     'y': 27}},
#   '2': {'region_attributes': {'text': 'inv_date'},
#    'shape_attributes': {'height': 26,
#     'name': 'rect',
#     'width': 66,
#     'x': 380,
#     'y': 22}},
#   '3': {'region_attributes': {'text': 'po'},
#    'shape_attributes': {'height': 25,
#     'name': 'rect',
#     'width': 86,
#     'x': 290,
#     'y': 79}},
#   '4': {'region_attributes': {'text': 'buyer'},
#    'shape_attributes': {'height': 51,
#     'name': 'rect',
#     'width': 171,
#     'x': 5,
#     'y': 126}}},
#  'size': 14939}
