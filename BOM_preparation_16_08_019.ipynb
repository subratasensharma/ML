# %%
import matplotlib.pyplot as plt

from PIL import Image

# %%
image_1 = Image.open('ML-9894-19-FSM-02-00-Model.jpg')
image_2 = Image.open('ML-2.jpg')

# %%
plt.imshow(image_1)
plt.show()

# %%
plt.imshow(image_2)
plt.show()

# %%
print(type(image_1))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
# summarize some details about the image
print(image_1.format)
print(image_1.mode)
print(image_1.size)
# show the image
image_1.show()
# Out:
# JPEG
# RGB
# (1600, 1280)

# %%
# summarize some details about the image
print(image_2.format)
print(image_2.mode)
print(image_2.size)
# Out:
# JPEG
# RGB
# (2144, 2988)

# %%
import numpy as np
from numpy import asarray

data_1 = asarray(image_1)
data_2 = asarray(image_2)

print(data_1.shape)
print(data_2.shape)
# Out:
# (1280, 1600, 3)
# (2988, 2144, 3)

# %%
print(data_1[1000,1500,:])
# Out:
# [0 0 0]

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data_1 = image.imread('ML-9894-19-FSM-02-00-Model.jpg')
data_2 = image.imread('ML-2.jpg')
# summarize shape of the pixel array
print(data_1.dtype)
print(data_2.dtype)
print(data_1.shape)
print(data_2.shape)
# display the array of pixels as an image
pyplot.imshow(data_1)
pyplot.show()
# Out:
# uint8
# uint8
# (1280, 1600, 3)
# (2988, 2144, 3)

# %%
## https://machinelearningmastery.com/how-to-load-and-manipulate-images-for-deep-learning-in-python-with-pil-pillow/

# %%
image_2R = image_2.rotate(90)

# %%
plt.imshow(image_2R)
plt.show()

# %%
print(image_2R.size)
# Out:
# (2144, 2988)
